# %%
# Cell 1: Install ViennaRNA
# !pip install viennarna

# Verify installation
try:
    import RNA
    VIENNA_AVAILABLE = True
    print("✓ ViennaRNA loaded successfully")
except ImportError:
    VIENNA_AVAILABLE = False
    print("⚠ ViennaRNA not available, using heuristic stability function")
    print("  Install with: !pip install viennarna")
# Out:
# Collecting viennarna
#   Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 45.0 MB/s eta 0:00:00
# Installing collected packages: viennarna
# Successfully installed viennarna-2.7.2
# ✓ ViennaRNA loaded successfully

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Stability-Distillation Hypothesis Simulation
Simulates wet-dry cycles driving RNA sequence frequency convergence and the emergence of tRNA-like structures.

Run in Google Colab:
    # !pip install viennarna
    then run this script.

Key mechanisms:
- Wet phase: Unstable sequences degrade based on thermal/acidic stress
- Dry phase: Frequent stable sequences ligate to form longer RNAs
- Nucleotide supplementation: Periodic monomer input from geothermal activity
- Stability difference amplification: Harsh conditions magnify stability disparities
"""

import numpy as np
import random
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
import warnings
warnings.filterwarnings('ignore')

# Try to import ViennaRNA for accurate stability calculation
try:
    import RNA
    VIENNA_AVAILABLE = True
    print("✓ ViennaRNA loaded successfully")
except ImportError:
    VIENNA_AVAILABLE = False
    print("⚠ ViennaRNA not available, using heuristic stability function")
    print("  Install with: !pip install viennarna")

# ============================================================================
# Part 1: Stability Calculation Functions
# ============================================================================

def calculate_stability_vienna(sequence, harshness=1.0):
    """
    Calculate RNA stability using ViennaRNA's minimum free energy (MFE).
    Directly uses MFE without length normalization - stable structures naturally have lower MFE.

    The harshness parameter amplifies stability differences:
    - harshness > 1.0: More extreme environment, stability differences magnified
    - harshness = 1.0: Normal environment
    - harshness < 1.0: Mild environment, stability differences reduced

    Args:
        sequence: RNA sequence string (A/U/G/C)
        harshness: Environmental harshness factor (amplifies stability differences)

    Returns:
        stability: normalized score 0-1 (higher = more stable)
        structure: dot-bracket secondary structure
        mfe: minimum free energy in kcal/mol
    """
    if len(sequence) < 4:
        return 0.2, "", 0

    try:
        fc = RNA.fold_compound(sequence)
        (ss, mfe) = fc.mfe()

        # Direct MFE usage - no length normalization!
        # MFE range: 0 to -50 kcal/mol (more negative = more stable)
        # Map to 0-1: -50 -> 1.0, 0 -> 0.0
        raw_stability = -mfe / 50.0
        stability = min(0.95, max(0.05, raw_stability))

        # Apply harshness: amplify the difference from baseline (0.5)
        # This makes stable sequences more stable, unstable ones more unstable
        if harshness != 1.0:
            # Center around 0.5, then stretch
            deviation = stability - 0.5
            stability = 0.5 + deviation * harshness
            stability = min(0.95, max(0.05, stability))

        return stability, ss, mfe

    except Exception as e:
        return calculate_stability_heuristic(sequence, harshness), "", 0


def calculate_stability_heuristic(sequence, harshness=1.0):
    """
    Heuristic stability calculation based on structural formation capability.
    Focuses on complementarity and stem-loop potential, not GC content bias.

    Args:
        sequence: RNA sequence string
        harshness: Environmental harshness factor

    Returns:
        stability: normalized score 0-1
    """
    if len(sequence) < 4:
        return 0.2

    comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}

    # 1. Self-complementarity detection (most important for stable folding)
    half_len = len(sequence) // 2
    complement_score = 0
    if half_len >= 1:
        first_half = sequence[:half_len]
        second_half_rev = sequence[half_len:][::-1]

        matches = 0
        for i in range(min(len(first_half), len(second_half_rev))):
            if comp_map.get(first_half[i], '') == second_half_rev[i]:
                matches += 1
        complement_score = matches / max(1, half_len)

    # 2. Local structure formation (ability to form hairpins and stems)
    structural_score = 0
    for i in range(len(sequence) - 3):
        for length in range(3, min(8, (len(sequence) - i) // 2)):
            left = sequence[i:i+length]
            right = sequence[i+length:i+2*length][::-1]

            if len(right) >= length:
                matches = 0
                for k in range(length):
                    if comp_map.get(left[k], '') == right[k]:
                        matches += 1
                pair_rate = matches / length
                if pair_rate > structural_score:
                    structural_score = pair_rate

    # 3. Base composition (reduced weight - structure matters more)
    gc_ratio = (sequence.count('G') + sequence.count('C')) / len(sequence)

    # 4. Stability = structural capability dominates
    # AU-rich sequences can be stable if they form good structures!
    stability = 0.1 + 0.5 * complement_score + 0.3 * structural_score + 0.1 * gc_ratio

    # 5. Long sequences with good structure get recognition
    if len(sequence) > 30 and structural_score > 0.5:
        stability = min(0.95, stability + 0.1)

    # Apply harshness: amplify stability differences
    if harshness != 1.0:
        deviation = stability - 0.5
        stability = 0.5 + deviation * harshness
        stability = min(0.95, max(0.05, stability))

    return stability


# Global variables for stability calculation
USE_VIENNA_GLOBAL = VIENNA_AVAILABLE
HARSHNESS_GLOBAL = 1.0

def get_stability(sequence):
    """
    Unified stability calculation interface.
    Uses global settings for ViennaRNA and harshness.

    Args:
        sequence: RNA sequence string

    Returns:
        stability: normalized score 0-1
    """
    if USE_VIENNA_GLOBAL and VIENNA_AVAILABLE and len(sequence) >= 4:
        stability, _, _ = calculate_stability_vienna(sequence, HARSHNESS_GLOBAL)
        return stability
    else:
        return calculate_stability_heuristic(sequence, HARSHNESS_GLOBAL)

# ============================================================================
# Part 2: Main Simulation Class
# ============================================================================

class StabilityDistillationSimulation:
    """
    Simulates the stability-distillation process for RNA sequence evolution.

    Key mechanisms:
    - Wet phase: Unstable sequences degrade (probability = 1 - stability^harshness)
    - Dry phase: Stable sequences serve as building blocks for ligation
    - Nucleotide supplementation: Periodic addition of monomers
    - Harshness: Environmental stress amplifies stability differences
    """

    def __init__(self,
                 initial_seq_length=6,
                 num_initial_sequences=200,
                 max_seq_length=150,
                 dry_growth_factor=1.3,
                 wet_degradation_strength=1.0,
                 ligation_base_prob=0.05,
                 supplementation_fraction=0.02,
                 initial_nucleotide_pool=1000,
                 harshness=1.0):
        """
        Initialize the simulation.

        Args:
            initial_seq_length: Length of randomly generated starting sequences
            num_initial_sequences: Number of initial sequences to generate
            max_seq_length: Maximum allowed sequence length (prevents unbounded growth)
            dry_growth_factor: Multiplication factor for copy numbers during dry phase
            wet_degradation_strength: Exponent controlling degradation strength (higher = more degradation)
            ligation_base_prob: Base probability for sequence ligation events
            supplementation_fraction: Fraction of INITIAL nucleotide pool to add as monomers each cycle
            initial_nucleotide_pool: Total number of ribonucleotide monomers available at start
            harshness: Environmental harshness factor (amplifies stability differences)
                      Higher values = more extreme conditions (hot, acidic)
                      Typical range: 0.5 (mild) to 2.0 (extreme)
        """
        self.max_seq_length = max_seq_length
        self.dry_growth_factor = dry_growth_factor
        self.wet_degradation_strength = wet_degradation_strength
        self.ligation_base_prob = ligation_base_prob
        self.supplementation_fraction = supplementation_fraction
        self.initial_nucleotide_pool = initial_nucleotide_pool
        self.harshness = harshness

        # Update global harshness for stability calculations
        global HARSHNESS_GLOBAL
        HARSHNESS_GLOBAL = harshness

        # Available nucleotides
        self.nucleotides = ['A', 'U', 'G', 'C']

        # Initialize sequence pool: generate random short sequences
        self.sequences = []
        for _ in range(num_initial_sequences):
            seq = ''.join(random.choice(self.nucleotides)
                         for _ in range(initial_seq_length))
            self.sequences.append(seq)

        # Frequency dictionary: sequence -> copy count
        self.frequencies = defaultdict(int)
        for seq in self.sequences:
            self.frequencies[seq] += 1

        # Add initial monomer pool
        for _ in range(initial_nucleotide_pool):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        # Track the current longest sequence for each cycle
        self.current_longest_sequence = ""

        # History tracking for visualization
        self.history = {
            'entropy': [],
            'num_unique_sequences': [],
            'avg_length': [],
            'total_copies': [],
            'max_length': [],
            'longest_sequence': [],
            'top_sequences': [],
            'trna_candidates': []
        }

        print(f"Simulation initialized")
        print(f"  Initial sequence count: {len(self.sequences)}")
        print(f"  Unique sequences: {len(self.frequencies)}")
        print(f"  Initial nucleotide pool: {self.initial_nucleotide_pool}")
        print(f"  ViennaRNA available: {VIENNA_AVAILABLE}")
        print(f"  Environmental harshness: {self.harshness}")
        print(f"  Supplementation fraction: {self.supplementation_fraction * 100:.1f}% of initial pool per cycle")
        print(f"  Ligation base probability: {self.ligation_base_prob}")

    def calculate_entropy(self):
        """
        Calculate Shannon entropy of the current sequence distribution.
        Lower entropy = more concentrated distribution = more information.

        Returns:
            entropy: Shannon entropy in bits
        """
        total = sum(self.frequencies.values())
        if total == 0:
            return 0
        entropy = 0
        for count in self.frequencies.values():
            p = count / total
            if p > 0:
                entropy -= p * np.log2(p)
        return entropy

    def get_longest_sequence(self):
        """
        Find the current longest RNA sequence in the pool.

        Returns:
            longest_seq: The longest sequence string
            max_len: Length of the longest sequence
        """
        if not self.frequencies:
            return "", 0

        # Filter out monomers (length 1) when looking for longest
        sequences_only = [seq for seq in self.frequencies.keys() if len(seq) > 1]
        if not sequences_only:
            return "", 0

        longest_seq = max(sequences_only, key=len)
        return longest_seq, len(longest_seq)

    def add_nucleotide_supplementation(self):
        """
        Add fresh ribonucleotide monomers to the pool.
        This simulates continuous input from the geothermal environment.

        The supplementation is added as monomers, which can be used
        during the dry phase to form new RNA sequences.

        Supplementation is anchored to the INITIAL nucleotide pool size,
        providing consistent input regardless of population fluctuations.
        """
        if self.supplementation_fraction <= 0:
            return 0

        # Calculate monomers to add based on INITIAL pool size
        num_monomers = max(1, int(self.initial_nucleotide_pool * self.supplementation_fraction))

        # Add monomers with balanced composition
        for _ in range(num_monomers):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        return num_monomers

    def is_trna_like(self, sequence):
        """
        Detect whether a sequence has tRNA-like structural potential.

        tRNA characteristics:
        - Can form cloverleaf structure with 3 or more stem-loop regions
        - Self-complementary regions allow stable folding
        - Typically 70-90 nucleotides in length

        Simplified detection: Look for 3 or more independent stem-loop regions
        where each stem has >=60% base pairing.

        Args:
            sequence: RNA sequence string

        Returns:
            True if the sequence exhibits tRNA-like characteristics
        """
        if len(sequence) < 30:
            return False

        # Base complementarity mapping
        comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}
        stem_regions = []

        # Sliding window to detect potential stem-loop structures
        for i in range(len(sequence) - 4):
            for length in range(3, min(8, (len(sequence) - i) // 2)):
                left = sequence[i:i+length]
                right = sequence[i+length:i+2*length][::-1]

                # Calculate pairing rate for this potential stem
                matches = 0
                for j in range(length):
                    if j < len(left) and j < len(right):
                        if comp_map.get(left[j], '') == right[j]:
                            matches += 1

                pairing_rate = matches / length if length > 0 else 0
                if pairing_rate >= 0.6:  # 60% or more base pairing
                    stem_regions.append((i, i+2*length, pairing_rate))

        # Merge overlapping regions
        merged = []
        for region in sorted(stem_regions, key=lambda x: x[0]):
            if not merged or region[0] > merged[-1][1] + 5:
                merged.append(region)

        # tRNA-like structures need at least 3 independent stem-loop regions
        return len(merged) >= 3

    def wet_phase(self):
        """
        Wet phase: Unstable sequences degrade.

        Degradation probability depends on:
        1. Sequence stability (higher stability = lower degradation)
        2. Environmental harshness (amplifies stability differences)
        3. Degradation strength parameter

        In harsh environments (high temperature, acidic), the difference
        between stable and unstable sequences is magnified.
        """
        new_frequencies = defaultdict(int)

        for seq, count in self.frequencies.items():
            stability = get_stability(seq)

            # Survival probability increases with stability
            # Harshness amplifies the difference:
            # - Stable sequences become MORE likely to survive
            # - Unstable sequences become LESS likely to survive
            survival_prob = stability ** (self.wet_degradation_strength * self.harshness)
            survived = np.random.binomial(count, survival_prob)

            if survived > 0:
                new_frequencies[seq] = survived

        self.frequencies = new_frequencies

        # If everything went extinct, reintroduce some random sequences
        if len(self.frequencies) == 0:
            for _ in range(50):
                seq = ''.join(random.choice(self.nucleotides)
                             for _ in range(6))
                self.frequencies[seq] += 1

    def dry_phase(self):
        """
        Dry phase: Sequence ligation and growth.

        Key mechanism from the stability-distillation hypothesis:
        - Frequent sequences are more likely to collide and ligate
        - Ligation probability ∝ frequency(a) × frequency(b)
        - This allows stable short sequences to serve as "stepping stones"
          for building longer, potentially more stable sequences.
        """
        total = sum(self.frequencies.values())
        if total == 0:
            return

        # Calculate frequency ratio for each sequence
        freq_ratio = {seq: count/total for seq, count in self.frequencies.items()}

        # Generate new sequences via ligation
        new_sequences = []
        seq_list = list(self.frequencies.keys())

        # Generate approximately 30% of current population as new ligation products
        num_ligations = int(total * 0.3)

        for _ in range(num_ligations):
            if len(seq_list) < 2:
                break

            # Weighted selection based on frequency
            weights = [freq_ratio.get(seq, 0) for seq in seq_list]
            if sum(weights) == 0:
                break

            # Select two sequences to ligate, weighted by their frequencies
            a = np.random.choice(seq_list, p=weights)
            b = np.random.choice(seq_list, p=weights)

            # Ligation probability is proportional to the product of their frequencies
            # This captures the "collision probability" concept
            p_ligate = self.ligation_base_prob * (freq_ratio[a] * freq_ratio[b] * 100)
            p_ligate = min(0.8, p_ligate)

            if random.random() < p_ligate:
                new_seq = a + b
                if len(new_seq) <= self.max_seq_length:
                    new_sequences.append(new_seq)

        # Add newly ligated sequences to the pool
        for seq in new_sequences:
            self.frequencies[seq] += 1

        # All sequences grow during dry phase (general polymerization)
        for seq in list(self.frequencies.keys()):
            growth = np.random.poisson(self.dry_growth_factor - 1)
            if growth > 0:
                self.frequencies[seq] += growth

    def step(self, cycle_number):
        """
        Execute one complete wet-dry cycle.

        Order:
        1. Wet phase: Degradation of unstable sequences
        2. Add fresh nucleotide supplementation (simulating geothermal input)
        3. Dry phase: Ligation and growth

        Args:
            cycle_number: Current cycle number (for logging)
        """
        # Step 1: Wet phase - degradation
        self.wet_phase()

        # Step 2: Add fresh nucleotide supplementation
        monomers_added = self.add_nucleotide_supplementation()

        # Step 3: Dry phase - ligation and growth
        self.dry_phase()

        # Track current longest sequence
        longest_seq, max_len = self.get_longest_sequence()
        self.current_longest_sequence = longest_seq

        # Print current longest sequence
        if longest_seq:
            display_seq = longest_seq[:50] + '...' if len(longest_seq) > 50 else longest_seq
            print(f"  Cycle {cycle_number:3d}: Longest RNA = {display_seq} (length={max_len})")

        return monomers_added

    def run(self, num_cycles=50, record_interval=5):
        """
        Run the simulation for a specified number of cycles.

        Args:
            num_cycles: Number of wet-dry cycles to simulate
            record_interval: How often to record statistics (cycles between records)
        """
        print(f"\nStarting simulation: {num_cycles} wet-dry cycles...")
        print("-" * 70)

        for cycle in range(num_cycles):
            monomers_added = self.step(cycle)

            # Record statistics at specified intervals
            if cycle % record_interval == 0 or cycle == num_cycles - 1:
                entropy = self.calculate_entropy()
                num_unique = len(self.frequencies)
                total = sum(self.frequencies.values())

                # Calculate average sequence length (excluding monomers)
                seq_lengths = [len(seq) for seq in self.frequencies.keys() if len(seq) > 1]
                avg_len = np.mean(seq_lengths) if seq_lengths else 0

                # Get current max length
                _, max_len = self.get_longest_sequence()

                # Get top 5 sequences by frequency
                top_seqs = Counter(self.frequencies).most_common(5)

                # Detect tRNA-like candidates
                trna_candidates = []
                for seq in list(self.frequencies.keys())[:50]:
                    if self.is_trna_like(seq) and self.frequencies[seq] > 1:
                        trna_candidates.append(seq)

                # Store history
                self.history['entropy'].append(entropy)
                self.history['num_unique_sequences'].append(num_unique)
                self.history['avg_length'].append(avg_len)
                self.history['total_copies'].append(total)
                self.history['max_length'].append(max_len)
                self.history['longest_sequence'].append(self.current_longest_sequence)
                self.history['top_sequences'].append(top_seqs)
                self.history['trna_candidates'].append(trna_candidates)

                print(f"  [Record] Cycle {cycle:3d}: Entropy={entropy:.3f} | Unique={num_unique:4d} | "
                      f"Total copies={total:6d} | Avg len={avg_len:.1f} | Max len={max_len} | "
                      f"tRNA candidates={len(trna_candidates)}")
                print()

        print("-" * 70)
        print("Simulation complete!")

    def plot_results(self):
        """
        Generate visualization plots showing key metrics over time.
        """
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # Generate x-axis values
        cycles = np.arange(len(self.history['entropy']))
        # Scale to approximate actual cycle numbers (if record_interval was 5)
        cycles_scaled = cycles * 5
        if len(cycles_scaled) < len(self.history['entropy']):
            cycles_scaled = cycles

        # Plot 1: Shannon entropy
        ax1 = axes[0, 0]
        ax1.plot(cycles_scaled, self.history['entropy'], 'b-o', linewidth=2, markersize=4)
        ax1.set_xlabel('Wet-dry cycles')
        ax1.set_ylabel('Shannon entropy (bits)')
        ax1.set_title('Entropy Decrease = Information Accumulation')
        ax1.grid(True, alpha=0.3)

        # Plot 2: Number of unique sequences
        ax2 = axes[0, 1]
        ax2.plot(cycles_scaled, self.history['num_unique_sequences'], 'r-s', linewidth=2, markersize=4)
        ax2.set_xlabel('Wet-dry cycles')
        ax2.set_ylabel('Number of unique sequences')
        ax2.set_title('Sequence Diversity')
        ax2.grid(True, alpha=0.3)

        # Plot 3: Total copy number
        ax3 = axes[0, 2]
        ax3.plot(cycles_scaled, self.history['total_copies'], 'g-^', linewidth=2, markersize=4)
        ax3.set_xlabel('Wet-dry cycles')
        ax3.set_ylabel('Total copy number')
        ax3.set_title(f'Total RNA Copies (Supp: {self.supplementation_fraction*100:.1f}%/cycle)')
        ax3.grid(True, alpha=0.3)

        # Plot 4: Maximum sequence length
        ax4 = axes[1, 0]
        ax4.plot(cycles_scaled, self.history['max_length'], 'c-d', linewidth=2, markersize=4)
        ax4.set_xlabel('Wet-dry cycles')
        ax4.set_ylabel('Maximum sequence length (nt)')
        ax4.set_title('Maximum Length Growth = Distillation Effect')
        ax4.grid(True, alpha=0.3)

        # Plot 5: Number of tRNA-like candidates
        ax5 = axes[1, 1]
        trna_counts = [len(t) for t in self.history['trna_candidates']]
        ax5.bar(cycles_scaled, trna_counts, color='purple', alpha=0.7)
        ax5.set_xlabel('Wet-dry cycles')
        ax5.set_ylabel('Number of tRNA-like candidates')
        ax5.set_title('Emergence of tRNA-like Structures')
        ax5.grid(True, alpha=0.3)

        # Plot 6: Entropy vs Total copies (phase space)
        ax6 = axes[1, 2]
        ax6.scatter(self.history['total_copies'], self.history['entropy'],
                   c=cycles_scaled, cmap='viridis', s=50, alpha=0.7)
        ax6.set_xlabel('Total copy number')
        ax6.set_ylabel('Shannon entropy')
        ax6.set_title('Phase Space: Entropy vs. Population Size')
        ax6.grid(True, alpha=0.3)
        cbar = plt.colorbar(ax6.collections[0], ax=ax6)
        cbar.set_label('Cycle number')

        plt.tight_layout()
        plt.savefig('stability_distillation_results.png', dpi=150)
        plt.show()

    def print_top_sequences(self, n=15):
        """
        Print the most frequent sequences with their stability scores.

        Args:
            n: Number of top sequences to display
        """
        print("\n" + "=" * 80)
        print(f"Top {n} Most Frequent Sequences")
        print("=" * 80)

        # Filter out monomers for top sequences display
        sequences_only = {seq: count for seq, count in self.frequencies.items() if len(seq) > 1}
        if not sequences_only:
            print("  No sequences longer than 1 nt found.")
            return

        top = Counter(sequences_only).most_common(n)
        for i, (seq, count) in enumerate(top, 1):
            stability = get_stability(seq)
            trna_flag = "★ tRNA-like" if self.is_trna_like(seq) else ""
            display_seq = seq[:50] + '...' if len(seq) > 50 else seq
            print(f"{i:2d}. [{count:5d}] {display_seq:55s} "
                  f"(stability={stability:.3f}) {trna_flag}")

        # Display all discovered tRNA-like sequences
        all_trna = [seq for seq in self.frequencies.keys() if self.is_trna_like(seq)]
        if all_trna:
            print("\n" + "=" * 80)
            print(f"Discovered tRNA-like Structures ({len(all_trna)} sequences)")
            print("=" * 80)
            for seq in all_trna[:5]:
                stability = get_stability(seq)
                print(f"\n  Sequence: {seq[:70]}")
                print(f"  Length: {len(seq)} nt, Stability: {stability:.3f}")

                # Show predicted secondary structure if ViennaRNA is available
                if VIENNA_AVAILABLE and len(seq) <= 100:
                    try:
                        fc = RNA.fold_compound(seq)
                        (ss, mfe) = fc.mfe()
                        print(f"  Predicted structure: {ss[:70]}")
                        print(f"  Minimum free energy: {mfe:.1f} kcal/mol")
                    except:
                        pass
            if len(all_trna) > 5:
                print(f"\n  ... and {len(all_trna) - 5} more")

        print()

# ============================================================================
# Part 3: Main Program with Configurable Parameters
# ============================================================================

def run_demo(stability_method='vienna',
             initial_nucleotide_pool=1000,
             num_cycles=50,
             supplementation_fraction=0.02,
             ligation_prob=0.05,
             harshness=1.0):
    """
    Run the stability-distillation simulation demo.

    Args:
        stability_method: Method for stability calculation
                         'vienna' - use ViennaRNA (requires installation)
                         'heuristic' - use built-in heuristic function
        initial_nucleotide_pool: Total number of ribonucleotide monomers at start
        num_cycles: Number of wet-dry cycles to simulate
        supplementation_fraction: Fraction of INITIAL pool to add as monomers each cycle
        ligation_prob: Base probability for sequence ligation during dry phase
                      Higher values = more frequent ligation events
        harshness: Environmental harshness factor (amplifies stability differences)
                  Higher values = more extreme conditions (hot, acidic)
                  Range: 0.5 (mild) to 2.0 (extreme), default: 1.0
    """
    global USE_VIENNA_GLOBAL, HARSHNESS_GLOBAL

    print("=" * 80)
    print("     Stability-Distillation Hypothesis Simulation")
    print("     Simulating wet-dry cycles driving RNA sequence convergence")
    print("=" * 80)

    # Display configuration
    print(f"\nConfiguration:")
    print(f"  Stability calculation method: {stability_method.upper()}")
    print(f"  Initial nucleotide pool: {initial_nucleotide_pool} monomers")
    print(f"  Number of cycles: {num_cycles}")
    print(f"  Supplementation fraction: {supplementation_fraction * 100:.1f}% of initial pool per cycle")
    print(f"  Ligation probability (base): {ligation_prob}")
    print(f"  Environmental harshness: {harshness}")
    print(f"    (Higher = more extreme conditions, stability differences amplified)")

    # Determine which stability method to use
    if stability_method.lower() == 'vienna':
        if VIENNA_AVAILABLE:
            USE_VIENNA_GLOBAL = True
            print(f"\n  ✓ Using ViennaRNA for stability calculations")
        else:
            USE_VIENNA_GLOBAL = False
            print(f"\n  ✗ ViennaRNA requested but not available!")
            print(f"    Falling back to heuristic method.")
            print(f"    Install with: !pip install viennarna")
    else:
        USE_VIENNA_GLOBAL = False
        print(f"\n  Using heuristic stability calculation")

    HARSHNESS_GLOBAL = harshness
    print()

    # Create simulator with parameters
    sim = StabilityDistillationSimulation(
        initial_seq_length=6,
        num_initial_sequences=200,
        max_seq_length=150,
        dry_growth_factor=1.3,
        wet_degradation_strength=1.0,
        ligation_base_prob=ligation_prob,
        supplementation_fraction=supplementation_fraction,
        initial_nucleotide_pool=initial_nucleotide_pool,
        harshness=harshness
    )

    # Run simulation
    sim.run(num_cycles=num_cycles, record_interval=5)

    # Visualize results
    sim.plot_results()

    # Print top sequences
    sim.print_top_sequences(n=15)

    # Summary statistics
    print("\n" + "=" * 80)
    print("Simulation Summary")
    print("=" * 80)

    # Filter out monomers for summary
    sequences_only = {seq: count for seq, count in sim.frequencies.items() if len(seq) > 1}

    print(f"Final unique sequences (length>1): {len(sequences_only)}")
    print(f"Final total copies (all): {sum(sim.frequencies.values())}")
    print(f"Final entropy: {sim.calculate_entropy():.3f} bits")

    if sequences_only:
        seq_lengths = [len(s) for s in sequences_only.keys()]
        print(f"Sequence length range: {min(seq_lengths)} - {max(seq_lengths)} nt")
        print(f"Average sequence length: {np.mean(seq_lengths):.1f} nt")

    # Check if we achieved significant convergence
    if sim.history['entropy']:
        initial_entropy = sim.history['entropy'][0]
        final_entropy = sim.history['entropy'][-1]
        entropy_reduction = initial_entropy - final_entropy
        print(f"\nEntropy reduction: {entropy_reduction:.2f} bits (from {initial_entropy:.2f} to {final_entropy:.2f})")

        if entropy_reduction > 2:
            print("  ✓ Significant information accumulation observed!")
        elif entropy_reduction > 1:
            print("  ~ Moderate information accumulation observed.")
        else:
            print("  ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.")

    # Show longest sequence found
    longest_seq, max_len = sim.get_longest_sequence()
    if longest_seq:
        display_seq = longest_seq[:80] + '...' if len(longest_seq) > 80 else longest_seq
        print(f"\nLongest sequence discovered: {display_seq}")
        print(f"  Length: {max_len} nt")

    # Show tRNA-like sequences found
    trna_found = [seq for seq in sim.frequencies.keys() if sim.is_trna_like(seq)]
    if trna_found:
        print(f"\n★ tRNA-like sequences found: {len(trna_found)}")
        for seq in trna_found[:3]:
            print(f"    - {seq[:60]}... (len={len(seq)})")

# ============================================================================
# Run with different configurations
# ============================================================================
# Out:
# ✓ ViennaRNA loaded successfully

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1000
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 50
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.05
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #    - Higher harshness = faster selection but may lose diversity
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'heuristic'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 300                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.001          # 2% of initial pool per cycle
    LIGATION_PROB = 0.1                     # Base ligation probability
    HARSHNESS = 0.2                          # Environmental harshness
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Configuration:
#   Stability calculation method: HEURISTIC
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 300
#   Supplementation fraction: 0.1% of initial pool per cycle
#   Ligation probability (base): 0.1
#   Environmental harshness: 0.2
#     (Higher = more extreme conditions, stability differences amplified)
#
#   Using heuristic stability calculation
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 200
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.2
#   Supplementation fraction: 0.1% of initial pool per cycle
#   Ligation base probability: 0.1
#
# Starting simulation: 300 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = AUAAUA (length=6)
#   [Record] Cycle   0: Entropy=3.181 | Unique= 193 | Total copies=  8710 | Avg len=5.7 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = AUAAUA (length=6)
#   Cycle   2: Longest RNA = AGGGAG (length=6)
#   Cycle   3: Longest RNA = GAAAACG (length=7)
#   Cycle   4: Longest RNA = GCAAUAUG (length=8)
#   Cycle   5: Longest RNA = GCAAUAUG (length=8)
#   [Record] Cycle   5: Entropy=4.534 | Unique= 164 | Total copies=  2647 | Avg len=5.1 | Max len=8 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = GCAAUAUG (length=8)
#   Cycle   7: Longest RNA = GCAAUAUG (length=8)
#   Cycle   8: Longest RNA = GCAAUAUG (length=8)
#   Cycle   9: Longest RNA = GCAAUAUG (length=8)
#   Cycle  10: Longest RNA = UAGGUUG (length=7)
#   [Record] Cycle  10: Entropy=5.528 | Unique= 136 | Total copies=   817 | Avg len=5.1 | Max len=7 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = UAGGUUG (length=7)
#   Cycle  12: Longest RNA = UAGGUUG (length=7)
#   Cycle  13: Longest RNA = UAGGUUG (length=7)
#   Cycle  14: Longest RNA = UAGGUUG (length=7)
#   Cycle  15: Longest RNA = UAGGUUG (length=7)
#   [Record] Cycle  15: Entropy=6.145 | Unique= 111 | Total copies=   403 | Avg len=5.1 | Max len=7 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = UAGGUUG (length=7)
#   Cycle  17: Longest RNA = UAGGUUG (length=7)
#   Cycle  18: Longest RNA = UAGGUUG (length=7)
#   Cycle  19: Longest RNA = CGGGCUGUACAU (length=12)
#   Cycle  20: Longest RNA = CGGGCUGUACAU (length=12)
#   [Record] Cycle  20: Entropy=6.006 | Unique=  87 | Total copies=   269 | Avg len=5.4 | Max len=12 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = CGGGCUGUACAU (length=12)
#   Cycle  22: Longest RNA = CGGGCUGUACAU (length=12)
#   Cycle  23: Longest RNA = CGGGCUGUACAU (length=12)
#   Cycle  24: Longest RNA = CGGGCUGUACAU (length=12)
#   Cycle  25: Longest RNA = UAGGUUG (length=7)
#   [Record] Cycle  25: Entropy=5.590 | Unique=  60 | Total copies=   189 | Avg len=5.7 | Max len=7 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = UAGGUUG (length=7)
#   Cycle  27: Longest RNA = UAGGUUG (length=7)
#   Cycle  28: Longest RNA = UAGGUUG (length=7)
#   Cycle  29: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  30: Longest RNA = UCUGUGCCUUCC (length=12)
#   [Record] Cycle  30: Entropy=5.383 | Unique=  52 | Total copies=   149 | Avg len=6.0 | Max len=12 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  32: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  33: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  34: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  35: Longest RNA = UCUGUGCCUUCC (length=12)
#   [Record] Cycle  35: Entropy=5.051 | Unique=  43 | Total copies=   120 | Avg len=6.3 | Max len=12 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  37: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  38: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  39: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  40: Longest RNA = UCUGUGCCUUCC (length=12)
#   [Record] Cycle  40: Entropy=4.811 | Unique=  35 | Total copies=    99 | Avg len=6.6 | Max len=12 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  42: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  43: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  44: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  45: Longest RNA = UCUGUGCCUUCC (length=12)
#   [Record] Cycle  45: Entropy=4.585 | Unique=  32 | Total copies=   115 | Avg len=6.8 | Max len=12 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = UCUGUGCCUUCCU (length=13)
#   Cycle  47: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  48: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  49: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  50: Longest RNA = UCUGUGCCUUCC (length=12)
#   [Record] Cycle  50: Entropy=4.259 | Unique=  29 | Total copies=   106 | Avg len=6.8 | Max len=12 | tRNA candidates=0
#
#   Cycle  51: Longest RNA = UCUGUGCCUUCC (length=12)
#   Cycle  52: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  53: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  54: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  55: Longest RNA = UAAUUGAGUUCAC (length=13)
#   [Record] Cycle  55: Entropy=4.492 | Unique=  30 | Total copies=   111 | Avg len=7.2 | Max len=13 | tRNA candidates=0
#
#   Cycle  56: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  57: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  58: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  59: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  60: Longest RNA = UAAUUGAGUUCAC (length=13)
#   [Record] Cycle  60: Entropy=4.441 | Unique=  29 | Total copies=    98 | Avg len=6.3 | Max len=13 | tRNA candidates=0
#
#   Cycle  61: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  62: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  63: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  64: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  65: Longest RNA = UAAUUGAGUUCAC (length=13)
#   [Record] Cycle  65: Entropy=4.339 | Unique=  29 | Total copies=    94 | Avg len=6.3 | Max len=13 | tRNA candidates=0
#
#   Cycle  66: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  67: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  68: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  69: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  70: Longest RNA = UAAUUGAGUUCAC (length=13)
#   [Record] Cycle  70: Entropy=4.068 | Unique=  22 | Total copies=    72 | Avg len=6.8 | Max len=13 | tRNA candidates=0
#
#   Cycle  71: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  72: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  73: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  74: Longest RNA = UAAUUGAGUUCAC (length=13)
#   Cycle  75: Longest RNA = UAAUUGAGUUCAC (length=13)
#   [Record] Cycle  75: Entropy=4.325 | Unique=  24 | Total copies=    73 | Avg len=6.8 | Max len=13 | tRNA candidates=0
#
#   Cycle  76: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   Cycle  77: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   Cycle  78: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  79: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   Cycle  80: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   [Record] Cycle  80: Entropy=4.239 | Unique=  24 | Total copies=    95 | Avg len=7.8 | Max len=14 | tRNA candidates=0
#
#   Cycle  81: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   Cycle  82: Longest RNA = CGCUGCAAAAUUGA (length=14)
#   Cycle  83: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  84: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  85: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   [Record] Cycle  85: Entropy=4.047 | Unique=  26 | Total copies=    93 | Avg len=7.7 | Max len=15 | tRNA candidates=0
#
#   Cycle  86: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  87: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  88: Longest RNA = CGCUGCAAAAUUGAG (length=15)
#   Cycle  89: Longest RNA = CGCUGCAAAAUUGAUC (length=16)
#   Cycle  90: Longest RNA = CCGCUGCAAAAUUGAUC (length=17)
#   [Record] Cycle  90: Entropy=4.022 | Unique=  24 | Total copies=    86 | Avg len=8.6 | Max len=17 | tRNA candidates=0
#
#   Cycle  91: Longest RNA = CCGCUGCAAAAUUGAUC (length=17)
#   Cycle  92: Longest RNA = CCGCUGCAAAAUUGAUC (length=17)
#   Cycle  93: Longest RNA = CGCUGCAAAAUUGAUC (length=16)
#   Cycle  94: Longest RNA = CGCUGCAAAAUUGAUC (length=16)
#   Cycle  95: Longest RNA = CGCUGCAAAAUUGAUC (length=16)
#   [Record] Cycle  95: Entropy=4.095 | Unique=  23 | Total copies=    88 | Avg len=7.9 | Max len=16 | tRNA candidates=0
#
#   Cycle  96: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   Cycle  97: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   Cycle  98: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   Cycle  99: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   Cycle 100: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   [Record] Cycle 100: Entropy=4.157 | Unique=  27 | Total copies=    83 | Avg len=9.9 | Max len=28 | tRNA candidates=0
#
#   Cycle 101: Longest RNA = CGGUUCACGUUCACCGGUUCACGUUCAC (length=28)
#   Cycle 102: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   Cycle 103: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   Cycle 104: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   Cycle 105: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   [Record] Cycle 105: Entropy=4.263 | Unique=  26 | Total copies=    92 | Avg len=8.4 | Max len=21 | tRNA candidates=0
#
#   Cycle 106: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   Cycle 107: Longest RNA = CUGAGCGCUGCAAAAUUGAUC (length=21)
#   Cycle 108: Longest RNA = CGCUGCAAAAUUGAUCC (length=17)
#   Cycle 109: Longest RNA = CGCUGCAAAAUUGAUCC (length=17)
#   Cycle 110: Longest RNA = GGUUCACGUUCACCUGAG (length=18)
#   [Record] Cycle 110: Entropy=4.122 | Unique=  25 | Total copies=    86 | Avg len=8.7 | Max len=18 | tRNA candidates=0
#
#   Cycle 111: Longest RNA = GGUUCACGUUCACCUGAG (length=18)
#   Cycle 112: Longest RNA = GGUUCACGUUCACCUGAG (length=18)
#   Cycle 113: Longest RNA = GGUUCACGUUCACCUGAG (length=18)
#   Cycle 114: Longest RNA = GGUUCACGUUCACCUGAG (length=18)
#   Cycle 115: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   [Record] Cycle 115: Entropy=4.107 | Unique=  23 | Total copies=    86 | Avg len=10.7 | Max len=19 | tRNA candidates=0
#
#   Cycle 116: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 117: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 118: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 119: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 120: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   [Record] Cycle 120: Entropy=3.971 | Unique=  24 | Total copies=    83 | Avg len=8.1 | Max len=19 | tRNA candidates=0
#
#   Cycle 121: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 122: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 123: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 124: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   Cycle 125: Longest RNA = UGGUUCACGUUCACCUGAG (length=19)
#   [Record] Cycle 125: Entropy=4.138 | Unique=  24 | Total copies=    91 | Avg len=8.0 | Max len=19 | tRNA candidates=0
#
#   Cycle 126: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 127: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 128: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 129: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 130: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 130: Entropy=3.921 | Unique=  21 | Total copies=    71 | Avg len=13.4 | Max len=36 | tRNA candidates=0
#
#   Cycle 131: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 132: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 133: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 134: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 135: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 135: Entropy=3.691 | Unique=  19 | Total copies=    68 | Avg len=11.8 | Max len=36 | tRNA candidates=0
#
#   Cycle 136: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 137: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 138: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 139: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 140: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 140: Entropy=3.912 | Unique=  20 | Total copies=    81 | Avg len=9.7 | Max len=36 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 142: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 143: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 144: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 145: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 145: Entropy=3.842 | Unique=  22 | Total copies=    88 | Avg len=11.1 | Max len=36 | tRNA candidates=0
#
#   Cycle 146: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 147: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 148: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 149: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 150: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 150: Entropy=4.003 | Unique=  23 | Total copies=    76 | Avg len=11.5 | Max len=36 | tRNA candidates=0
#
#   Cycle 151: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 152: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 153: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 154: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 155: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 155: Entropy=4.001 | Unique=  21 | Total copies=    82 | Avg len=11.5 | Max len=36 | tRNA candidates=0
#
#   Cycle 156: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 157: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 158: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 159: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 160: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 160: Entropy=4.055 | Unique=  23 | Total copies=    90 | Avg len=11.1 | Max len=36 | tRNA candidates=0
#
#   Cycle 161: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 162: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 163: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 164: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 165: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   [Record] Cycle 165: Entropy=4.117 | Unique=  23 | Total copies=    82 | Avg len=11.4 | Max len=36 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 167: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 168: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 169: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCC (length=36)
#   Cycle 170: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 170: Entropy=3.910 | Unique=  19 | Total copies=    83 | Avg len=13.9 | Max len=46 | tRNA candidates=1
#
#   Cycle 171: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 172: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 173: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 174: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 175: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 175: Entropy=3.855 | Unique=  20 | Total copies=    87 | Avg len=15.2 | Max len=46 | tRNA candidates=1
#
#   Cycle 176: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 177: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 178: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 179: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 180: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 180: Entropy=3.864 | Unique=  21 | Total copies=    70 | Avg len=14.2 | Max len=46 | tRNA candidates=1
#
#   Cycle 181: Longest RNA = UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=47)
#   Cycle 182: Longest RNA = UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=47)
#   Cycle 183: Longest RNA = UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=47)
#   Cycle 184: Longest RNA = UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=47)
#   Cycle 185: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 185: Entropy=4.108 | Unique=  24 | Total copies=    84 | Avg len=15.0 | Max len=46 | tRNA candidates=1
#
#   Cycle 186: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 187: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 188: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 189: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 190: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 190: Entropy=3.670 | Unique=  19 | Total copies=    73 | Avg len=15.3 | Max len=46 | tRNA candidates=0
#
#   Cycle 191: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 192: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 193: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGGUUCACGUUCAC... (length=73)
#   Cycle 194: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGGUUCACGUUCAC... (length=73)
#   Cycle 195: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGGUUCACGUUCAC... (length=73)
#   [Record] Cycle 195: Entropy=3.521 | Unique=  16 | Total copies=    63 | Avg len=24.7 | Max len=73 | tRNA candidates=2
#
#   Cycle 196: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGGUUCACGUUCAC... (length=73)
#   Cycle 197: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGGUUCACGUUCAC... (length=73)
#   Cycle 198: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 199: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 200: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 200: Entropy=3.780 | Unique=  16 | Total copies=    62 | Avg len=21.5 | Max len=46 | tRNA candidates=1
#
#   Cycle 201: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 202: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 203: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 204: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 205: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 205: Entropy=3.740 | Unique=  18 | Total copies=    72 | Avg len=17.8 | Max len=46 | tRNA candidates=1
#
#   Cycle 206: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 207: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 208: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 209: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 210: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 210: Entropy=3.520 | Unique=  16 | Total copies=    69 | Avg len=16.5 | Max len=46 | tRNA candidates=1
#
#   Cycle 211: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 212: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 213: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 214: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 215: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 215: Entropy=3.597 | Unique=  18 | Total copies=    64 | Avg len=16.1 | Max len=46 | tRNA candidates=1
#
#   Cycle 216: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 217: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 218: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 219: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 220: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   [Record] Cycle 220: Entropy=3.711 | Unique=  19 | Total copies=    67 | Avg len=25.0 | Max len=74 | tRNA candidates=1
#
#   Cycle 221: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 222: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 223: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUGUGGUUCACGUUC... (length=74)
#   Cycle 224: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 225: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   [Record] Cycle 225: Entropy=3.887 | Unique=  19 | Total copies=    83 | Avg len=22.7 | Max len=46 | tRNA candidates=1
#
#   Cycle 226: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 227: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 228: Longest RNA = UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCAGGUUGACA (length=46)
#   Cycle 229: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=75)
#   Cycle 230: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=75)
#   [Record] Cycle 230: Entropy=3.745 | Unique=  18 | Total copies=    78 | Avg len=31.1 | Max len=75 | tRNA candidates=1
#
#   Cycle 231: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=75)
#   Cycle 232: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=75)
#   Cycle 233: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 234: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 235: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   [Record] Cycle 235: Entropy=3.983 | Unique=  23 | Total copies=    89 | Avg len=35.1 | Max len=76 | tRNA candidates=3
#
#   Cycle 236: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 237: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 238: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 239: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 240: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   [Record] Cycle 240: Entropy=3.752 | Unique=  20 | Total copies=    75 | Avg len=34.4 | Max len=76 | tRNA candidates=2
#
#   Cycle 241: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 242: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 243: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 244: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 245: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   [Record] Cycle 245: Entropy=4.180 | Unique=  26 | Total copies=    90 | Avg len=27.3 | Max len=76 | tRNA candidates=3
#
#   Cycle 246: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 247: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 248: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 249: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 250: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   [Record] Cycle 250: Entropy=4.321 | Unique=  26 | Total copies=    93 | Avg len=32.7 | Max len=76 | tRNA candidates=5
#
#   Cycle 251: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 252: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 253: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 254: Longest RNA = GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUUC... (length=76)
#   Cycle 255: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=77)
#   [Record] Cycle 255: Entropy=4.138 | Unique=  23 | Total copies=    96 | Avg len=37.0 | Max len=77 | tRNA candidates=3
#
#   Cycle 256: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 257: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 258: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 259: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 260: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   [Record] Cycle 260: Entropy=4.491 | Unique=  31 | Total copies=   104 | Avg len=35.1 | Max len=78 | tRNA candidates=4
#
#   Cycle 261: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 262: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 263: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 264: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 265: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   [Record] Cycle 265: Entropy=4.356 | Unique=  28 | Total copies=   102 | Avg len=39.2 | Max len=78 | tRNA candidates=4
#
#   Cycle 266: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 267: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 268: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 269: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=78)
#   Cycle 270: Longest RNA = UGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUU... (length=77)
#   [Record] Cycle 270: Entropy=4.178 | Unique=  24 | Total copies=    93 | Avg len=37.5 | Max len=77 | tRNA candidates=2
#
#   Cycle 271: Longest RNA = UGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUU... (length=77)
#   Cycle 272: Longest RNA = UGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCGUGGUUCACGUU... (length=77)
#   Cycle 273: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=115)
#   Cycle 274: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 275: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   [Record] Cycle 275: Entropy=4.328 | Unique=  28 | Total copies=   105 | Avg len=44.3 | Max len=117 | tRNA candidates=3
#
#   Cycle 276: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 277: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 278: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 279: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 280: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   [Record] Cycle 280: Entropy=4.366 | Unique=  27 | Total copies=   100 | Avg len=44.5 | Max len=117 | tRNA candidates=4
#
#   Cycle 281: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 282: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 283: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 284: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 285: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   [Record] Cycle 285: Entropy=4.295 | Unique=  25 | Total copies=   100 | Avg len=43.4 | Max len=117 | tRNA candidates=4
#
#   Cycle 286: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 287: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 288: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 289: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 290: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   [Record] Cycle 290: Entropy=4.008 | Unique=  22 | Total copies=    88 | Avg len=45.9 | Max len=117 | tRNA candidates=3
#
#   Cycle 291: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 292: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 293: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 294: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 295: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   [Record] Cycle 295: Entropy=4.073 | Unique=  23 | Total copies=    99 | Avg len=37.5 | Max len=117 | tRNA candidates=3
#
#   Cycle 296: Longest RNA = CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU... (length=117)
#   Cycle 297: Longest RNA = GCGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGU... (length=118)
#   Cycle 298: Longest RNA = GCGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGU... (length=118)
#   Cycle 299: Longest RNA = GCGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGU... (length=118)
#   [Record] Cycle 299: Entropy=4.386 | Unique=  28 | Total copies=   106 | Avg len=46.0 | Max len=118 | tRNA candidates=4
#
# ----------------------------------------------------------------------
# Simulation complete!
# ================================================================================
# Top 15 Most Frequent Sequences
# ================================================================================
#  1. [    6] CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU...   (stability=0.540) ★ tRNA-like
#  2. [    5] GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUC...   (stability=0.543) ★ tRNA-like
#  3. [    5] CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUU...   (stability=0.536) ★ tRNA-like
#  4. [    4] UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCU                   (stability=0.554)
#  5. [    4] UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCU                  (stability=0.541)
#  6. [    4] GGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCC                 (stability=0.542)
#  7. [    4] UGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUG                (stability=0.540)
#  8. [    4] CU                                                      (stability=0.200)
#  9. [    3] UGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUG                  (stability=0.542)
# 10. [    3] UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUUUUC              (stability=0.528)
# 11. [    3] UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUC                 (stability=0.552)
# 12. [    2] UUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUUUU               (stability=0.519)
# 13. [    2] AC                                                      (stability=0.200)
# 14. [    2] CG                                                      (stability=0.200)
# 15. [    2] AA                                                      (stability=0.200)
#
# ================================================================================
# Discovered tRNA-like Structures (6 sequences)
# ================================================================================
#
#   Sequence: GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAUUG
#   Length: 75 nt, Stability: 0.543
#   Predicted structure: ..((.(((((((((..((((((.........(((........)))))))))..)))))).........))
#   Minimum free energy: -15.4 kcal/mol
#
#   Sequence: CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAUU
#   Length: 115 nt, Stability: 0.540
#
#   Sequence: CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAUU
#   Length: 117 nt, Stability: 0.536
#
#   Sequence: CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAUU
#   Length: 116 nt, Stability: 0.543
#
#   Sequence: GCGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAU
#   Length: 118 nt, Stability: 0.547
#
#   ... and 1 more
#
#
# ================================================================================
# Simulation Summary
# ================================================================================
# Final unique sequences (length>1): 24
# Final total copies (all): 106
# Final entropy: 4.386 bits
# Sequence length range: 2 - 118 nt
# Average sequence length: 46.0 nt
#
# Entropy reduction: -1.20 bits (from 3.18 to 4.39)
#   ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.
#
# Longest sequence discovered: GCGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCUUUG...
#   Length: 118 nt
#
# ★ tRNA-like sequences found: 6
#     - GUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCGC... (len=75)
#     - CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCG... (len=115)
#     - CGUGGUUCACGUUCACCUGAGCGCUGCAAAAUUGAUCCCUGGUUCACGUUCACCUGAGCG... (len=117)

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1000
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 50
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.05
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #    - Higher harshness = faster selection but may lose diversity
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'vienna'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 1000                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.0001          # 2% of initial pool per cycle
    LIGATION_PROB = 0.15                     # Base ligation probability
    HARSHNESS = 0.1                          # Environmental harshness
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Configuration:
#   Stability calculation method: VIENNA
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 1000
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation probability (base): 0.15
#   Environmental harshness: 0.1
#     (Higher = more extreme conditions, stability differences amplified)
#
#   ✓ Using ViennaRNA for stability calculations
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 202
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.1
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation base probability: 0.15
#
# Starting simulation: 1000 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = GCAUUU (length=6)
#   [Record] Cycle   0: Entropy=3.322 | Unique= 206 | Total copies= 10734 | Avg len=5.7 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = GCAUUU (length=6)
#   Cycle   2: Longest RNA = GCAUUU (length=6)
#   Cycle   3: Longest RNA = GCAUUU (length=6)
#   Cycle   4: Longest RNA = GCAUUU (length=6)
#   Cycle   5: Longest RNA = GCAUUU (length=6)
#   [Record] Cycle   5: Entropy=4.549 | Unique= 237 | Total copies=  6932 | Avg len=4.9 | Max len=6 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = GCAUUU (length=6)
#   Cycle   7: Longest RNA = GCAUUU (length=6)
#   Cycle   8: Longest RNA = GCAUUU (length=6)
#   Cycle   9: Longest RNA = GCAUUU (length=6)
#   Cycle  10: Longest RNA = GCAUUU (length=6)
#   [Record] Cycle  10: Entropy=5.241 | Unique= 234 | Total copies=  3830 | Avg len=4.8 | Max len=6 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = GCAUUU (length=6)
#   Cycle  12: Longest RNA = GCAUUU (length=6)
#   Cycle  13: Longest RNA = GCAUUU (length=6)
#   Cycle  14: Longest RNA = GCAUUU (length=6)
#   Cycle  15: Longest RNA = GCAUUU (length=6)
#   [Record] Cycle  15: Entropy=5.979 | Unique= 227 | Total copies=  2202 | Avg len=4.7 | Max len=6 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = GCAUUU (length=6)
#   Cycle  17: Longest RNA = GCAUUU (length=6)
#   Cycle  18: Longest RNA = GCAUUU (length=6)
#   Cycle  19: Longest RNA = GCAUUU (length=6)
#   Cycle  20: Longest RNA = GCAUUU (length=6)
#   [Record] Cycle  20: Entropy=6.654 | Unique= 217 | Total copies=  1412 | Avg len=4.7 | Max len=6 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = GCAUUU (length=6)
#   Cycle  22: Longest RNA = GCAUUU (length=6)
#   Cycle  23: Longest RNA = GCAUUU (length=6)
#   Cycle  24: Longest RNA = GCAUUU (length=6)
#   Cycle  25: Longest RNA = UUGAACA (length=7)
#   [Record] Cycle  25: Entropy=7.108 | Unique= 207 | Total copies=  1036 | Avg len=4.8 | Max len=7 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = UUGAACA (length=7)
#   Cycle  27: Longest RNA = UUGAACA (length=7)
#   Cycle  28: Longest RNA = UUGAACA (length=7)
#   Cycle  29: Longest RNA = UUGAACA (length=7)
#   Cycle  30: Longest RNA = UUGAACA (length=7)
#   [Record] Cycle  30: Entropy=7.321 | Unique= 196 | Total copies=   845 | Avg len=4.8 | Max len=7 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = UUGAACA (length=7)
#   Cycle  32: Longest RNA = UUGAACA (length=7)
#   Cycle  33: Longest RNA = UUGAACA (length=7)
#   Cycle  34: Longest RNA = UUGAACA (length=7)
#   Cycle  35: Longest RNA = UUGAACA (length=7)
#   [Record] Cycle  35: Entropy=7.306 | Unique= 182 | Total copies=   755 | Avg len=4.9 | Max len=7 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = UUGAACA (length=7)
#   Cycle  37: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  38: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  39: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  40: Longest RNA = UGAAUCACUAAA (length=12)
#   [Record] Cycle  40: Entropy=7.252 | Unique= 175 | Total copies=   695 | Avg len=5.0 | Max len=12 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  42: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  43: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  44: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  45: Longest RNA = UGAAUCACUAAA (length=12)
#   [Record] Cycle  45: Entropy=7.134 | Unique= 161 | Total copies=   635 | Avg len=5.1 | Max len=12 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  47: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  48: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  49: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  50: Longest RNA = UGAAUCACUAAA (length=12)
#   [Record] Cycle  50: Entropy=7.100 | Unique= 156 | Total copies=   635 | Avg len=5.2 | Max len=12 | tRNA candidates=0
#
#   Cycle  51: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  52: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  53: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  54: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  55: Longest RNA = UGAAUCACUAAA (length=12)
#   [Record] Cycle  55: Entropy=7.073 | Unique= 148 | Total copies=   599 | Avg len=5.4 | Max len=12 | tRNA candidates=0
#
#   Cycle  56: Longest RNA = UGAAUCACUAAA (length=12)
#   Cycle  57: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  58: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  59: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  60: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  60: Entropy=7.017 | Unique= 141 | Total copies=   567 | Avg len=5.6 | Max len=18 | tRNA candidates=0
#
#   Cycle  61: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  62: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  63: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  64: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  65: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  65: Entropy=6.968 | Unique= 139 | Total copies=   554 | Avg len=5.7 | Max len=18 | tRNA candidates=0
#
#   Cycle  66: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  67: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  68: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  69: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  70: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  70: Entropy=6.918 | Unique= 133 | Total copies=   563 | Avg len=5.8 | Max len=18 | tRNA candidates=0
#
#   Cycle  71: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  72: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  73: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  74: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  75: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  75: Entropy=6.845 | Unique= 131 | Total copies=   540 | Avg len=5.8 | Max len=18 | tRNA candidates=0
#
#   Cycle  76: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  77: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  78: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  79: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  80: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  80: Entropy=6.842 | Unique= 132 | Total copies=   571 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle  81: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  82: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  83: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  84: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  85: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  85: Entropy=6.856 | Unique= 130 | Total copies=   540 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle  86: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  87: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  88: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  89: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  90: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  90: Entropy=6.827 | Unique= 126 | Total copies=   531 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle  91: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  92: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  93: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  94: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  95: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle  95: Entropy=6.782 | Unique= 122 | Total copies=   497 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle  96: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  97: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  98: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle  99: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 100: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 100: Entropy=6.732 | Unique= 119 | Total copies=   512 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 101: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 102: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 103: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 104: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 105: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 105: Entropy=6.720 | Unique= 117 | Total copies=   531 | Avg len=5.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 106: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 107: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 108: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 109: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 110: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 110: Entropy=6.680 | Unique= 116 | Total copies=   494 | Avg len=6.1 | Max len=18 | tRNA candidates=0
#
#   Cycle 111: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 112: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 113: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 114: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 115: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 115: Entropy=6.684 | Unique= 114 | Total copies=   516 | Avg len=6.2 | Max len=18 | tRNA candidates=0
#
#   Cycle 116: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 117: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 118: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 119: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 120: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 120: Entropy=6.703 | Unique= 115 | Total copies=   505 | Avg len=6.4 | Max len=18 | tRNA candidates=0
#
#   Cycle 121: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 122: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 123: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 124: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 125: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 125: Entropy=6.633 | Unique= 111 | Total copies=   470 | Avg len=6.4 | Max len=18 | tRNA candidates=0
#
#   Cycle 126: Longest RNA = GUCCUAGUCCUAGUCGUGAAUCACUAAA (length=28)
#   Cycle 127: Longest RNA = GUCCUAGUCCUAGUCGUGAAUCACUAAA (length=28)
#   Cycle 128: Longest RNA = GUCCUAGUCCUAGUCGUGAAUCACUAAA (length=28)
#   Cycle 129: Longest RNA = GUCCUAGUCCUAGUCGUGAAUCACUAAA (length=28)
#   Cycle 130: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 130: Entropy=6.609 | Unique= 110 | Total copies=   459 | Avg len=6.4 | Max len=18 | tRNA candidates=0
#
#   Cycle 131: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 132: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 133: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 134: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 135: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 135: Entropy=6.557 | Unique= 107 | Total copies=   456 | Avg len=6.4 | Max len=18 | tRNA candidates=0
#
#   Cycle 136: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 137: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 138: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 139: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 140: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 140: Entropy=6.554 | Unique= 106 | Total copies=   439 | Avg len=6.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 142: Longest RNA = GUCCUAGUCCUACCAGAUGGCGAU (length=24)
#   Cycle 143: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 144: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 145: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 145: Entropy=6.508 | Unique= 102 | Total copies=   430 | Avg len=6.6 | Max len=18 | tRNA candidates=0
#
#   Cycle 146: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 147: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 148: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 149: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 150: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 150: Entropy=6.479 | Unique=  98 | Total copies=   402 | Avg len=6.7 | Max len=18 | tRNA candidates=0
#
#   Cycle 151: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 152: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 153: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 154: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 155: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 155: Entropy=6.369 | Unique=  95 | Total copies=   365 | Avg len=6.8 | Max len=18 | tRNA candidates=0
#
#   Cycle 156: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 157: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 158: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 159: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 160: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 160: Entropy=6.374 | Unique=  94 | Total copies=   365 | Avg len=6.8 | Max len=18 | tRNA candidates=0
#
#   Cycle 161: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 162: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 163: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 164: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 165: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   [Record] Cycle 165: Entropy=6.368 | Unique=  92 | Total copies=   356 | Avg len=6.8 | Max len=18 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 167: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 168: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 169: Longest RNA = UUUCUGUGAAUCACUAAA (length=18)
#   Cycle 170: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 170: Entropy=6.384 | Unique=  93 | Total copies=   372 | Avg len=6.9 | Max len=24 | tRNA candidates=0
#
#   Cycle 171: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 172: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 173: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 174: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 175: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 175: Entropy=6.365 | Unique=  91 | Total copies=   382 | Avg len=7.0 | Max len=24 | tRNA candidates=0
#
#   Cycle 176: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 177: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 178: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 179: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 180: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 180: Entropy=6.365 | Unique=  89 | Total copies=   353 | Avg len=7.1 | Max len=24 | tRNA candidates=0
#
#   Cycle 181: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 182: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 183: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 184: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 185: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 185: Entropy=6.313 | Unique=  88 | Total copies=   377 | Avg len=7.2 | Max len=24 | tRNA candidates=0
#
#   Cycle 186: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 187: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 188: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 189: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 190: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 190: Entropy=6.309 | Unique=  88 | Total copies=   365 | Avg len=7.2 | Max len=24 | tRNA candidates=0
#
#   Cycle 191: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 192: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 193: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 194: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 195: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 195: Entropy=6.336 | Unique=  89 | Total copies=   375 | Avg len=7.4 | Max len=24 | tRNA candidates=0
#
#   Cycle 196: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 197: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 198: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 199: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 200: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 200: Entropy=6.304 | Unique=  87 | Total copies=   368 | Avg len=7.4 | Max len=24 | tRNA candidates=0
#
#   Cycle 201: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 202: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 203: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 204: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 205: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 205: Entropy=6.259 | Unique=  87 | Total copies=   362 | Avg len=7.7 | Max len=24 | tRNA candidates=0
#
#   Cycle 206: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 207: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 208: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 209: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 210: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 210: Entropy=6.240 | Unique=  84 | Total copies=   337 | Avg len=7.5 | Max len=24 | tRNA candidates=0
#
#   Cycle 211: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 212: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 213: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 214: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 215: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 215: Entropy=6.259 | Unique=  83 | Total copies=   340 | Avg len=7.4 | Max len=24 | tRNA candidates=0
#
#   Cycle 216: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 217: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 218: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 219: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 220: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 220: Entropy=6.232 | Unique=  86 | Total copies=   324 | Avg len=7.8 | Max len=24 | tRNA candidates=0
#
#   Cycle 221: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 222: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 223: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 224: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 225: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 225: Entropy=6.168 | Unique=  81 | Total copies=   329 | Avg len=7.7 | Max len=24 | tRNA candidates=0
#
#   Cycle 226: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 227: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 228: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 229: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 230: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 230: Entropy=6.128 | Unique=  79 | Total copies=   321 | Avg len=7.8 | Max len=24 | tRNA candidates=0
#
#   Cycle 231: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 232: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 233: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 234: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 235: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 235: Entropy=6.158 | Unique=  80 | Total copies=   323 | Avg len=8.0 | Max len=24 | tRNA candidates=0
#
#   Cycle 236: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 237: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 238: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 239: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 240: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 240: Entropy=6.165 | Unique=  80 | Total copies=   321 | Avg len=8.0 | Max len=24 | tRNA candidates=0
#
#   Cycle 241: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 242: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 243: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 244: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 245: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 245: Entropy=6.231 | Unique=  83 | Total copies=   315 | Avg len=8.4 | Max len=24 | tRNA candidates=0
#
#   Cycle 246: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 247: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 248: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 249: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 250: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 250: Entropy=6.207 | Unique=  82 | Total copies=   332 | Avg len=8.4 | Max len=24 | tRNA candidates=0
#
#   Cycle 251: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 252: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 253: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 254: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 255: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 255: Entropy=6.236 | Unique=  83 | Total copies=   327 | Avg len=8.5 | Max len=24 | tRNA candidates=0
#
#   Cycle 256: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 257: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 258: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 259: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 260: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 260: Entropy=6.243 | Unique=  84 | Total copies=   335 | Avg len=8.7 | Max len=24 | tRNA candidates=0
#
#   Cycle 261: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 262: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 263: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 264: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 265: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 265: Entropy=6.202 | Unique=  83 | Total copies=   322 | Avg len=8.7 | Max len=24 | tRNA candidates=0
#
#   Cycle 266: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 267: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 268: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 269: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   Cycle 270: Longest RNA = GCUCAACGUUGUGACCAUACUAAA (length=24)
#   [Record] Cycle 270: Entropy=6.175 | Unique=  82 | Total copies=   319 | Avg len=9.0 | Max len=24 | tRNA candidates=0
#
#   Cycle 271: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 272: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 273: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 274: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 275: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 275: Entropy=6.200 | Unique=  82 | Total copies=   313 | Avg len=9.5 | Max len=34 | tRNA candidates=0
#
#   Cycle 276: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 277: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 278: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 279: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 280: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 280: Entropy=6.211 | Unique=  82 | Total copies=   332 | Avg len=9.6 | Max len=34 | tRNA candidates=0
#
#   Cycle 281: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 282: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 283: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 284: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 285: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 285: Entropy=6.206 | Unique=  82 | Total copies=   352 | Avg len=10.1 | Max len=34 | tRNA candidates=0
#
#   Cycle 286: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 287: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 288: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 289: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 290: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 290: Entropy=6.164 | Unique=  81 | Total copies=   315 | Avg len=10.0 | Max len=34 | tRNA candidates=0
#
#   Cycle 291: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 292: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 293: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 294: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 295: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 295: Entropy=6.177 | Unique=  80 | Total copies=   317 | Avg len=9.9 | Max len=34 | tRNA candidates=0
#
#   Cycle 296: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 297: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 298: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 299: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 300: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 300: Entropy=6.141 | Unique=  79 | Total copies=   309 | Avg len=10.0 | Max len=34 | tRNA candidates=0
#
#   Cycle 301: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 302: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 303: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 304: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 305: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 305: Entropy=6.140 | Unique=  77 | Total copies=   287 | Avg len=10.5 | Max len=34 | tRNA candidates=0
#
#   Cycle 306: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 307: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 308: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 309: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 310: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 310: Entropy=6.171 | Unique=  78 | Total copies=   307 | Avg len=10.6 | Max len=34 | tRNA candidates=0
#
#   Cycle 311: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 312: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 313: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 314: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 315: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 315: Entropy=6.155 | Unique=  77 | Total copies=   317 | Avg len=10.8 | Max len=34 | tRNA candidates=0
#
#   Cycle 316: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 317: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 318: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 319: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 320: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 320: Entropy=6.135 | Unique=  77 | Total copies=   321 | Avg len=10.9 | Max len=34 | tRNA candidates=0
#
#   Cycle 321: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 322: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 323: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 324: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 325: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 325: Entropy=6.101 | Unique=  77 | Total copies=   316 | Avg len=11.0 | Max len=34 | tRNA candidates=0
#
#   Cycle 326: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 327: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 328: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 329: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 330: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 330: Entropy=6.112 | Unique=  77 | Total copies=   275 | Avg len=11.2 | Max len=34 | tRNA candidates=0
#
#   Cycle 331: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 332: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 333: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 334: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 335: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   [Record] Cycle 335: Entropy=6.056 | Unique=  75 | Total copies=   259 | Avg len=11.2 | Max len=34 | tRNA candidates=0
#
#   Cycle 336: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 337: Longest RNA = AGUAGCGCAGGCUCAACGUUGUGACCAUACUAAA (length=34)
#   Cycle 338: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 339: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 340: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   [Record] Cycle 340: Entropy=6.059 | Unique=  76 | Total copies=   293 | Avg len=11.8 | Max len=46 | tRNA candidates=0
#
#   Cycle 341: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 342: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 343: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 344: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 345: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   [Record] Cycle 345: Entropy=6.037 | Unique=  73 | Total copies=   301 | Avg len=11.4 | Max len=46 | tRNA candidates=0
#
#   Cycle 346: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 347: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 348: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 349: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 350: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   [Record] Cycle 350: Entropy=6.010 | Unique=  74 | Total copies=   308 | Avg len=11.9 | Max len=46 | tRNA candidates=0
#
#   Cycle 351: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 352: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 353: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 354: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 355: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   [Record] Cycle 355: Entropy=5.988 | Unique=  71 | Total copies=   309 | Avg len=11.8 | Max len=46 | tRNA candidates=0
#
#   Cycle 356: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 357: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 358: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 359: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 360: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   [Record] Cycle 360: Entropy=5.976 | Unique=  71 | Total copies=   302 | Avg len=12.0 | Max len=46 | tRNA candidates=0
#
#   Cycle 361: Longest RNA = UGAAUCGCAGUGUCCUAGUCCUAUGAAUCGCAGUGUCCUAGUCCUA (length=46)
#   Cycle 362: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 363: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 364: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 365: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   [Record] Cycle 365: Entropy=5.990 | Unique=  70 | Total copies=   290 | Avg len=11.4 | Max len=30 | tRNA candidates=0
#
#   Cycle 366: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 367: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 368: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 369: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 370: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   [Record] Cycle 370: Entropy=6.010 | Unique=  71 | Total copies=   284 | Avg len=11.6 | Max len=30 | tRNA candidates=0
#
#   Cycle 371: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 372: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 373: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 374: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 375: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   [Record] Cycle 375: Entropy=6.008 | Unique=  72 | Total copies=   262 | Avg len=12.2 | Max len=34 | tRNA candidates=0
#
#   Cycle 376: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 377: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 378: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 379: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   Cycle 380: Longest RNA = UGGGAUGUUACUGCUUGACCAUGUCCUAGUCCUA (length=34)
#   [Record] Cycle 380: Entropy=5.968 | Unique=  72 | Total copies=   254 | Avg len=12.5 | Max len=34 | tRNA candidates=0
#
#   Cycle 381: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 382: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 383: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 384: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 385: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   [Record] Cycle 385: Entropy=5.980 | Unique=  70 | Total copies=   270 | Avg len=12.2 | Max len=30 | tRNA candidates=0
#
#   Cycle 386: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 387: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 388: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 389: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 390: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   [Record] Cycle 390: Entropy=5.953 | Unique=  67 | Total copies=   270 | Avg len=12.3 | Max len=30 | tRNA candidates=0
#
#   Cycle 391: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 392: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=30)
#   Cycle 393: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 394: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 395: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   [Record] Cycle 395: Entropy=5.788 | Unique=  62 | Total copies=   249 | Avg len=12.6 | Max len=48 | tRNA candidates=0
#
#   Cycle 396: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 397: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 398: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 399: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 400: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   [Record] Cycle 400: Entropy=5.878 | Unique=  65 | Total copies=   248 | Avg len=13.2 | Max len=48 | tRNA candidates=0
#
#   Cycle 401: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 402: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 403: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 404: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   Cycle 405: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUA (length=48)
#   [Record] Cycle 405: Entropy=5.923 | Unique=  66 | Total copies=   245 | Avg len=13.3 | Max len=48 | tRNA candidates=0
#
#   Cycle 406: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 407: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 408: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 409: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 410: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 410: Entropy=5.917 | Unique=  67 | Total copies=   255 | Avg len=13.9 | Max len=52 | tRNA candidates=0
#
#   Cycle 411: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 412: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 413: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 414: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 415: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 415: Entropy=5.968 | Unique=  68 | Total copies=   242 | Avg len=14.0 | Max len=52 | tRNA candidates=0
#
#   Cycle 416: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 417: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 418: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 419: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 420: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 420: Entropy=5.923 | Unique=  67 | Total copies=   264 | Avg len=14.5 | Max len=52 | tRNA candidates=0
#
#   Cycle 421: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 422: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 423: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 424: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 425: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 425: Entropy=5.970 | Unique=  69 | Total copies=   281 | Avg len=15.0 | Max len=52 | tRNA candidates=0
#
#   Cycle 426: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 427: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 428: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 429: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 430: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 430: Entropy=5.937 | Unique=  68 | Total copies=   289 | Avg len=14.9 | Max len=52 | tRNA candidates=0
#
#   Cycle 431: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 432: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 433: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 434: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 435: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 435: Entropy=5.972 | Unique=  69 | Total copies=   292 | Avg len=15.0 | Max len=52 | tRNA candidates=0
#
#   Cycle 436: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 437: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 438: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 439: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 440: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 440: Entropy=5.903 | Unique=  65 | Total copies=   285 | Avg len=15.0 | Max len=52 | tRNA candidates=0
#
#   Cycle 441: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 442: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 443: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 444: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 445: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 445: Entropy=5.895 | Unique=  65 | Total copies=   275 | Avg len=14.9 | Max len=52 | tRNA candidates=0
#
#   Cycle 446: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 447: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 448: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 449: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 450: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 450: Entropy=5.912 | Unique=  68 | Total copies=   279 | Avg len=15.3 | Max len=52 | tRNA candidates=0
#
#   Cycle 451: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 452: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 453: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 454: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 455: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 455: Entropy=5.906 | Unique=  67 | Total copies=   284 | Avg len=15.0 | Max len=52 | tRNA candidates=0
#
#   Cycle 456: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 457: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 458: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 459: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 460: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 460: Entropy=5.914 | Unique=  68 | Total copies=   286 | Avg len=16.2 | Max len=52 | tRNA candidates=1
#
#   Cycle 461: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 462: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 463: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 464: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 465: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   [Record] Cycle 465: Entropy=6.020 | Unique=  72 | Total copies=   300 | Avg len=17.3 | Max len=62 | tRNA candidates=1
#
#   Cycle 466: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 467: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 468: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 469: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 470: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   [Record] Cycle 470: Entropy=6.015 | Unique=  73 | Total copies=   308 | Avg len=17.3 | Max len=62 | tRNA candidates=1
#
#   Cycle 471: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 472: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=62)
#   Cycle 473: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 474: Longest RNA = GUCUGAGCUUGACCAUUGAAUCCAUGACGGUCCAUUCGCCCGUCUGAGAA... (length=60)
#   Cycle 475: Longest RNA = GUCUGAGCUUGACCAUUGAAUCCAUGACGGUCCAUUCGCCCGUCUGAGAA... (length=60)
#   [Record] Cycle 475: Entropy=6.027 | Unique=  71 | Total copies=   299 | Avg len=17.4 | Max len=60 | tRNA candidates=1
#
#   Cycle 476: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 477: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 478: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 479: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 480: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 480: Entropy=5.969 | Unique=  69 | Total copies=   289 | Avg len=17.1 | Max len=52 | tRNA candidates=2
#
#   Cycle 481: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 482: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 483: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 484: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 485: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   [Record] Cycle 485: Entropy=5.980 | Unique=  68 | Total copies=   287 | Avg len=17.4 | Max len=52 | tRNA candidates=2
#
#   Cycle 486: Longest RNA = AUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCC... (length=52)
#   Cycle 487: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 488: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 489: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 490: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   [Record] Cycle 490: Entropy=6.023 | Unique=  71 | Total copies=   295 | Avg len=18.0 | Max len=61 | tRNA candidates=1
#
#   Cycle 491: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 492: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 493: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 494: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 495: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   [Record] Cycle 495: Entropy=6.057 | Unique=  72 | Total copies=   289 | Avg len=18.4 | Max len=61 | tRNA candidates=1
#
#   Cycle 496: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 497: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 498: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
#   Cycle 499: Longest RNA = CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU... (length=61)
# ...
#   Cycle 900: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 900: Entropy=5.608 | Unique=  55 | Total copies=   230 | Avg len=74.8 | Max len=142 | tRNA candidates=34
#
#   Cycle 901: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 902: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 903: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 904: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 905: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 905: Entropy=5.631 | Unique=  56 | Total copies=   238 | Avg len=77.5 | Max len=142 | tRNA candidates=36
#
#   Cycle 906: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 907: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 908: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 909: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 910: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 910: Entropy=5.670 | Unique=  57 | Total copies=   249 | Avg len=75.0 | Max len=142 | tRNA candidates=36
#
#   Cycle 911: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 912: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 913: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 914: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 915: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 915: Entropy=5.717 | Unique=  58 | Total copies=   243 | Avg len=72.8 | Max len=142 | tRNA candidates=37
#
#   Cycle 916: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 917: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 918: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 919: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 920: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 920: Entropy=5.705 | Unique=  59 | Total copies=   248 | Avg len=75.7 | Max len=142 | tRNA candidates=35
#
#   Cycle 921: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 922: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 923: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 924: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 925: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 925: Entropy=5.812 | Unique=  62 | Total copies=   258 | Avg len=77.6 | Max len=142 | tRNA candidates=37
#
#   Cycle 926: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 927: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 928: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 929: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 930: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 930: Entropy=5.807 | Unique=  62 | Total copies=   255 | Avg len=79.2 | Max len=142 | tRNA candidates=36
#
#   Cycle 931: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 932: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 933: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 934: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   Cycle 935: Longest RNA = GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA... (length=142)
#   [Record] Cycle 935: Entropy=5.776 | Unique=  61 | Total copies=   276 | Avg len=78.8 | Max len=142 | tRNA candidates=35
#
#   Cycle 936: Longest RNA = CCUUCAUGCUAAAUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAA... (length=145)
#   Cycle 937: Longest RNA = CCUUCAUGCUAAAUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAA... (length=145)
#   Cycle 938: Longest RNA = CCUUCAUGCUAAAUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAA... (length=145)
#   Cycle 939: Longest RNA = CCUUCAUGCUAAAUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAA... (length=145)
#   Cycle 940: Longest RNA = AUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAACGCGACAUGACG... (length=146)
#   [Record] Cycle 940: Entropy=5.736 | Unique=  61 | Total copies=   265 | Avg len=81.9 | Max len=146 | tRNA candidates=32
#
#   Cycle 941: Longest RNA = AUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAACGCGACAUGACG... (length=146)
#   Cycle 942: Longest RNA = AUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAACGCGACAUGACG... (length=146)
#   Cycle 943: Longest RNA = AUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAACGCGACAUGACG... (length=146)
#   Cycle 944: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 945: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   [Record] Cycle 945: Entropy=5.833 | Unique=  63 | Total copies=   286 | Avg len=83.3 | Max len=147 | tRNA candidates=34
#
#   Cycle 946: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 947: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 948: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 949: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 950: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   [Record] Cycle 950: Entropy=5.774 | Unique=  62 | Total copies=   299 | Avg len=83.3 | Max len=147 | tRNA candidates=33
#
#   Cycle 951: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 952: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 953: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 954: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 955: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   [Record] Cycle 955: Entropy=5.759 | Unique=  61 | Total copies=   290 | Avg len=83.5 | Max len=147 | tRNA candidates=36
#
#   Cycle 956: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 957: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 958: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 959: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 960: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   [Record] Cycle 960: Entropy=5.777 | Unique=  62 | Total copies=   295 | Avg len=84.3 | Max len=147 | tRNA candidates=34
#
#   Cycle 961: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 962: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 963: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 964: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 965: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   [Record] Cycle 965: Entropy=5.839 | Unique=  63 | Total copies=   304 | Avg len=86.2 | Max len=147 | tRNA candidates=38
#
#   Cycle 966: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 967: Longest RNA = AUGACGGCGCAGCAGCUCGCCUUCAUGGGAUCCAGAUAUGACGGUCCAUU... (length=147)
#   Cycle 968: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 969: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 970: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 970: Entropy=5.939 | Unique=  68 | Total copies=   314 | Avg len=87.4 | Max len=149 | tRNA candidates=38
#
#   Cycle 971: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 972: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 973: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 974: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 975: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 975: Entropy=5.952 | Unique=  69 | Total copies=   299 | Avg len=87.7 | Max len=149 | tRNA candidates=38
#
#   Cycle 976: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 977: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 978: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 979: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 980: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 980: Entropy=5.966 | Unique=  69 | Total copies=   303 | Avg len=87.7 | Max len=149 | tRNA candidates=37
#
#   Cycle 981: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 982: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 983: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 984: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 985: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 985: Entropy=5.899 | Unique=  67 | Total copies=   296 | Avg len=88.2 | Max len=149 | tRNA candidates=36
#
#   Cycle 986: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 987: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 988: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 989: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 990: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 990: Entropy=5.933 | Unique=  69 | Total copies=   305 | Avg len=87.7 | Max len=149 | tRNA candidates=36
#
#   Cycle 991: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 992: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 993: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 994: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 995: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 995: Entropy=5.930 | Unique=  68 | Total copies=   286 | Avg len=87.5 | Max len=149 | tRNA candidates=36
#
#   Cycle 996: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 997: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 998: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   Cycle 999: Longest RNA = GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG... (length=149)
#   [Record] Cycle 999: Entropy=5.930 | Unique=  66 | Total copies=   289 | Avg len=89.0 | Max len=149 | tRNA candidates=38
#
# ----------------------------------------------------------------------
# Simulation complete!
# ================================================================================
# Top 15 Most Frequent Sequences
# ================================================================================
#  1. [    9] CCUUCA                                                  (stability=0.455)
#  2. [    8] GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAA                 (stability=0.457) ★ tRNA-like
#  3. [    7] GCGCAGCAGCUCAUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACC...   (stability=0.514) ★ tRNA-like
#  4. [    7] UGAAUCCUGGGAUAAGCUCUGAAUCGAUACUUUGAAUCGCAGUGUCCUAG...   (stability=0.525) ★ tRNA-like
#  5. [    7] CCUUCAGCUUGACCAUAGUCGGAUGACGGCGCAGCAGCUCUCGCAUAAUG...   (stability=0.533) ★ tRNA-like
#  6. [    7] GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAG...   (stability=0.502) ★ tRNA-like
#  7. [    7] AUGACGGCGCAGCAGCUCUCGCAUAAUGCGGCUGCUAACGCGACCGCGUC...   (stability=0.526) ★ tRNA-like
#  8. [    7] CGCGACAUGCGGCCCAGUCCCCGUCUGAGCUUGACCAUGUCCUAGUCCUA...   (stability=0.514) ★ tRNA-like
#  9. [    6] CGCAUAAUGCGGCUGCUAAUGAAUCCUGGGAUAAGCUCGUCUGAGCUUGA...   (stability=0.532) ★ tRNA-like
# 10. [    6] CCUUCAGCUUGACCAUAGUCGG                                  (stability=0.455)
# 11. [    6] CCUUCAAUGACGGCUUGACCAUAGUCGGCGCGUCCGCGUCCCUUCA          (stability=0.471)
# 12. [    6] CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAGU...   (stability=0.507) ★ tRNA-like
# 13. [    6] CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAU...   (stability=0.492) ★ tRNA-like
# 14. [    6] GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCAAUGACGCCUUCA...   (stability=0.515) ★ tRNA-like
# 15. [    6] GGCUUGACCAUAGUCGGAUGACGAUGCGGCCCAGCGCAGCAGCUCGCAUA...   (stability=0.505) ★ tRNA-like
#
# ================================================================================
# Discovered tRNA-like Structures (49 sequences)
# ================================================================================
#
#   Sequence: GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCA
#   Length: 38 nt, Stability: 0.457
#   Predicted structure: ......(((.......(((....))).....)))....
#   Minimum free energy: -3.5 kcal/mol
#
#   Sequence: GCGCAGCAGCUCAUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGUCCUA
#   Length: 64 nt, Stability: 0.476
#   Predicted structure: ..((.....((((.(((((.(.....).))))))))).....))....................
#   Minimum free energy: -13.2 kcal/mol
#
#   Sequence: CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAUGACGAUGCGGCCCAGCGCAG
#   Length: 76 nt, Stability: 0.480
#   Predicted structure: ........(((((((....))..)))))..((((.((((...........))))..))))...(((....
#   Minimum free energy: -15.1 kcal/mol
#
#   Sequence: CGCGACAUGCGGCCCAGUCCCCGUCUGAGCUUGACCAUGUCCUAGUCCUAGUCCCCGUCUGACCUUCA
#   Length: 68 nt, Stability: 0.474
#   Predicted structure: ...((((((.(((.(((.......))).)))....)))))).........(((.......))).....
#   Minimum free energy: -11.9 kcal/mol
#
#   Sequence: CGCAUAAUGCGGCUGCUAAUGAAUCCUGGGAUAAGCUCGCAUACCCUUUUCAUCCGCGUCCGCGUCCCCA
#   Length: 88 nt, Stability: 0.511
#   Predicted structure: ......((((((.(((...((((.((((((....((.(((...............)))...))...))))
#   Minimum free energy: -30.4 kcal/mol
#
#   ... and 44 more
#
#
# ================================================================================
# Simulation Summary
# ================================================================================
# Final unique sequences (length>1): 62
# Final total copies (all): 289
# Final entropy: 5.930 bits
# Sequence length range: 6 - 149 nt
# Average sequence length: 89.0 nt
#
# Entropy reduction: -2.61 bits (from 3.32 to 5.93)
#   ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.
#
# Longest sequence discovered: GCCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAGUCCUAGUCCUACGCAUAAUGCGGCUGCUAA...
#   Length: 149 nt
#
# ★ tRNA-like sequences found: 49
#     - GCAUACCCUUUUCAUCCGCGUCCGCGUCCCCAGGUUCA... (len=38)
#     - GCGCAGCAGCUCAUGACGGUCCAUUCGCCCGUCUGAGAAUUAGCUUGACCAUGUCCUAGU... (len=64)
#     - CCUUCAUGGGAUCCAGAUAUGACGGUCCAUUCGCCCGUCUGAGAAUUAAUGACGAUGCGG... (len=76)

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1000
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 50
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.05
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #    - Higher harshness = faster selection but may lose diversity
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'heuristic'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 300                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.02          # 2% of initial pool per cycle
    LIGATION_PROB = 0.1                     # Base ligation probability
    HARSHNESS = 0.2                          # Environmental harshness
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Configuration:
#   Stability calculation method: HEURISTIC
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 300
#   Supplementation fraction: 2.0% of initial pool per cycle
#   Ligation probability (base): 0.1
#   Environmental harshness: 0.2
#     (Higher = more extreme conditions, stability differences amplified)
#
#   Using heuristic stability calculation
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 200
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.2
#   Supplementation fraction: 2.0% of initial pool per cycle
#   Ligation base probability: 0.1
#
# Starting simulation: 300 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = UUGUCC (length=6)
#   [Record] Cycle   0: Entropy=3.175 | Unique= 190 | Total copies=  8936 | Avg len=5.7 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = UUGUCC (length=6)
#   Cycle   2: Longest RNA = UUGUCC (length=6)
#   Cycle   3: Longest RNA = UUGUCC (length=6)
#   Cycle   4: Longest RNA = AUGACCC (length=7)
#   Cycle   5: Longest RNA = AUGACCC (length=7)
#   [Record] Cycle   5: Entropy=4.227 | Unique= 157 | Total copies=  3164 | Avg len=5.1 | Max len=7 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = AUGACCC (length=7)
#   Cycle   7: Longest RNA = AUGACCC (length=7)
#   Cycle   8: Longest RNA = AUGACCC (length=7)
#   Cycle   9: Longest RNA = AUGACCC (length=7)
#   Cycle  10: Longest RNA = AUGACCC (length=7)
#   [Record] Cycle  10: Entropy=4.501 | Unique= 134 | Total copies=  1586 | Avg len=5.0 | Max len=7 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = AUGACCC (length=7)
#   Cycle  12: Longest RNA = AUGACCC (length=7)
#   Cycle  13: Longest RNA = AUGACCC (length=7)
#   Cycle  14: Longest RNA = CAAACGU (length=7)
#   Cycle  15: Longest RNA = CAAACGU (length=7)
#   [Record] Cycle  15: Entropy=4.447 | Unique= 106 | Total copies=  1231 | Avg len=5.0 | Max len=7 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = CAAACGU (length=7)
#   Cycle  17: Longest RNA = CAAACGU (length=7)
#   Cycle  18: Longest RNA = CAAACGU (length=7)
#   Cycle  19: Longest RNA = CAAACGU (length=7)
#   Cycle  20: Longest RNA = CAAACGU (length=7)
#   [Record] Cycle  20: Entropy=4.233 | Unique=  91 | Total copies=  1094 | Avg len=4.9 | Max len=7 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = CAAACGU (length=7)
#   Cycle  22: Longest RNA = CAAACGU (length=7)
#   Cycle  23: Longest RNA = CAAACGU (length=7)
#   Cycle  24: Longest RNA = CAAACGU (length=7)
#   Cycle  25: Longest RNA = UAAUCCGC (length=8)
#   [Record] Cycle  25: Entropy=4.018 | Unique=  77 | Total copies=  1035 | Avg len=4.8 | Max len=8 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = UAAUCCGC (length=8)
#   Cycle  27: Longest RNA = UAAUCCGC (length=8)
#   Cycle  28: Longest RNA = UAAUCCGC (length=8)
#   Cycle  29: Longest RNA = UAAUCCGC (length=8)
#   Cycle  30: Longest RNA = CAAACGU (length=7)
#   [Record] Cycle  30: Entropy=3.916 | Unique=  67 | Total copies=  1090 | Avg len=4.6 | Max len=7 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = CAAACGU (length=7)
#   Cycle  32: Longest RNA = CAAACGU (length=7)
#   Cycle  33: Longest RNA = CAAACGU (length=7)
#   Cycle  34: Longest RNA = CAAACGU (length=7)
#   Cycle  35: Longest RNA = CAAACGU (length=7)
#   [Record] Cycle  35: Entropy=3.911 | Unique=  68 | Total copies=  1070 | Avg len=4.7 | Max len=7 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = CAAACGU (length=7)
#   Cycle  37: Longest RNA = CAAACGU (length=7)
#   Cycle  38: Longest RNA = CAAACGU (length=7)
#   Cycle  39: Longest RNA = GAUUGCUC (length=8)
#   Cycle  40: Longest RNA = GAUUGCUC (length=8)
#   [Record] Cycle  40: Entropy=3.947 | Unique=  67 | Total copies=  1030 | Avg len=4.6 | Max len=8 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = GAUUGCUC (length=8)
#   Cycle  42: Longest RNA = GAUUGCUC (length=8)
#   Cycle  43: Longest RNA = GAUUGCUC (length=8)
#   Cycle  44: Longest RNA = GAUUGCUC (length=8)
#   Cycle  45: Longest RNA = GAUUGCUC (length=8)
#   [Record] Cycle  45: Entropy=3.869 | Unique=  59 | Total copies=  1037 | Avg len=4.4 | Max len=8 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = GAUUGCUC (length=8)
#   Cycle  47: Longest RNA = GAUUGCUC (length=8)
#   Cycle  48: Longest RNA = GAUUGCUC (length=8)
#   Cycle  49: Longest RNA = GAUUGCUC (length=8)
#   Cycle  50: Longest RNA = GAUUGCUC (length=8)
#   [Record] Cycle  50: Entropy=3.850 | Unique=  55 | Total copies=  1078 | Avg len=4.2 | Max len=8 | tRNA candidates=0
#
#   Cycle  51: Longest RNA = GAUUGCUC (length=8)
#   Cycle  52: Longest RNA = GAUUGCUC (length=8)
#   Cycle  53: Longest RNA = GAUUGCUC (length=8)
#   Cycle  54: Longest RNA = GAUUGCUC (length=8)
#   Cycle  55: Longest RNA = GAUUGCUC (length=8)
#   [Record] Cycle  55: Entropy=3.715 | Unique=  48 | Total copies=  1016 | Avg len=4.1 | Max len=8 | tRNA candidates=0
#
#   Cycle  56: Longest RNA = GAUUGCUC (length=8)
#   Cycle  57: Longest RNA = GAUUGCUC (length=8)
#   Cycle  58: Longest RNA = GAUUGCUC (length=8)
#   Cycle  59: Longest RNA = GAUUGCUC (length=8)
#   Cycle  60: Longest RNA = GAUUGCUC (length=8)
#   [Record] Cycle  60: Entropy=3.704 | Unique=  48 | Total copies=  1036 | Avg len=4.2 | Max len=8 | tRNA candidates=0
#
#   Cycle  61: Longest RNA = GAUUGCUC (length=8)
#   Cycle  62: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  63: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  64: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  65: Longest RNA = CGAUUGCUC (length=9)
#   [Record] Cycle  65: Entropy=3.745 | Unique=  48 | Total copies=  1089 | Avg len=4.2 | Max len=9 | tRNA candidates=0
#
#   Cycle  66: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  67: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  68: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  69: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  70: Longest RNA = CGAUUGCUC (length=9)
#   [Record] Cycle  70: Entropy=3.774 | Unique=  46 | Total copies=  1082 | Avg len=4.2 | Max len=9 | tRNA candidates=0
#
#   Cycle  71: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  72: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  73: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  74: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  75: Longest RNA = CGAUUGCUC (length=9)
#   [Record] Cycle  75: Entropy=3.741 | Unique=  45 | Total copies=  1063 | Avg len=3.9 | Max len=9 | tRNA candidates=0
#
#   Cycle  76: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  77: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  78: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  79: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  80: Longest RNA = CGAUUGCUC (length=9)
#   [Record] Cycle  80: Entropy=3.676 | Unique=  43 | Total copies=  1069 | Avg len=3.8 | Max len=9 | tRNA candidates=0
#
#   Cycle  81: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  82: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  83: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  84: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  85: Longest RNA = CGAUUGCUC (length=9)
#   [Record] Cycle  85: Entropy=3.668 | Unique=  42 | Total copies=  1058 | Avg len=3.8 | Max len=9 | tRNA candidates=0
#
#   Cycle  86: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  87: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  88: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  89: Longest RNA = CGAUUGCUC (length=9)
#   Cycle  90: Longest RNA = CCUGGACA (length=8)
#   [Record] Cycle  90: Entropy=3.673 | Unique=  45 | Total copies=  1016 | Avg len=3.6 | Max len=8 | tRNA candidates=0
#
#   Cycle  91: Longest RNA = CCUGGACA (length=8)
#   Cycle  92: Longest RNA = CCUGGACA (length=8)
#   Cycle  93: Longest RNA = CCUGGACA (length=8)
#   Cycle  94: Longest RNA = CCUGGACA (length=8)
#   Cycle  95: Longest RNA = AAGGGCUGC (length=9)
#   [Record] Cycle  95: Entropy=3.646 | Unique=  43 | Total copies=  1005 | Avg len=3.7 | Max len=9 | tRNA candidates=0
#
#   Cycle  96: Longest RNA = AAGGGCUGC (length=9)
#   Cycle  97: Longest RNA = AAGGGCUGC (length=9)
#   Cycle  98: Longest RNA = AAGGGCUGC (length=9)
#   Cycle  99: Longest RNA = AAGGGCUGC (length=9)
#   Cycle 100: Longest RNA = AAGGGCUGC (length=9)
#   [Record] Cycle 100: Entropy=3.600 | Unique=  40 | Total copies=  1028 | Avg len=3.6 | Max len=9 | tRNA candidates=0
#
#   Cycle 101: Longest RNA = AAGGGCUGC (length=9)
#   Cycle 102: Longest RNA = AAGGGCUGC (length=9)
#   Cycle 103: Longest RNA = CCUGGACA (length=8)
#   Cycle 104: Longest RNA = CCUGGACA (length=8)
#   Cycle 105: Longest RNA = CCUGGACA (length=8)
#   [Record] Cycle 105: Entropy=3.537 | Unique=  39 | Total copies=  1033 | Avg len=3.3 | Max len=8 | tRNA candidates=0
#
#   Cycle 106: Longest RNA = AGGGCUGC (length=8)
#   Cycle 107: Longest RNA = AGGGCUGC (length=8)
#   Cycle 108: Longest RNA = AGGGCUGC (length=8)
#   Cycle 109: Longest RNA = AGGGCUGC (length=8)
#   Cycle 110: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 110: Entropy=3.593 | Unique=  37 | Total copies=  1014 | Avg len=3.2 | Max len=8 | tRNA candidates=0
#
#   Cycle 111: Longest RNA = AGGGCUGC (length=8)
#   Cycle 112: Longest RNA = AGGGCUGC (length=8)
#   Cycle 113: Longest RNA = AGGGCUGC (length=8)
#   Cycle 114: Longest RNA = AGGGCUGC (length=8)
#   Cycle 115: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 115: Entropy=3.526 | Unique=  35 | Total copies=   987 | Avg len=3.1 | Max len=8 | tRNA candidates=0
#
#   Cycle 116: Longest RNA = AGGGCUGC (length=8)
#   Cycle 117: Longest RNA = AGGGCUGC (length=8)
#   Cycle 118: Longest RNA = AGGGCUGC (length=8)
#   Cycle 119: Longest RNA = AGGGCUGC (length=8)
#   Cycle 120: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 120: Entropy=3.458 | Unique=  34 | Total copies=   970 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 121: Longest RNA = AGGGCUGC (length=8)
#   Cycle 122: Longest RNA = AGGGCUGC (length=8)
#   Cycle 123: Longest RNA = AGGGCUGC (length=8)
#   Cycle 124: Longest RNA = AGGGCUGC (length=8)
#   Cycle 125: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 125: Entropy=3.447 | Unique=  27 | Total copies=   969 | Avg len=2.5 | Max len=8 | tRNA candidates=0
#
#   Cycle 126: Longest RNA = AGGGCUGC (length=8)
#   Cycle 127: Longest RNA = AGGGCUGC (length=8)
#   Cycle 128: Longest RNA = AGGGCUGC (length=8)
#   Cycle 129: Longest RNA = AGGGCUGC (length=8)
#   Cycle 130: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 130: Entropy=3.471 | Unique=  30 | Total copies=  1008 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 131: Longest RNA = AGGGCUGC (length=8)
#   Cycle 132: Longest RNA = AGGGCUGC (length=8)
#   Cycle 133: Longest RNA = AGGGCUGC (length=8)
#   Cycle 134: Longest RNA = AGGGCUGC (length=8)
#   Cycle 135: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 135: Entropy=3.478 | Unique=  29 | Total copies=  1075 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 136: Longest RNA = AGGGCUGC (length=8)
#   Cycle 137: Longest RNA = AGGGCUGC (length=8)
#   Cycle 138: Longest RNA = AGGGCUGC (length=8)
#   Cycle 139: Longest RNA = AGGGCUGC (length=8)
#   Cycle 140: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 140: Entropy=3.455 | Unique=  32 | Total copies=  1069 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = AGGGCUGC (length=8)
#   Cycle 142: Longest RNA = AGGGCUGC (length=8)
#   Cycle 143: Longest RNA = AGGGCUGC (length=8)
#   Cycle 144: Longest RNA = AGGGCUGC (length=8)
#   Cycle 145: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 145: Entropy=3.548 | Unique=  36 | Total copies=  1008 | Avg len=2.7 | Max len=8 | tRNA candidates=0
#
#   Cycle 146: Longest RNA = AGGGCUGC (length=8)
#   Cycle 147: Longest RNA = AGGGCUGC (length=8)
#   Cycle 148: Longest RNA = AGGGCUGC (length=8)
#   Cycle 149: Longest RNA = AGGGCUGC (length=8)
#   Cycle 150: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 150: Entropy=3.446 | Unique=  37 | Total copies=   963 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 151: Longest RNA = AGGGCUGC (length=8)
#   Cycle 152: Longest RNA = AGGGCUGC (length=8)
#   Cycle 153: Longest RNA = AGGGCUGC (length=8)
#   Cycle 154: Longest RNA = AGGGCUGC (length=8)
#   Cycle 155: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 155: Entropy=3.539 | Unique=  35 | Total copies=  1071 | Avg len=2.7 | Max len=8 | tRNA candidates=0
#
#   Cycle 156: Longest RNA = AGGGCUGC (length=8)
#   Cycle 157: Longest RNA = AGGGCUGC (length=8)
#   Cycle 158: Longest RNA = AGGGCUGC (length=8)
#   Cycle 159: Longest RNA = AGGGCUGC (length=8)
#   Cycle 160: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 160: Entropy=3.512 | Unique=  36 | Total copies=  1041 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 161: Longest RNA = AGGGCUGC (length=8)
#   Cycle 162: Longest RNA = AGGGCUGC (length=8)
#   Cycle 163: Longest RNA = AGGGCUGC (length=8)
#   Cycle 164: Longest RNA = AGGGCUGC (length=8)
#   Cycle 165: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 165: Entropy=3.516 | Unique=  38 | Total copies=  1017 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = AGGGCUGC (length=8)
#   Cycle 167: Longest RNA = AGGGCUGC (length=8)
#   Cycle 168: Longest RNA = AGGGCUGC (length=8)
#   Cycle 169: Longest RNA = AGGGCUGC (length=8)
#   Cycle 170: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 170: Entropy=3.593 | Unique=  40 | Total copies=   986 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 171: Longest RNA = AGGGCUGC (length=8)
#   Cycle 172: Longest RNA = AGGGCUGC (length=8)
#   Cycle 173: Longest RNA = AGGGCUGC (length=8)
#   Cycle 174: Longest RNA = AGGGCUGC (length=8)
#   Cycle 175: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 175: Entropy=3.611 | Unique=  39 | Total copies=  1033 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 176: Longest RNA = AGGGCUGC (length=8)
#   Cycle 177: Longest RNA = AGGGCUGC (length=8)
#   Cycle 178: Longest RNA = AGGGCUGC (length=8)
#   Cycle 179: Longest RNA = AGGGCUGC (length=8)
#   Cycle 180: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 180: Entropy=3.518 | Unique=  37 | Total copies=  1017 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 181: Longest RNA = AGGGCUGC (length=8)
#   Cycle 182: Longest RNA = AGGGCUGC (length=8)
#   Cycle 183: Longest RNA = AGGGCUGC (length=8)
#   Cycle 184: Longest RNA = AGGGCUGC (length=8)
#   Cycle 185: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 185: Entropy=3.592 | Unique=  33 | Total copies=  1071 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 186: Longest RNA = AGGGCUGC (length=8)
#   Cycle 187: Longest RNA = AGGGCUGC (length=8)
#   Cycle 188: Longest RNA = AGGGCUGC (length=8)
#   Cycle 189: Longest RNA = AGGGCUGC (length=8)
#   Cycle 190: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 190: Entropy=3.508 | Unique=  33 | Total copies=  1053 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 191: Longest RNA = AGGGCUGC (length=8)
#   Cycle 192: Longest RNA = AGGGCUGC (length=8)
#   Cycle 193: Longest RNA = AGGGCUGC (length=8)
#   Cycle 194: Longest RNA = AGGGCUGC (length=8)
#   Cycle 195: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 195: Entropy=3.605 | Unique=  42 | Total copies=  1047 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 196: Longest RNA = AGGGCUGC (length=8)
#   Cycle 197: Longest RNA = AGGGCUGC (length=8)
#   Cycle 198: Longest RNA = AGGGCUGC (length=8)
#   Cycle 199: Longest RNA = AGGGCUGC (length=8)
#   Cycle 200: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 200: Entropy=3.565 | Unique=  38 | Total copies=  1047 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 201: Longest RNA = AGGGCUGC (length=8)
#   Cycle 202: Longest RNA = AGGGCUGC (length=8)
#   Cycle 203: Longest RNA = AGGGCUGC (length=8)
#   Cycle 204: Longest RNA = AGGGCUGC (length=8)
#   Cycle 205: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 205: Entropy=3.550 | Unique=  32 | Total copies=  1004 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 206: Longest RNA = AGGGCUGC (length=8)
#   Cycle 207: Longest RNA = AGGGCUGC (length=8)
#   Cycle 208: Longest RNA = AGGGCUGC (length=8)
#   Cycle 209: Longest RNA = AGGGCUGC (length=8)
#   Cycle 210: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 210: Entropy=3.479 | Unique=  29 | Total copies=  1012 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 211: Longest RNA = AGGGCUGC (length=8)
#   Cycle 212: Longest RNA = AGGGCUGC (length=8)
#   Cycle 213: Longest RNA = AGGGCUGC (length=8)
#   Cycle 214: Longest RNA = AGGGCUGC (length=8)
#   Cycle 215: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 215: Entropy=3.520 | Unique=  34 | Total copies=  1021 | Avg len=2.7 | Max len=8 | tRNA candidates=0
#
#   Cycle 216: Longest RNA = AGGGCUGC (length=8)
#   Cycle 217: Longest RNA = AGGGCUGC (length=8)
#   Cycle 218: Longest RNA = AGGGCUGC (length=8)
#   Cycle 219: Longest RNA = AGGGCUGC (length=8)
#   Cycle 220: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 220: Entropy=3.481 | Unique=  32 | Total copies=   974 | Avg len=2.6 | Max len=8 | tRNA candidates=0
#
#   Cycle 221: Longest RNA = AGGGCUGC (length=8)
#   Cycle 222: Longest RNA = AGGGCUGC (length=8)
#   Cycle 223: Longest RNA = AGGGCUGC (length=8)
#   Cycle 224: Longest RNA = AGGGCUGC (length=8)
#   Cycle 225: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 225: Entropy=3.533 | Unique=  36 | Total copies=  1011 | Avg len=2.8 | Max len=8 | tRNA candidates=0
#
#   Cycle 226: Longest RNA = AGGGCUGC (length=8)
#   Cycle 227: Longest RNA = AGGGCUGC (length=8)
#   Cycle 228: Longest RNA = AGGGCUGC (length=8)
#   Cycle 229: Longest RNA = AGGGCUGC (length=8)
#   Cycle 230: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 230: Entropy=3.543 | Unique=  39 | Total copies=  1004 | Avg len=2.7 | Max len=8 | tRNA candidates=0
#
#   Cycle 231: Longest RNA = AGGGCUGC (length=8)
#   Cycle 232: Longest RNA = AGGGCUGC (length=8)
#   Cycle 233: Longest RNA = AGGGCUGC (length=8)
#   Cycle 234: Longest RNA = AGGGCUGC (length=8)
#   Cycle 235: Longest RNA = AGGGCUGC (length=8)
#   [Record] Cycle 235: Entropy=3.490 | Unique=  31 | Total copies=   975 | Avg len=2.7 | Max len=8 | tRNA candidates=0
#
#   Cycle 236: Longest RNA = AGGGCUGC (length=8)
#   Cycle 237: Longest RNA = AGGGCUGC (length=8)
#   Cycle 238: Longest RNA = GCGCU (length=5)
#   Cycle 239: Longest RNA = GCGCU (length=5)
#   Cycle 240: Longest RNA = GCGCU (length=5)
#   [Record] Cycle 240: Entropy=3.517 | Unique=  35 | Total copies=  1017 | Avg len=2.5 | Max len=5 | tRNA candidates=0
#
#   Cycle 241: Longest RNA = GCGCU (length=5)
#   Cycle 242: Longest RNA = GUA (length=3)
#   Cycle 243: Longest RNA = GUA (length=3)
#   Cycle 244: Longest RNA = GUA (length=3)
#   Cycle 245: Longest RNA = ACG (length=3)
#   [Record] Cycle 245: Entropy=3.429 | Unique=  27 | Total copies=  1004 | Avg len=2.3 | Max len=3 | tRNA candidates=0
#
#   Cycle 246: Longest RNA = ACG (length=3)
#   Cycle 247: Longest RNA = ACG (length=3)
#   Cycle 248: Longest RNA = ACG (length=3)
#   Cycle 249: Longest RNA = ACG (length=3)
#   Cycle 250: Longest RNA = UCA (length=3)
#   [Record] Cycle 250: Entropy=3.465 | Unique=  32 | Total copies=  1053 | Avg len=2.4 | Max len=3 | tRNA candidates=0
#
#   Cycle 251: Longest RNA = UCA (length=3)
#   Cycle 252: Longest RNA = UCA (length=3)
#   Cycle 253: Longest RNA = UCA (length=3)
#   Cycle 254: Longest RNA = UCA (length=3)
#   Cycle 255: Longest RNA = GCC (length=3)
#   [Record] Cycle 255: Entropy=3.438 | Unique=  34 | Total copies=  1018 | Avg len=2.5 | Max len=3 | tRNA candidates=0
#
#   Cycle 256: Longest RNA = GCC (length=3)
#   Cycle 257: Longest RNA = GCC (length=3)
#   Cycle 258: Longest RNA = GCC (length=3)
#   Cycle 259: Longest RNA = GUCC (length=4)
#   Cycle 260: Longest RNA = GUCC (length=4)
#   [Record] Cycle 260: Entropy=3.387 | Unique=  24 | Total copies=  1050 | Avg len=2.2 | Max len=4 | tRNA candidates=0
#
#   Cycle 261: Longest RNA = GUCC (length=4)
#   Cycle 262: Longest RNA = GUCC (length=4)
#   Cycle 263: Longest RNA = GUCC (length=4)
#   Cycle 264: Longest RNA = GUCC (length=4)
#   Cycle 265: Longest RNA = GUCC (length=4)
#   [Record] Cycle 265: Entropy=3.548 | Unique=  38 | Total copies=  1033 | Avg len=2.6 | Max len=4 | tRNA candidates=0
#
#   Cycle 266: Longest RNA = GUCC (length=4)
#   Cycle 267: Longest RNA = GUCC (length=4)
#   Cycle 268: Longest RNA = GUCC (length=4)
#   Cycle 269: Longest RNA = GUCC (length=4)
#   Cycle 270: Longest RNA = GUCC (length=4)
#   [Record] Cycle 270: Entropy=3.523 | Unique=  35 | Total copies=  1028 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
#   Cycle 271: Longest RNA = GUCC (length=4)
#   Cycle 272: Longest RNA = GUCC (length=4)
#   Cycle 273: Longest RNA = GUCC (length=4)
#   Cycle 274: Longest RNA = GUCC (length=4)
#   Cycle 275: Longest RNA = GUCC (length=4)
#   [Record] Cycle 275: Entropy=3.453 | Unique=  31 | Total copies=   984 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
#   Cycle 276: Longest RNA = GUCC (length=4)
#   Cycle 277: Longest RNA = GUCC (length=4)
#   Cycle 278: Longest RNA = GUCC (length=4)
#   Cycle 279: Longest RNA = GUCC (length=4)
#   Cycle 280: Longest RNA = GUCC (length=4)
#   [Record] Cycle 280: Entropy=3.499 | Unique=  28 | Total copies=  1027 | Avg len=2.4 | Max len=4 | tRNA candidates=0
#
#   Cycle 281: Longest RNA = GUCC (length=4)
#   Cycle 282: Longest RNA = GUCC (length=4)
#   Cycle 283: Longest RNA = GUCC (length=4)
#   Cycle 284: Longest RNA = GUCC (length=4)
#   Cycle 285: Longest RNA = GUCC (length=4)
#   [Record] Cycle 285: Entropy=3.486 | Unique=  34 | Total copies=  1016 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
#   Cycle 286: Longest RNA = GUCC (length=4)
#   Cycle 287: Longest RNA = GUCC (length=4)
#   Cycle 288: Longest RNA = GUCC (length=4)
#   Cycle 289: Longest RNA = GUCC (length=4)
#   Cycle 290: Longest RNA = GUCC (length=4)
#   [Record] Cycle 290: Entropy=3.558 | Unique=  34 | Total copies=  1003 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
#   Cycle 291: Longest RNA = GUCC (length=4)
#   Cycle 292: Longest RNA = GUCC (length=4)
#   Cycle 293: Longest RNA = GUCC (length=4)
#   Cycle 294: Longest RNA = GUCC (length=4)
#   Cycle 295: Longest RNA = GUCC (length=4)
#   [Record] Cycle 295: Entropy=3.485 | Unique=  34 | Total copies=  1011 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
#   Cycle 296: Longest RNA = GUCC (length=4)
#   Cycle 297: Longest RNA = GUCC (length=4)
#   Cycle 298: Longest RNA = GUCC (length=4)
#   Cycle 299: Longest RNA = GUCC (length=4)
#   [Record] Cycle 299: Entropy=3.533 | Unique=  34 | Total copies=  1006 | Avg len=2.5 | Max len=4 | tRNA candidates=0
#
# ----------------------------------------------------------------------
# Simulation complete!
# ================================================================================
# Top 15 Most Frequent Sequences
# ================================================================================
#  1. [   22] CU                                                      (stability=0.200)
#  2. [   20] UU                                                      (stability=0.200)
#  3. [   20] CA                                                      (stability=0.200)
#  4. [   19] GU                                                      (stability=0.200)
#  5. [   18] UG                                                      (stability=0.200)
#  6. [   18] CG                                                      (stability=0.200)
#  7. [   17] AU                                                      (stability=0.200)
#  8. [   17] GC                                                      (stability=0.200)
#  9. [   16] CC                                                      (stability=0.200)
# 10. [   14] UC                                                      (stability=0.200)
# 11. [   13] AA                                                      (stability=0.200)
# 12. [   13] AC                                                      (stability=0.200)
# 13. [   12] UA                                                      (stability=0.200)
# 14. [   11] AG                                                      (stability=0.200)
# 15. [   10] GA                                                      (stability=0.200)
#
#
# ================================================================================
# Simulation Summary
# ================================================================================
# Final unique sequences (length>1): 30
# Final total copies (all): 1006
# Final entropy: 3.533 bits
# Sequence length range: 2 - 4 nt
# Average sequence length: 2.5 nt
#
# Entropy reduction: -0.36 bits (from 3.18 to 3.53)
#   ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.
#
# Longest sequence discovered: GUCC
#   Length: 4 nt

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1000
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 50
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.05
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #    - Higher harshness = faster selection but may lose diversity
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'heuristic'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 300                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.0          # 2% of initial pool per cycle
    LIGATION_PROB = 0.1                     # Base ligation probability
    HARSHNESS = 0.8                          # Environmental harshness
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Configuration:
#   Stability calculation method: HEURISTIC
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 300
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation probability (base): 0.1
#   Environmental harshness: 0.8
#     (Higher = more extreme conditions, stability differences amplified)
#
#   Using heuristic stability calculation
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 199
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.8
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation base probability: 0.1
#
# Starting simulation: 300 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = UCAUCU (length=6)
#   [Record] Cycle   0: Entropy=3.234 | Unique= 103 | Total copies=  3350 | Avg len=5.4 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = CCGCCG (length=6)
#   Cycle   2: Longest RNA = GCGCAUU (length=7)
#   Cycle   3: Longest RNA = CCGCCG (length=6)
#   Cycle   4: Longest RNA = AGAACUA (length=7)
#   Cycle   5: Longest RNA = UCCGCU (length=6)
#   [Record] Cycle   5: Entropy=3.912 | Unique=  16 | Total copies=    27 | Avg len=4.1 | Max len=6 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = AGAACU (length=6)
#   Cycle   7: Longest RNA = GAGACC (length=6)
#   Cycle   8: Longest RNA = GGUAGA (length=6)
#   Cycle   9: Longest RNA = GGUAGA (length=6)
#   Cycle  10: Longest RNA = GGUAGA (length=6)
#   [Record] Cycle  10: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = GGUAGA (length=6)
#   Cycle  12: Longest RNA = GGUAGA (length=6)
#   Cycle  13: Longest RNA = ACACCC (length=6)
#   Cycle  14: Longest RNA = UCUCUA (length=6)
#   Cycle  15: Longest RNA = UCUCUA (length=6)
#   [Record] Cycle  15: Entropy=3.499 | Unique=  12 | Total copies=    17 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = CAAGGCUGGAAU (length=12)
#   Cycle  17: Longest RNA = UGGAAUCAAGGC (length=12)
#   Cycle  18: Longest RNA = CACGCA (length=6)
#   Cycle  19: Longest RNA = UCUGCC (length=6)
#   Cycle  20: Longest RNA = GUUCGA (length=6)
#   [Record] Cycle  20: Entropy=4.629 | Unique=  27 | Total copies=    38 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = GUUCGA (length=6)
#   Cycle  22: Longest RNA = CAUCUA (length=6)
#   Cycle  23: Longest RNA = CCCAGG (length=6)
#   Cycle  24: Longest RNA = CCCAGG (length=6)
#   Cycle  25: Longest RNA = CCCAGG (length=6)
#   [Record] Cycle  25: Entropy=1.000 | Unique=   2 | Total copies=     2 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = CCCAGG (length=6)
#   Cycle  27: Longest RNA = UCCGGG (length=6)
#   Cycle  28: Longest RNA = UCCUCA (length=6)
#   Cycle  29: Longest RNA = GGAUAU (length=6)
#   Cycle  30: Longest RNA = CCGUUG (length=6)
#   [Record] Cycle  30: Entropy=1.922 | Unique=   4 | Total copies=     5 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = UGAACG (length=6)
#   Cycle  32: Longest RNA = UGAACG (length=6)
#   Cycle  33: Longest RNA = UGAACG (length=6)
#   Cycle  34: Longest RNA = CCCGGC (length=6)
#   Cycle  35: Longest RNA = CCCGGC (length=6)
#   [Record] Cycle  35: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = AGGCGG (length=6)
#   Cycle  37: Longest RNA = AGGCGG (length=6)
#   Cycle  38: Longest RNA = AGGCGG (length=6)
#   Cycle  39: Longest RNA = GCCGUACGCGCG (length=12)
#   Cycle  40: Longest RNA = GCCGUACGCGCG (length=12)
#   [Record] Cycle  40: Entropy=2.500 | Unique=   6 | Total copies=     8 | Avg len=7.0 | Max len=12 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = GCCGUACGCGCGCGCGCG (length=18)
#   Cycle  42: Longest RNA = GCCGUACGCGCGCGCGCG (length=18)
#   Cycle  43: Longest RNA = GCCGUACGCGCGGCCGUACGCGCG (length=24)
#   Cycle  44: Longest RNA = GCCGUACGCGCGGCCGUACGCGCG (length=24)
#   Cycle  45: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCG (length=36)
#   [Record] Cycle  45: Entropy=1.459 | Unique=   3 | Total copies=     6 | Avg len=22.0 | Max len=36 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=54)
#   Cycle  47: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=54)
#   Cycle  48: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCG (length=36)
#   Cycle  49: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCG (length=36)
#   Cycle  50: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCG (length=36)
#   [Record] Cycle  50: Entropy=0.918 | Unique=   2 | Total copies=     6 | Avg len=27.0 | Max len=36 | tRNA candidates=1
#
#   Cycle  51: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=72)
#   Cycle  52: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=72)
#   Cycle  53: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=72)
#   Cycle  54: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=126)
#   Cycle  55: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=126)
#   [Record] Cycle  55: Entropy=1.922 | Unique=   4 | Total copies=    10 | Avg len=67.5 | Max len=126 | tRNA candidates=3
#
#   Cycle  56: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=126)
#   Cycle  57: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=126)
#   Cycle  58: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=126)
#   Cycle  59: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  60: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  60: Entropy=2.507 | Unique=   6 | Total copies=    13 | Avg len=84.0 | Max len=144 | tRNA candidates=4
#
#   Cycle  61: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  62: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  63: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  64: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  65: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  65: Entropy=2.419 | Unique=   6 | Total copies=     9 | Avg len=99.0 | Max len=144 | tRNA candidates=2
#
#   Cycle  66: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  67: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  68: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  69: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  70: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  70: Entropy=2.200 | Unique=   5 | Total copies=    13 | Avg len=93.6 | Max len=144 | tRNA candidates=4
#
#   Cycle  71: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  72: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  73: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  74: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  75: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  75: Entropy=1.157 | Unique=   3 | Total copies=    10 | Avg len=114.0 | Max len=144 | tRNA candidates=2
#
#   Cycle  76: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  77: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  78: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  79: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  80: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  80: Entropy=1.485 | Unique=   3 | Total copies=    10 | Avg len=114.0 | Max len=144 | tRNA candidates=3
#
#   Cycle  81: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  82: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  83: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  84: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  85: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  85: Entropy=1.352 | Unique=   3 | Total copies=     9 | Avg len=114.0 | Max len=144 | tRNA candidates=2
#
#   Cycle  86: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  87: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  88: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  89: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  90: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  90: Entropy=1.530 | Unique=   3 | Total copies=     9 | Avg len=114.0 | Max len=144 | tRNA candidates=3
#
#   Cycle  91: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  92: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  93: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  94: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  95: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle  95: Entropy=1.459 | Unique=   3 | Total copies=     6 | Avg len=114.0 | Max len=144 | tRNA candidates=2
#
#   Cycle  96: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  97: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  98: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle  99: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 100: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 100: Entropy=1.500 | Unique=   3 | Total copies=     4 | Avg len=114.0 | Max len=144 | tRNA candidates=1
#
#   Cycle 101: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 102: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 103: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 104: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 105: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 105: Entropy=0.918 | Unique=   2 | Total copies=     6 | Avg len=126.0 | Max len=144 | tRNA candidates=2
#
#   Cycle 106: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 107: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 108: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 109: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 110: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 110: Entropy=0.811 | Unique=   2 | Total copies=     4 | Avg len=126.0 | Max len=144 | tRNA candidates=1
#
#   Cycle 111: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 112: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 113: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 114: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 115: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 115: Entropy=0.544 | Unique=   2 | Total copies=     8 | Avg len=126.0 | Max len=144 | tRNA candidates=1
#
#   Cycle 116: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 117: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 118: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 119: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 120: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 120: Entropy=0.918 | Unique=   2 | Total copies=     3 | Avg len=126.0 | Max len=144 | tRNA candidates=1
#
#   Cycle 121: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 122: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 123: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 124: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 125: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 125: Entropy=1.000 | Unique=   2 | Total copies=     6 | Avg len=126.0 | Max len=144 | tRNA candidates=2
#
#   Cycle 126: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 127: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 128: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 129: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 130: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   [Record] Cycle 130: Entropy=0.722 | Unique=   2 | Total copies=     5 | Avg len=126.0 | Max len=144 | tRNA candidates=1
#
#   Cycle 131: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=144)
#   Cycle 132: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 133: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 134: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 135: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 135: Entropy=0.000 | Unique=   1 | Total copies=     3 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 136: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 137: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 138: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 139: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 140: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 140: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 142: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 143: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 144: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 145: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 145: Entropy=0.000 | Unique=   1 | Total copies=     2 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 146: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 147: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 148: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 149: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 150: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 150: Entropy=0.000 | Unique=   1 | Total copies=     4 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 151: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 152: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 153: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 154: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 155: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 155: Entropy=0.000 | Unique=   1 | Total copies=     3 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 156: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 157: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 158: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 159: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 160: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 160: Entropy=0.000 | Unique=   1 | Total copies=     4 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 161: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 162: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 163: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 164: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 165: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 165: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 167: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 168: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 169: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 170: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 170: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 171: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 172: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 173: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 174: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 175: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 175: Entropy=0.000 | Unique=   1 | Total copies=     2 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 176: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 177: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 178: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 179: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 180: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 180: Entropy=0.000 | Unique=   1 | Total copies=     4 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 181: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 182: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 183: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 184: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 185: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 185: Entropy=0.000 | Unique=   1 | Total copies=     3 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 186: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 187: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 188: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 189: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 190: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 190: Entropy=0.000 | Unique=   1 | Total copies=     3 | Avg len=108.0 | Max len=108 | tRNA candidates=1
#
#   Cycle 191: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 192: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 193: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 194: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 195: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 195: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 196: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 197: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 198: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 199: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 200: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 200: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 201: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 202: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 203: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 204: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 205: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 205: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 206: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 207: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 208: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 209: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 210: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   [Record] Cycle 210: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=108.0 | Max len=108 | tRNA candidates=0
#
#   Cycle 211: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 212: Longest RNA = GCCGUACGCGCGCGCGCGGCCGUACGCGCGCGCGCGGCCGUACGCGCGCG... (length=108)
#   Cycle 213: Longest RNA = AUUCCA (length=6)
#   Cycle 214: Longest RNA = UAUGUG (length=6)
#   Cycle 215: Longest RNA = UAUGUG (length=6)
#   [Record] Cycle 215: Entropy=2.922 | Unique=   8 | Total copies=    10 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle 216: Longest RNA = UUGAAUUUGAAU (length=12)
#   Cycle 217: Longest RNA = UUGAAUUUGAAU (length=12)
#   Cycle 218: Longest RNA = UUGAAUUUGAAUUUGAAU (length=18)
#   Cycle 219: Longest RNA = UUGAAUUUGAAU (length=12)
#   Cycle 220: Longest RNA = UUGAAUUUGAAU (length=12)
#   [Record] Cycle 220: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=12.0 | Max len=12 | tRNA candidates=0
#
#   Cycle 221: Longest RNA = AAUCGC (length=6)
#   Cycle 222: Longest RNA = AAUCGC (length=6)
#   Cycle 223: Longest RNA = CUGGAC (length=6)
#   Cycle 224: Longest RNA = CUGGAC (length=6)
#   Cycle 225: Longest RNA = AACCGU (length=6)
#   [Record] Cycle 225: Entropy=1.950 | Unique=   4 | Total copies=     7 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle 226: Longest RNA = GUGAAAGUGAAA (length=12)
#   Cycle 227: Longest RNA = UCCAGG (length=6)
#   Cycle 228: Longest RNA = AACCGC (length=6)
#   Cycle 229: Longest RNA = GGGCAU (length=6)
#   Cycle 230: Longest RNA = GAGAACGGCCCC (length=12)
#   [Record] Cycle 230: Entropy=3.873 | Unique=  16 | Total copies=    26 | Avg len=6.8 | Max len=12 | tRNA candidates=0
#
#   Cycle 231: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 232: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 233: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   Cycle 234: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   Cycle 235: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   [Record] Cycle 235: Entropy=1.500 | Unique=   3 | Total copies=     4 | Avg len=14.0 | Max len=24 | tRNA candidates=0
#
#   Cycle 236: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   Cycle 237: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   Cycle 238: Longest RNA = GAGAACGGCCCCGAGAACGGCCCC (length=24)
#   Cycle 239: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 240: Longest RNA = GAGAACGGCCCC (length=12)
#   [Record] Cycle 240: Entropy=0.000 | Unique=   1 | Total copies=     2 | Avg len=12.0 | Max len=12 | tRNA candidates=0
#
#   Cycle 241: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 242: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 243: Longest RNA = GAGAACGGCCCC (length=12)
#   Cycle 244: Longest RNA = GGACAU (length=6)
#   Cycle 245: Longest RNA = CGCAAG (length=6)
#   [Record] Cycle 245: Entropy=4.515 | Unique=  25 | Total copies=    35 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle 246: Longest RNA = CGCAAGGUCGAC (length=12)
#   Cycle 247: Longest RNA = CGCAAGGUCGAC (length=12)
#   Cycle 248: Longest RNA = GUCGACCGCAAGGUCGAC (length=18)
#   Cycle 249: Longest RNA = GUCGACCGCAAGGUCGAC (length=18)
#   Cycle 250: Longest RNA = CGCAAGGUCGAC (length=12)
#   [Record] Cycle 250: Entropy=2.252 | Unique=   5 | Total copies=     6 | Avg len=8.4 | Max len=12 | tRNA candidates=0
#
#   Cycle 251: Longest RNA = GUCGACGUUUGC (length=12)
#   Cycle 252: Longest RNA = GUCGACGUUUGC (length=12)
#   Cycle 253: Longest RNA = GUCGACGUUUGC (length=12)
#   Cycle 254: Longest RNA = GUCGAC (length=6)
#   Cycle 255: Longest RNA = GUCGAC (length=6)
#   [Record] Cycle 255: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle 256: Longest RNA = GUCGAC (length=6)
#   Cycle 257: Longest RNA = GUCGAC (length=6)
#   Cycle 258: Longest RNA = CGGAAA (length=6)
#   Cycle 259: Longest RNA = CUUAAG (length=6)
#   Cycle 260: Longest RNA = GGCAGGAACGGG (length=12)
#   [Record] Cycle 260: Entropy=3.837 | Unique=  15 | Total copies=    18 | Avg len=6.8 | Max len=12 | tRNA candidates=0
#
#   Cycle 261: Longest RNA = GGCAGGAACGGG (length=12)
#   Cycle 262: Longest RNA = CAUAUGGGCAGGAACGGG (length=18)
#   Cycle 263: Longest RNA = GGCAGGAACGGG (length=12)
#   Cycle 264: Longest RNA = GGCAGGAACGGG (length=12)
#   Cycle 265: Longest RNA = CAUAUGCAUAUG (length=12)
#   [Record] Cycle 265: Entropy=0.971 | Unique=   2 | Total copies=     5 | Avg len=9.0 | Max len=12 | tRNA candidates=0
#
#   Cycle 266: Longest RNA = CAUAUGCAUAUGCAUAUG (length=18)
#   Cycle 267: Longest RNA = CAUAUGCAUAUGCAUAUG (length=18)
#   Cycle 268: Longest RNA = CAUAUGCAUAUGCAUAUG (length=18)
#   Cycle 269: Longest RNA = CAUAUGCAUAUG (length=12)
#   Cycle 270: Longest RNA = CAUAUGCAUAUG (length=12)
#   [Record] Cycle 270: Entropy=0.000 | Unique=   1 | Total copies=     2 | Avg len=12.0 | Max len=12 | tRNA candidates=0
#
#   Cycle 271: Longest RNA = CAUAUGCAUAUG (length=12)
#   Cycle 272: Longest RNA = CAUAUGCAUAUG (length=12)
#   Cycle 273: Longest RNA = CAUAUGCAUAUG (length=12)
#   Cycle 274: Longest RNA = CAUAUGCAUAUG (length=12)
#   Cycle 275: Longest RNA = CAUAUGCAUAUG (length=12)
#   [Record] Cycle 275: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=12.0 | Max len=12 | tRNA candidates=0
#
#   Cycle 276: Longest RNA = UCUAGU (length=6)
#   Cycle 277: Longest RNA = UCUAGU (length=6)
#   Cycle 278: Longest RNA = CAGAUC (length=6)
#   Cycle 279: Longest RNA = UAUGUAGAUAGG (length=12)
#   Cycle 280: Longest RNA = UAUGUAGAUAGG (length=12)
#   [Record] Cycle 280: Entropy=3.022 | Unique=   9 | Total copies=    12 | Avg len=7.3 | Max len=12 | tRNA candidates=0
#
#   Cycle 281: Longest RNA = UAUGUAGAUAGG (length=12)
#   Cycle 282: Longest RNA = UAUGUAGAUAGGUAUGUA (length=18)
#   Cycle 283: Longest RNA = UAUGUAGAUAGGUAUGUA (length=18)
#   Cycle 284: Longest RNA = UAUGUAGAUAGGUAUGUAUAUGUAGAUAGGUAUGUA (length=36)
#   Cycle 285: Longest RNA = UAUGUAGAUAGGUAUGUA (length=18)
#   [Record] Cycle 285: Entropy=1.000 | Unique=   2 | Total copies=     2 | Avg len=15.0 | Max len=18 | tRNA candidates=0
#
#   Cycle 286: Longest RNA = UAUGUAGAUAGGUAUGUA (length=18)
#   Cycle 287: Longest RNA = UAUGUAGAUAGGUAUGUA (length=18)
#   Cycle 288: Longest RNA = AAUGGC (length=6)
#   Cycle 289: Longest RNA = CGUUUCGGGCAA (length=12)
#   Cycle 290: Longest RNA = CGUUUCGGGCAA (length=12)
#   [Record] Cycle 290: Entropy=3.637 | Unique=  15 | Total copies=    24 | Avg len=6.8 | Max len=12 | tRNA candidates=0
#
#   Cycle 291: Longest RNA = GUAUGCUUAGAG (length=12)
#   Cycle 292: Longest RNA = GUAUGCUUAGAG (length=12)
#   Cycle 293: Longest RNA = AGACCU (length=6)
#   Cycle 294: Longest RNA = AGACCU (length=6)
#   Cycle 295: Longest RNA = AAACGC (length=6)
#   [Record] Cycle 295: Entropy=0.000 | Unique=   1 | Total copies=     1 | Avg len=6.0 | Max len=6 | tRNA candidates=0
#
#   Cycle 296: Longest RNA = AAACGC (length=6)
#   Cycle 297: Longest RNA = CCUCAC (length=6)
#   Cycle 298: Longest RNA = AUAGUGGUUCUA (length=12)
#   Cycle 299: Longest RNA = CAGCGGCAUUAG (length=12)
#   [Record] Cycle 299: Entropy=3.239 | Unique=  10 | Total copies=    13 | Avg len=6.6 | Max len=12 | tRNA candidates=0
#
# ----------------------------------------------------------------------
# Simulation complete!
# ================================================================================
# Top 15 Most Frequent Sequences
# ================================================================================
#  1. [    2] CAGCGG                                                  (stability=0.513)
#  2. [    2] AGUACU                                                  (stability=0.607)
#  3. [    2] GCUGAC                                                  (stability=0.367)
#  4. [    1] CAUUAG                                                  (stability=0.340)
#  5. [    1] AACGCU                                                  (stability=0.487)
#  6. [    1] CUCAUA                                                  (stability=0.207)
#  7. [    1] AUAGUG                                                  (stability=0.207)
#  8. [    1] CGGCGU                                                  (stability=0.380)
#  9. [    1] CGCUUA                                                  (stability=0.220)
# 10. [    1] CAGCGGCAUUAG                                            (stability=0.520)
#
#
# ================================================================================
# Simulation Summary
# ================================================================================
# Final unique sequences (length>1): 10
# Final total copies (all): 13
# Final entropy: 3.239 bits
# Sequence length range: 6 - 12 nt
# Average sequence length: 6.6 nt
#
# Entropy reduction: -0.00 bits (from 3.23 to 3.24)
#   ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.
#
# Longest sequence discovered: CAGCGGCAUUAG
#   Length: 12 nt

# %% [markdown]
# In the origin of life, the appropriate intensity of environmental selection is crucial. If the environment is too harsh—such as excessively high temperature or extreme acidity—it may indiscriminately degrade almost any RNA sequence, including those with relatively stable structures, leaving little opportunity for complex molecules to accumulate. Conversely, an overly mild environment may fail to amplify the stability differences among sequences, resulting in a slow and inefficient distillation process.
#
# Moderate supplementation of ribonucleotides plays an important role in maintaining the total copy number of RNA molecules. Periodic addition of "food" (monomers) provides the raw materials necessary for polymerization and ligation during dry phases, preventing the system from going extinct due to resource depletion. However, excessive supplementation may reduce evolutionary pressure. When monomers are too abundant, even unstable and functionally irrelevant sequences can survive and replicate, reducing the selective advantage of stable, structure-forming RNAs. In such a "resource-rich" environment, the system may remain trapped at the stage of short, random sequences without ever progressing toward longer, functional molecules like tRNA-like structures.
#
# This phenomenon mirrors Darwinian natural selection: without sufficient selective pressure, evolution stalls; with too much pressure, diversity collapses. Only at the "Goldilocks" level of environmental stress and resource availability can the stability-distillation process effectively generate and accumulate informational macromolecules. This suggests that the origin of life is not merely a chemical inevitability but a finely balanced interplay between environmental conditions and molecular selection.
