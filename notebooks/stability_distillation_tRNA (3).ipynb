# %%
# Cell: Install Biopython for sequence alignment
# !pip install biopython

from Bio import pairwise2
from Bio.pairwise2 import format_alignment
# Out:
# Collecting biopython
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 41.7 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.87

# %%
# Cell 1: Install ViennaRNA
# !pip install viennarna

# Verify installation
try:
    import RNA
    VIENNA_AVAILABLE = True
    print("✓ ViennaRNA loaded successfully")
except ImportError:
    VIENNA_AVAILABLE = False
    print("⚠ ViennaRNA not available, using heuristic stability function")
    print("  Install with: !pip install viennarna")
# Out:
# Collecting viennarna
#   Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: viennarna
# Successfully installed viennarna-2.7.2
# ✓ ViennaRNA loaded successfully

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Stability-Distillation Hypothesis Simulation
Simulates wet-dry cycles driving RNA sequence frequency convergence and the emergence of tRNA-like structures.

Run in Google Colab:
    # !pip install viennarna
    then run this script.

Key mechanisms:
- Wet phase: Unstable sequences degrade based on thermal/acidic stress
- Dry phase: Frequent stable sequences ligate to form longer RNAs
- Nucleotide supplementation: Periodic monomer input from geothermal activity
- Stability difference amplification: Harsh conditions magnify stability disparities
"""

import numpy as np
import random
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
import warnings
warnings.filterwarnings('ignore')

# Try to import ViennaRNA for accurate stability calculation
try:
    import RNA
    VIENNA_AVAILABLE = True
    print("✓ ViennaRNA loaded successfully")
except ImportError:
    VIENNA_AVAILABLE = False
    print("⚠ ViennaRNA not available, using heuristic stability function")
    print("  Install with: !pip install viennarna")

# ============================================================================
# Part 1: Stability Calculation Functions
# ============================================================================

def calculate_stability_vienna(sequence, harshness=1.0):
    """
    Calculate RNA stability using ViennaRNA's minimum free energy (MFE).
    Directly uses MFE without length normalization - stable structures naturally have lower MFE.

    The harshness parameter amplifies stability differences:
    - harshness > 1.0: More extreme environment, stability differences magnified
    - harshness = 1.0: Normal environment
    - harshness < 1.0: Mild environment, stability differences reduced

    Args:
        sequence: RNA sequence string (A/U/G/C)
        harshness: Environmental harshness factor (amplifies stability differences)

    Returns:
        stability: normalized score 0-1 (higher = more stable)
        structure: dot-bracket secondary structure
        mfe: minimum free energy in kcal/mol
    """
    if len(sequence) < 4:
        return 0.2, "", 0

    try:
        fc = RNA.fold_compound(sequence)
        (ss, mfe) = fc.mfe()

        # Direct MFE usage - no length normalization!
        # MFE range: 0 to -50 kcal/mol (more negative = more stable)
        # Map to 0-1: -50 -> 1.0, 0 -> 0.0
        raw_stability = -mfe / 50.0
        stability = min(0.95, max(0.05, raw_stability))

        # Apply harshness: amplify the difference from baseline (0.5)
        # This makes stable sequences more stable, unstable ones more unstable
        if harshness != 1.0:
            # Center around 0.5, then stretch
            deviation = stability - 0.5
            stability = 0.5 + deviation * harshness
            stability = min(0.95, max(0.05, stability))

        return stability, ss, mfe

    except Exception as e:
        return calculate_stability_heuristic(sequence, harshness), "", 0


def calculate_stability_heuristic(sequence, harshness=1.0):
    """
    Heuristic stability calculation based on structural formation capability.
    Focuses on complementarity and stem-loop potential, not GC content bias.

    Args:
        sequence: RNA sequence string
        harshness: Environmental harshness factor

    Returns:
        stability: normalized score 0-1
    """
    if len(sequence) < 4:
        return 0.2

    comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}

    # 1. Self-complementarity detection (most important for stable folding)
    half_len = len(sequence) // 2
    complement_score = 0
    if half_len >= 1:
        first_half = sequence[:half_len]
        second_half_rev = sequence[half_len:][::-1]

        matches = 0
        for i in range(min(len(first_half), len(second_half_rev))):
            if comp_map.get(first_half[i], '') == second_half_rev[i]:
                matches += 1
        complement_score = matches / max(1, half_len)

    # 2. Local structure formation (ability to form hairpins and stems)
    structural_score = 0
    for i in range(len(sequence) - 3):
        for length in range(3, min(8, (len(sequence) - i) // 2)):
            left = sequence[i:i+length]
            right = sequence[i+length:i+2*length][::-1]

            if len(right) >= length:
                matches = 0
                for k in range(length):
                    if comp_map.get(left[k], '') == right[k]:
                        matches += 1
                pair_rate = matches / length
                if pair_rate > structural_score:
                    structural_score = pair_rate

    # 3. Base composition (reduced weight - structure matters more)
    gc_ratio = (sequence.count('G') + sequence.count('C')) / len(sequence)

    # 4. Stability = structural capability dominates
    # AU-rich sequences can be stable if they form good structures!
    stability = 0.1 + 0.5 * complement_score + 0.3 * structural_score + 0.1 * gc_ratio

    # 5. Long sequences with good structure get recognition
    if len(sequence) > 30 and structural_score > 0.5:
        stability = min(0.95, stability + 0.1)

    # Apply harshness: amplify stability differences
    if harshness != 1.0:
        deviation = stability - 0.5
        stability = 0.5 + deviation * harshness
        stability = min(0.95, max(0.05, stability))

    return stability


# Global variables for stability calculation
USE_VIENNA_GLOBAL = VIENNA_AVAILABLE
HARSHNESS_GLOBAL = 1.0

def get_stability(sequence):
    """
    Unified stability calculation interface.
    Uses global settings for ViennaRNA and harshness.

    Args:
        sequence: RNA sequence string

    Returns:
        stability: normalized score 0-1
    """
    if USE_VIENNA_GLOBAL and VIENNA_AVAILABLE and len(sequence) >= 4:
        stability, _, _ = calculate_stability_vienna(sequence, HARSHNESS_GLOBAL)
        return stability
    else:
        return calculate_stability_heuristic(sequence, HARSHNESS_GLOBAL)

# ============================================================================
# Part 2: Main Simulation Class
# ============================================================================

class StabilityDistillationSimulation:
    """
    Simulates the stability-distillation process for RNA sequence evolution.

    Key mechanisms:
    - Wet phase: Unstable sequences degrade (probability = 1 - stability^harshness)
    - Dry phase: Stable sequences serve as building blocks for ligation
    - Nucleotide supplementation: Periodic addition of monomers
    - Harshness: Environmental stress amplifies stability differences
    """

    def __init__(self,
                 initial_seq_length=6,
                 num_initial_sequences=200,
                 max_seq_length=150,
                 dry_growth_factor=1.3,
                 wet_degradation_strength=1.0,
                 ligation_base_prob=0.05,
                 supplementation_fraction=0.02,
                 initial_nucleotide_pool=1000,
                 harshness=1.0):
        """
        Initialize the simulation.

        Args:
            initial_seq_length: Length of randomly generated starting sequences
            num_initial_sequences: Number of initial sequences to generate
            max_seq_length: Maximum allowed sequence length (prevents unbounded growth)
            dry_growth_factor: Multiplication factor for copy numbers during dry phase
            wet_degradation_strength: Exponent controlling degradation strength (higher = more degradation)
            ligation_base_prob: Base probability for sequence ligation events
            supplementation_fraction: Fraction of INITIAL nucleotide pool to add as monomers each cycle
            initial_nucleotide_pool: Total number of ribonucleotide monomers available at start
            harshness: Environmental harshness factor (amplifies stability differences)
                      Higher values = more extreme conditions (hot, acidic)
                      Typical range: 0.5 (mild) to 2.0 (extreme)
        """
        self.max_seq_length = max_seq_length
        self.dry_growth_factor = dry_growth_factor
        self.wet_degradation_strength = wet_degradation_strength
        self.ligation_base_prob = ligation_base_prob
        self.supplementation_fraction = supplementation_fraction
        self.initial_nucleotide_pool = initial_nucleotide_pool
        self.harshness = harshness

        # Update global harshness for stability calculations
        global HARSHNESS_GLOBAL
        HARSHNESS_GLOBAL = harshness

        # Available nucleotides
        self.nucleotides = ['A', 'U', 'G', 'C']

        # Initialize sequence pool: generate random short sequences
        self.sequences = []
        for _ in range(num_initial_sequences):
            seq = ''.join(random.choice(self.nucleotides)
                         for _ in range(initial_seq_length))
            self.sequences.append(seq)

        # Frequency dictionary: sequence -> copy count
        self.frequencies = defaultdict(int)
        for seq in self.sequences:
            self.frequencies[seq] += 1

        # Add initial monomer pool
        for _ in range(initial_nucleotide_pool):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        # Track the current longest sequence for each cycle
        self.current_longest_sequence = ""

        # History tracking for visualization
        self.history = {
            'entropy': [],
            'num_unique_sequences': [],
            'avg_length': [],
            'total_copies': [],
            'max_length': [],
            'longest_sequence': [],
            'top_sequences': [],
            'trna_candidates': []
        }

        print(f"Simulation initialized")
        print(f"  Initial sequence count: {len(self.sequences)}")
        print(f"  Unique sequences: {len(self.frequencies)}")
        print(f"  Initial nucleotide pool: {self.initial_nucleotide_pool}")
        print(f"  ViennaRNA available: {VIENNA_AVAILABLE}")
        print(f"  Environmental harshness: {self.harshness}")
        print(f"  Supplementation fraction: {self.supplementation_fraction * 100:.1f}% of initial pool per cycle")
        print(f"  Ligation base probability: {self.ligation_base_prob}")

    def calculate_entropy(self):
        """
        Calculate Shannon entropy of the current sequence distribution.
        Lower entropy = more concentrated distribution = more information.

        Returns:
            entropy: Shannon entropy in bits
        """
        total = sum(self.frequencies.values())
        if total == 0:
            return 0
        entropy = 0
        for count in self.frequencies.values():
            p = count / total
            if p > 0:
                entropy -= p * np.log2(p)
        return entropy

    def get_longest_sequence(self):
        """
        Find the current longest RNA sequence in the pool.

        Returns:
            longest_seq: The longest sequence string
            max_len: Length of the longest sequence
        """
        if not self.frequencies:
            return "", 0

        # Filter out monomers (length 1) when looking for longest
        sequences_only = [seq for seq in self.frequencies.keys() if len(seq) > 1]
        if not sequences_only:
            return "", 0

        longest_seq = max(sequences_only, key=len)
        return longest_seq, len(longest_seq)

    def add_nucleotide_supplementation(self):
        """
        Add fresh ribonucleotide monomers to the pool.
        This simulates continuous input from the geothermal environment.

        The supplementation is added as monomers, which can be used
        during the dry phase to form new RNA sequences.

        Supplementation is anchored to the INITIAL nucleotide pool size,
        providing consistent input regardless of population fluctuations.
        """
        if self.supplementation_fraction <= 0:
            return 0

        # Calculate monomers to add based on INITIAL pool size
        num_monomers = max(1, int(self.initial_nucleotide_pool * self.supplementation_fraction))

        # Add monomers with balanced composition
        for _ in range(num_monomers):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        return num_monomers

    def is_trna_like(self, sequence):
        """
        Detect whether a sequence has tRNA-like structural potential.

        tRNA characteristics:
        - Can form cloverleaf structure with 3 or more stem-loop regions
        - Self-complementary regions allow stable folding
        - Typically 70-90 nucleotides in length

        Simplified detection: Look for 3 or more independent stem-loop regions
        where each stem has >=60% base pairing.

        Args:
            sequence: RNA sequence string

        Returns:
            True if the sequence exhibits tRNA-like characteristics
        """
        if len(sequence) < 30:
            return False

        # Base complementarity mapping
        comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}
        stem_regions = []

        # Sliding window to detect potential stem-loop structures
        for i in range(len(sequence) - 4):
            for length in range(3, min(8, (len(sequence) - i) // 2)):
                left = sequence[i:i+length]
                right = sequence[i+length:i+2*length][::-1]

                # Calculate pairing rate for this potential stem
                matches = 0
                for j in range(length):
                    if j < len(left) and j < len(right):
                        if comp_map.get(left[j], '') == right[j]:
                            matches += 1

                pairing_rate = matches / length if length > 0 else 0
                if pairing_rate >= 0.6:  # 60% or more base pairing
                    stem_regions.append((i, i+2*length, pairing_rate))

        # Merge overlapping regions
        merged = []
        for region in sorted(stem_regions, key=lambda x: x[0]):
            if not merged or region[0] > merged[-1][1] + 5:
                merged.append(region)

        # tRNA-like structures need at least 3 independent stem-loop regions
        return len(merged) >= 3

    def wet_phase(self):
        """
        Wet phase: Unstable sequences degrade.

        Degradation probability depends on:
        1. Sequence stability (higher stability = lower degradation)
        2. Environmental harshness (amplifies stability differences)
        3. Degradation strength parameter

        In harsh environments (high temperature, acidic), the difference
        between stable and unstable sequences is magnified.
        """
        new_frequencies = defaultdict(int)

        for seq, count in self.frequencies.items():
            stability = get_stability(seq)

            # Survival probability increases with stability
            # Harshness amplifies the difference:
            # - Stable sequences become MORE likely to survive
            # - Unstable sequences become LESS likely to survive
            survival_prob = stability ** (self.wet_degradation_strength * self.harshness)
            survived = np.random.binomial(count, survival_prob)

            if survived > 0:
                new_frequencies[seq] = survived

        self.frequencies = new_frequencies

        # If everything went extinct, reintroduce some random sequences
        if len(self.frequencies) == 0:
            for _ in range(50):
                seq = ''.join(random.choice(self.nucleotides)
                             for _ in range(6))
                self.frequencies[seq] += 1

    def dry_phase(self):
        """
        Dry phase: Sequence ligation and growth.

        Key mechanism from the stability-distillation hypothesis:
        - Frequent sequences are more likely to collide and ligate
        - Ligation probability ∝ frequency(a) × frequency(b)
        - This allows stable short sequences to serve as "stepping stones"
          for building longer, potentially more stable sequences.
        """
        total = sum(self.frequencies.values())
        if total == 0:
            return

        # Calculate frequency ratio for each sequence
        freq_ratio = {seq: count/total for seq, count in self.frequencies.items()}

        # Generate new sequences via ligation
        new_sequences = []
        seq_list = list(self.frequencies.keys())

        # Generate approximately 30% of current population as new ligation products
        num_ligations = int(total * 0.3)

        for _ in range(num_ligations):
            if len(seq_list) < 2:
                break

            # Weighted selection based on frequency
            weights = [freq_ratio.get(seq, 0) for seq in seq_list]
            if sum(weights) == 0:
                break

            # Select two sequences to ligate, weighted by their frequencies
            a = np.random.choice(seq_list, p=weights)
            b = np.random.choice(seq_list, p=weights)

            # Ligation probability is proportional to the product of their frequencies
            # This captures the "collision probability" concept
            p_ligate = self.ligation_base_prob * (freq_ratio[a] * freq_ratio[b] * 100)
            p_ligate = min(0.8, p_ligate)

            if random.random() < p_ligate:
                new_seq = a + b
                if len(new_seq) <= self.max_seq_length:
                    new_sequences.append(new_seq)

        # Add newly ligated sequences to the pool
        for seq in new_sequences:
            self.frequencies[seq] += 1

        # All sequences grow during dry phase (general polymerization)
        for seq in list(self.frequencies.keys()):
            growth = np.random.poisson(self.dry_growth_factor - 1)
            if growth > 0:
                self.frequencies[seq] += growth

    def step(self, cycle_number):
        """
        Execute one complete wet-dry cycle.

        Order:
        1. Wet phase: Degradation of unstable sequences
        2. Add fresh nucleotide supplementation (simulating geothermal input)
        3. Dry phase: Ligation and growth

        Args:
            cycle_number: Current cycle number (for logging)
        """
        # Step 1: Wet phase - degradation
        self.wet_phase()

        # Step 2: Add fresh nucleotide supplementation
        monomers_added = self.add_nucleotide_supplementation()

        # Step 3: Dry phase - ligation and growth
        self.dry_phase()

        # Track current longest sequence
        longest_seq, max_len = self.get_longest_sequence()
        self.current_longest_sequence = longest_seq

        # Print current longest sequence
        if longest_seq:
            display_seq = longest_seq[:50] + '...' if len(longest_seq) > 50 else longest_seq
            print(f"  Cycle {cycle_number:3d}: Longest RNA = {display_seq} (length={max_len})")

        return monomers_added

    def run(self, num_cycles=50, record_interval=5):
        """
        Run the simulation for a specified number of cycles.

        Args:
            num_cycles: Number of wet-dry cycles to simulate
            record_interval: How often to record statistics (cycles between records)
        """
        print(f"\nStarting simulation: {num_cycles} wet-dry cycles...")
        print("-" * 70)

        for cycle in range(num_cycles):
            monomers_added = self.step(cycle)

            # Record statistics at specified intervals
            if cycle % record_interval == 0 or cycle == num_cycles - 1:
                entropy = self.calculate_entropy()
                num_unique = len(self.frequencies)
                total = sum(self.frequencies.values())

                # Calculate average sequence length (excluding monomers)
                seq_lengths = [len(seq) for seq in self.frequencies.keys() if len(seq) > 1]
                avg_len = np.mean(seq_lengths) if seq_lengths else 0

                # Get current max length
                _, max_len = self.get_longest_sequence()

                # Get top 5 sequences by frequency
                top_seqs = Counter(self.frequencies).most_common(5)

                # Detect tRNA-like candidates
                trna_candidates = []
                for seq in list(self.frequencies.keys())[:50]:
                    if self.is_trna_like(seq) and self.frequencies[seq] > 1:
                        trna_candidates.append(seq)

                # Store history
                self.history['entropy'].append(entropy)
                self.history['num_unique_sequences'].append(num_unique)
                self.history['avg_length'].append(avg_len)
                self.history['total_copies'].append(total)
                self.history['max_length'].append(max_len)
                self.history['longest_sequence'].append(self.current_longest_sequence)
                self.history['top_sequences'].append(top_seqs)
                self.history['trna_candidates'].append(trna_candidates)

                print(f"  [Record] Cycle {cycle:3d}: Entropy={entropy:.3f} | Unique={num_unique:4d} | "
                      f"Total copies={total:6d} | Avg len={avg_len:.1f} | Max len={max_len} | "
                      f"tRNA candidates={len(trna_candidates)}")
                print()

        print("-" * 70)
        print("Simulation complete!")

    def plot_results(self):
        """
        Generate visualization plots showing key metrics over time.
        """
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # Generate x-axis values
        cycles = np.arange(len(self.history['entropy']))
        # Scale to approximate actual cycle numbers (if record_interval was 5)
        cycles_scaled = cycles * 5
        if len(cycles_scaled) < len(self.history['entropy']):
            cycles_scaled = cycles

        # Plot 1: Shannon entropy
        ax1 = axes[0, 0]
        ax1.plot(cycles_scaled, self.history['entropy'], 'b-o', linewidth=2, markersize=4)
        ax1.set_xlabel('Wet-dry cycles')
        ax1.set_ylabel('Shannon entropy (bits)')
        ax1.set_title('Entropy Decrease = Information Accumulation')
        ax1.grid(True, alpha=0.3)

        # Plot 2: Number of unique sequences
        ax2 = axes[0, 1]
        ax2.plot(cycles_scaled, self.history['num_unique_sequences'], 'r-s', linewidth=2, markersize=4)
        ax2.set_xlabel('Wet-dry cycles')
        ax2.set_ylabel('Number of unique sequences')
        ax2.set_title('Sequence Diversity')
        ax2.grid(True, alpha=0.3)

        # Plot 3: Total copy number
        ax3 = axes[0, 2]
        ax3.plot(cycles_scaled, self.history['total_copies'], 'g-^', linewidth=2, markersize=4)
        ax3.set_xlabel('Wet-dry cycles')
        ax3.set_ylabel('Total copy number')
        ax3.set_title(f'Total RNA Copies (Supp: {self.supplementation_fraction*100:.1f}%/cycle)')
        ax3.grid(True, alpha=0.3)

        # Plot 4: Maximum sequence length
        ax4 = axes[1, 0]
        ax4.plot(cycles_scaled, self.history['max_length'], 'c-d', linewidth=2, markersize=4)
        ax4.set_xlabel('Wet-dry cycles')
        ax4.set_ylabel('Maximum sequence length (nt)')
        ax4.set_title('Maximum Length Growth = Distillation Effect')
        ax4.grid(True, alpha=0.3)

        # Plot 5: Number of tRNA-like candidates
        ax5 = axes[1, 1]
        trna_counts = [len(t) for t in self.history['trna_candidates']]
        ax5.bar(cycles_scaled, trna_counts, color='purple', alpha=0.7)
        ax5.set_xlabel('Wet-dry cycles')
        ax5.set_ylabel('Number of tRNA-like candidates')
        ax5.set_title('Emergence of tRNA-like Structures')
        ax5.grid(True, alpha=0.3)

        # Plot 6: Entropy vs Total copies (phase space)
        ax6 = axes[1, 2]
        ax6.scatter(self.history['total_copies'], self.history['entropy'],
                   c=cycles_scaled, cmap='viridis', s=50, alpha=0.7)
        ax6.set_xlabel('Total copy number')
        ax6.set_ylabel('Shannon entropy')
        ax6.set_title('Phase Space: Entropy vs. Population Size')
        ax6.grid(True, alpha=0.3)
        cbar = plt.colorbar(ax6.collections[0], ax=ax6)
        cbar.set_label('Cycle number')

        plt.tight_layout()
        plt.savefig('stability_distillation_results.png', dpi=150)
        plt.show()

    def print_top_sequences(self, n=15):
        """
        Print the most frequent sequences with their stability scores.

        Args:
            n: Number of top sequences to display
        """
        print("\n" + "=" * 80)
        print(f"Top {n} Most Frequent Sequences")
        print("=" * 80)

        # Filter out monomers for top sequences display
        sequences_only = {seq: count for seq, count in self.frequencies.items() if len(seq) > 1}
        if not sequences_only:
            print("  No sequences longer than 1 nt found.")
            return

        top = Counter(sequences_only).most_common(n)
        for i, (seq, count) in enumerate(top, 1):
            stability = get_stability(seq)
            trna_flag = "★ tRNA-like" if self.is_trna_like(seq) else ""
            display_seq = seq[:50] + '...' if len(seq) > 50 else seq
            print(f"{i:2d}. [{count:5d}] {display_seq:55s} "
                  f"(stability={stability:.3f}) {trna_flag}")

        # Display all discovered tRNA-like sequences
        all_trna = [seq for seq in self.frequencies.keys() if self.is_trna_like(seq)]
        if all_trna:
            print("\n" + "=" * 80)
            print(f"Discovered tRNA-like Structures ({len(all_trna)} sequences)")
            print("=" * 80)
            for seq in all_trna[:5]:
                stability = get_stability(seq)
                print(f"\n  Sequence: {seq[:70]}")
                print(f"  Length: {len(seq)} nt, Stability: {stability:.3f}")

                # Show predicted secondary structure if ViennaRNA is available
                if VIENNA_AVAILABLE and len(seq) <= 100:
                    try:
                        fc = RNA.fold_compound(seq)
                        (ss, mfe) = fc.mfe()
                        print(f"  Predicted structure: {ss[:70]}")
                        print(f"  Minimum free energy: {mfe:.1f} kcal/mol")
                    except:
                        pass
            if len(all_trna) > 5:
                print(f"\n  ... and {len(all_trna) - 5} more")

        print()

    def compare_with_known_trna(self):
        """
        Compare generated tRNA-like sequences with known tRNA sequences.
        Performs global alignment for overall similarity and local alignment
        to find conserved fragments.
        """
        # ====================================================================
        # Known tRNA sequences (at least 20 from various organisms)
        # ====================================================================
        KNOWN_TRNA = {
            # Escherichia coli tRNAs
            'E_coli_Ala_tRNA': 'GGGGAUGUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAGGAGGUCUGCGGUUCGAUCCCGCAUCUCCACCA',
            'E_coli_Arg_tRNA': 'GCCCCAGUGGCCUAGCUGGAUAGGCGCUGGCCUCCGGAGCCAGGGUCGUGGGUUCGAAUCCCAUCUGGGGCG',
            'E_coli_Asn_tRNA': 'UCCUCUGUAGUUCAGUCGGUAGAACGGCGGACUGUUAAUCCGUAUGUCACUGGUUCGAGUCCAGUCAGAGGAG',
            'E_coli_Asp_tRNA': 'GGAGCGUGGUCGUAGUCUGGUUAGGACACCGGCCCGUCACACGGUGGAGCGUGGGUUCGAAUCCCACCGUUCCG',
            'E_coli_Cys_tRNA': 'GGCGCGUUAGCAAAGUGGUAUGCACCGCAACUGCGAAUGCAGUAGGUCGUGAGUUCGAUCCUCACACGCGCCU',
            'E_coli_Gln_tRNA': 'UGGGGUAUCGCCAAGCGGUAAGGCAUCGGCUUUUGACCGCCAUCCAUUAGGUUCGAAUCCUGAUACCCCAG',
            'E_coli_Glu_tRNA': 'GUCCCCUUCGUCUAGAGGCCCAGGACACCGCCCUUUCACGGCGGUAACAGGGGUUCGAAUCCCCUAGGGGACG',
            'E_coli_Gly_tRNA': 'GCGGGUAUCGUCUAGUUGGUUAGGACACCACCUUCCCAAGCGGUUGUACGGGUUCGAUUCCCGUUACCCGCU',
            'E_coli_His_tRNA': 'GUGGCUGUAGCUCAGUUGGUUAGAGCUCCGAUUCUCAUUCAGAGGGUCGUGAGUUCGACCCUCACAGCCACC',
            'E_coli_Ile_tRNA': 'GGCCCUUUAGCUCAGUUGGUUAGAGCGUUGUGCUCAUAACACUUGGGUCGUGGGUUCGAACCCCACAAGGGCC',
            'E_coli_Leu_tRNA': 'GCCGAGUUGGCGAAAUUGGUUAGACGCAGAUGAUUUAGGUCGUGGUGUCGAUGGGCAUGUGGGUUCGAAUCCCAUUCUCGGC',
            'E_coli_Lys_tRNA': 'GGGUCGUUAGCUCAGUUGGUAGAGCAGUUGACUUUUAAUCAUUGGUCGCAGGUUCGAAUCCUGCACGACCCA',
            'E_coli_Met_tRNA': 'GGCUACGUAGCUCAGUUGGUUAGAGCACAUGACUCAUAAUCAGUUGGUCGCGGGUUCGAAUCCCGUCGUAGCC',
            'E_coli_Phe_tRNA': 'GCCCGGAUAGCUCAGUCGGUAGAGCAGGGGAUUGAAAAUCCCCGUGUCCUUGGUUCGAUUCCGAGUCCGGGCA',
            'E_coli_Pro_tRNA': 'CGGAAUGUAGCUCAGUUGGUUAGAGCAUCUGACUUUGGAUCAGUAGGUCGUGGGUUCGAAUCCCACAUUCCGA',
            'E_coli_Ser_tRNA': 'GGAGAGGUGGCCGAGUGGUUUAAGGCGAUGGACUUGAAAUCUAUUGGGGUCUUCCCCGCGCAGGUUCGAAUCCUGCCUCUCCG',
            'E_coli_Thr_tRNA': 'GCCGAUAUAGCUCAGUUGGUUAGAGCGCAUCCCUCAUAAGGGAGAGGUCGCUGGUUCGAUUCCAGUAUCGGCU',
            'E_coli_Trp_tRNA': 'AGGGGCGUAGCUCAGUUGGUUAGAGCACUGGUCUCCAAAACCAGGGGUCGCAGGUUCGAUUCCUGUCGCCCCU',
            'E_coli_Tyr_tRNA': 'GGUGGGGUUCCCGAGCGGCCAAAGGGAGCAGACUCUAAAUCUGCCGUCAUCGACUUCGAAGGUUCGAAUCCUUCCCCCACCA',
            'E_coli_Val_tRNA': 'GGGUGAUUAGCUCAGUUGGUUAGAGCGUACCUUGACAUGGUAGGGGUCGUGGGUUCGAGUCCCACUCACCCA',

            # Saccharomyces cerevisiae (yeast) tRNAs
            'Yeast_Ala_tRNA': 'GGGGGAUUAGCUCAAUUGGUAGAGCGCGUGCUUCGCAUGUACGAGAUCGUGAGUUCGAUCCUCAUUCCUCCA',
            'Yeast_Phe_tRNA': 'GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGGUCCUGUGUUCGAUCCACAGAAUUCGCA',
            'Yeast_Met_tRNA': 'GCCUCUUUAGCUCAGUUGGAAGAGCGCAAGACUCUUAAUCUUGAGGUCCUGGGUUCGAGUCCCAGAGAGGGCA',
            'Yeast_Val_tRNA': 'GGUUCCAUAGUGUAGUGGUUAUCACGUCUGCUUUACACGCAGAAGGUCUCUAGUUCGAUCCUGGUGGAAACA',

            # Homo sapiens (human) tRNAs
            'Human_Ala_tRNA': 'GGGGGAUUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAGGAGGUCUGCGGUUCGAUCCCGCAUCCUCCA',
            'Human_Lys_tRNA': 'GCCCGGCUAGCUCAGUCGGUAGAGCAUGAGACUCUUAAUCUCAGGGUCGUGGGUUCGAGCCCCACGUUGGGCG',
            'Human_Val_tRNA': 'GUUUCCGUAGUGUAGUGGUUAUCACGUCUGCCUCACACGCAGAAGGUCUCCGGUUCGAACCCGGGCGGAAACA',
            'Human_Phe_tRNA': 'GCCGAAAUAGCUCAGUUGGGAGAGCGUUAGACUGAAGAUCUAAAUGUCCUGGUGUUCGAUCCCACGUUUCGGCA',

            # Bacillus subtilis tRNAs
            'Bsub_Ala_tRNA': 'GGGGGAUUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAAGAGGUCUGCGGUUCGAUCCCGCAUCUCCGCA',
            'Bsub_Met_tRNA': 'GGCCUCUUAGCUCAGUUGGUUAGAGCGCAUGACUCAUAAUCAGUUGGUCGCGGGUUCGAAUCCCGAGAGGGCU',
        }

        # Get all generated sequences that are long enough for comparison
        sequences_only = {seq: count for seq, count in self.frequencies.items()
                         if len(seq) > 10}

        print("\n" + "=" * 80)
        print("COMPARISON WITH KNOWN tRNA SEQUENCES")
        print("=" * 80)

        for gen_seq, count in sorted(sequences_only.items(),
                                      key=lambda x: x[1], reverse=True)[:10]:
            print(f"\n{'-' * 60}")
            display_seq = gen_seq[:60] + '...' if len(gen_seq) > 60 else gen_seq
            print(f"Generated sequence (copy count: {count}):")
            print(f"  {display_seq}")
            print(f"  Length: {len(gen_seq)} nt")
            print(f"{'-' * 60}")

            # ============================================================
            # 1. Global alignment - overall similarity
            # ============================================================
            global_results = []
            for name, known_seq in KNOWN_TRNA.items():
                # Perform global alignment
                alignments = pairwise2.align.globalms(
                    gen_seq, known_seq, 2, -1, -2, -1,
                    one_alignment_only=True
                )
                if alignments:
                    aligned1, aligned2, score, begin, end = alignments[0]
                    # Calculate identity percentage
                    matches = sum(1 for a, b in zip(aligned1, aligned2) if a == b)
                    aligned_len = len(aligned1)
                    identity = (matches / aligned_len) * 100 if aligned_len > 0 else 0
                    global_results.append({
                        'name': name,
                        'score': score,
                        'identity': identity,
                        'aligned1': aligned1,
                        'aligned2': aligned2
                    })

            # Sort by identity
            global_results.sort(key=lambda x: x['identity'], reverse=True)

            print("\n  [Global Alignment - Overall Similarity]")
            print(f"  {'Rank':<5} {'tRNA':<25} {'Identity':<10} {'Score':<10}")
            print(f"  {'-' * 50}")
            for i, res in enumerate(global_results[:5], 1):
                star = " ★" if res['identity'] > 50 else ""
                print(f"  {i:<5} {res['name']:<25} {res['identity']:>6.1f}%   {res['score']:>6}{star}")
            if len(global_results) > 5:
                print(f"  ... and {len(global_results) - 5} more")

            # Show best alignment details
            best_global = global_results[0]
            print(f"\n  Best global match: {best_global['name']} "
                  f"(identity: {best_global['identity']:.1f}%)")
            print(f"  Alignment preview (first 80 chars):")
            print(f"    Gen: {best_global['aligned1'][:80]}")
            print(f"    tRNA: {best_global['aligned2'][:80]}")

            # ============================================================
            # 2. Local alignment - find conserved fragments
            # ============================================================
            local_results = []
            for name, known_seq in KNOWN_TRNA.items():
                # Perform local alignment to find best matching fragments
                alignments = pairwise2.align.localms(
                    gen_seq, known_seq, 2, -1, -2, -1,
                    one_alignment_only=True
                )
                if alignments:
                    aligned1, aligned2, score, start1, end1 = alignments[0]
                    # Calculate the matched fragment
                    fragment_gen = gen_seq[start1:end1]
                    # Calculate identity within the matched region
                    matches = sum(1 for a, b in zip(aligned1, aligned2) if a == b)
                    aligned_len = len(aligned1)
                    identity = (matches / aligned_len) * 100 if aligned_len > 0 else 0
                    local_results.append({
                        'name': name,
                        'score': score,
                        'identity': identity,
                        'fragment': fragment_gen,
                        'fragment_len': len(fragment_gen),
                        'aligned1': aligned1,
                        'aligned2': aligned2,
                        'start': start1,
                        'end': end1
                    })

            # Sort by fragment length (descending) then identity
            local_results.sort(key=lambda x: (x['fragment_len'], x['identity']),
                              reverse=True)

            print(f"\n  [Local Alignment - Conserved Fragments]")
            print(f"  {'Rank':<5} {'tRNA':<25} {'Frag Len':<10} {'Identity':<10} {'Score':<10}")
            print(f"  {'-' * 60}")

            shown = 0
            for res in local_results:
                if res['fragment_len'] >= 8:  # Only show fragments >= 8 nt
                    shown += 1
                    star = " ★" if res['identity'] > 70 else ""
                    print(f"  {shown:<5} {res['name']:<25} {res['fragment_len']:>8} nt  "
                          f"{res['identity']:>6.1f}%   {res['score']:>6}{star}")
                    if shown >= 10:
                        break

            if shown == 0:
                print(f"  No significant fragments found (length >= 8 nt)")

            # Show best local alignment detail
            if local_results:
                best_local = local_results[0]
                print(f"\n  Best local match: {best_local['name']}")
                print(f"  Fragment length: {best_local['fragment_len']} nt")
                print(f"  Fragment identity: {best_local['identity']:.1f}%")
                print(f"  Fragment position in generated sequence: "
                      f"nt {best_local['start']} - {best_local['end']}")
                print(f"  Fragment sequence: {best_local['fragment'][:60]}")
                print(f"  Alignment:")
                print(f"    Gen: {best_local['aligned1'][:80]}")
                print(f"    tRNA: {best_local['aligned2'][:80]}")

        print(f"\n{'=' * 80}")
        print("END OF TRNA COMPARISON")
        print(f"{'=' * 80}\n")

# ============================================================================
# Part 3: Main Program with Configurable Parameters
# ============================================================================

def run_demo(stability_method='vienna',
             initial_nucleotide_pool=1000,
             num_cycles=50,
             supplementation_fraction=0.02,
             ligation_prob=0.05,
             harshness=1.0):
    """
    Run the stability-distillation simulation demo.

    Args:
        stability_method: Method for stability calculation
                         'vienna' - use ViennaRNA (requires installation)
                         'heuristic' - use built-in heuristic function
        initial_nucleotide_pool: Total number of ribonucleotide monomers at start
        num_cycles: Number of wet-dry cycles to simulate
        supplementation_fraction: Fraction of INITIAL pool to add as monomers each cycle
        ligation_prob: Base probability for sequence ligation during dry phase
                      Higher values = more frequent ligation events
        harshness: Environmental harshness factor (amplifies stability differences)
                  Higher values = more extreme conditions (hot, acidic)
                  Range: 0.5 (mild) to 2.0 (extreme), default: 1.0
    """
    global USE_VIENNA_GLOBAL, HARSHNESS_GLOBAL

    print("=" * 80)
    print("     Stability-Distillation Hypothesis Simulation")
    print("     Simulating wet-dry cycles driving RNA sequence convergence")
    print("=" * 80)

    # Display configuration
    print(f"\nConfiguration:")
    print(f"  Stability calculation method: {stability_method.upper()}")
    print(f"  Initial nucleotide pool: {initial_nucleotide_pool} monomers")
    print(f"  Number of cycles: {num_cycles}")
    print(f"  Supplementation fraction: {supplementation_fraction * 100:.1f}% of initial pool per cycle")
    print(f"  Ligation probability (base): {ligation_prob}")
    print(f"  Environmental harshness: {harshness}")
    print(f"    (Higher = more extreme conditions, stability differences amplified)")

    # Determine which stability method to use
    if stability_method.lower() == 'vienna':
        if VIENNA_AVAILABLE:
            USE_VIENNA_GLOBAL = True
            print(f"\n  ✓ Using ViennaRNA for stability calculations")
        else:
            USE_VIENNA_GLOBAL = False
            print(f"\n  ✗ ViennaRNA requested but not available!")
            print(f"    Falling back to heuristic method.")
            print(f"    Install with: !pip install viennarna")
    else:
        USE_VIENNA_GLOBAL = False
        print(f"\n  Using heuristic stability calculation")

    HARSHNESS_GLOBAL = harshness
    print()

    # Create simulator with parameters
    sim = StabilityDistillationSimulation(
        initial_seq_length=6,
        num_initial_sequences=200,
        max_seq_length=150,
        dry_growth_factor=1.3,
        wet_degradation_strength=1.0,
        ligation_base_prob=ligation_prob,
        supplementation_fraction=supplementation_fraction,
        initial_nucleotide_pool=initial_nucleotide_pool,
        harshness=harshness
    )

    # Run simulation
    sim.run(num_cycles=num_cycles, record_interval=5)
    sim.compare_with_known_trna()

    # Visualize results
    sim.plot_results()

    # Print top sequences
    sim.print_top_sequences(n=15)

    # Summary statistics
    print("\n" + "=" * 80)
    print("Simulation Summary")
    print("=" * 80)

    # Filter out monomers for summary
    sequences_only = {seq: count for seq, count in sim.frequencies.items() if len(seq) > 1}

    print(f"Final unique sequences (length>1): {len(sequences_only)}")
    print(f"Final total copies (all): {sum(sim.frequencies.values())}")
    print(f"Final entropy: {sim.calculate_entropy():.3f} bits")

    if sequences_only:
        seq_lengths = [len(s) for s in sequences_only.keys()]
        print(f"Sequence length range: {min(seq_lengths)} - {max(seq_lengths)} nt")
        print(f"Average sequence length: {np.mean(seq_lengths):.1f} nt")

    # Check if we achieved significant convergence
    if sim.history['entropy']:
        initial_entropy = sim.history['entropy'][0]
        final_entropy = sim.history['entropy'][-1]
        entropy_reduction = initial_entropy - final_entropy
        print(f"\nEntropy reduction: {entropy_reduction:.2f} bits (from {initial_entropy:.2f} to {final_entropy:.2f})")

        if entropy_reduction > 2:
            print("  ✓ Significant information accumulation observed!")
        elif entropy_reduction > 1:
            print("  ~ Moderate information accumulation observed.")
        else:
            print("  ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.")

    # Show longest sequence found
    longest_seq, max_len = sim.get_longest_sequence()
    if longest_seq:
        display_seq = longest_seq[:80] + '...' if len(longest_seq) > 80 else longest_seq
        print(f"\nLongest sequence discovered: {display_seq}")
        print(f"  Length: {max_len} nt")

    # Show tRNA-like sequences found
    trna_found = [seq for seq in sim.frequencies.keys() if sim.is_trna_like(seq)]
    if trna_found:
        print(f"\n★ tRNA-like sequences found: {len(trna_found)}")
        for seq in trna_found[:3]:
            print(f"    - {seq[:60]}... (len={len(seq)})")

# ============================================================================
# Run with different configurations
# ============================================================================
# Out:
# ✓ ViennaRNA loaded successfully

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1000
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 50
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.05
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #    - Higher harshness = faster selection but may lose diversity
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'vienna'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 1000                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.0001          # 2% of initial pool per cycle
    LIGATION_PROB = 0.15                     # Base ligation probability
    HARSHNESS = 0.12                          # Environmental harshness
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Configuration:
#   Stability calculation method: VIENNA
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 1000
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation probability (base): 0.15
#   Environmental harshness: 0.12
#     (Higher = more extreme conditions, stability differences amplified)
#
#   ✓ Using ViennaRNA for stability calculations
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 196
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.12
#   Supplementation fraction: 0.0% of initial pool per cycle
#   Ligation base probability: 0.15
#
# Starting simulation: 1000 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = AUUUUU (length=6)
#   [Record] Cycle   0: Entropy=3.325 | Unique= 197 | Total copies= 10343 | Avg len=5.7 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = AUUUUU (length=6)
#   Cycle   2: Longest RNA = AUUUUU (length=6)
#   Cycle   3: Longest RNA = AUUUUU (length=6)
#   Cycle   4: Longest RNA = AUUUUU (length=6)
#   Cycle   5: Longest RNA = CGGACCG (length=7)
#   [Record] Cycle   5: Entropy=4.531 | Unique= 226 | Total copies=  5741 | Avg len=4.9 | Max len=7 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = CGGACCG (length=7)
#   Cycle   7: Longest RNA = CGGACCG (length=7)
#   Cycle   8: Longest RNA = CGGACCG (length=7)
#   Cycle   9: Longest RNA = CGGACCG (length=7)
#   Cycle  10: Longest RNA = CGGACCG (length=7)
#   [Record] Cycle  10: Entropy=5.318 | Unique= 216 | Total copies=  2721 | Avg len=4.8 | Max len=7 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = CGGACCG (length=7)
#   Cycle  12: Longest RNA = CGGACCG (length=7)
#   Cycle  13: Longest RNA = CGGACCG (length=7)
#   Cycle  14: Longest RNA = AUGCCCUA (length=8)
#   Cycle  15: Longest RNA = AUGCCCUA (length=8)
#   [Record] Cycle  15: Entropy=6.181 | Unique= 204 | Total copies=  1406 | Avg len=4.8 | Max len=8 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = AUGCCCUA (length=8)
#   Cycle  17: Longest RNA = AUGCCCUA (length=8)
#   Cycle  18: Longest RNA = AUGCCCUA (length=8)
#   Cycle  19: Longest RNA = AUGCCCUA (length=8)
#   Cycle  20: Longest RNA = AUGCCCUA (length=8)
#   [Record] Cycle  20: Entropy=6.814 | Unique= 181 | Total copies=   859 | Avg len=4.9 | Max len=8 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = AUGCCCUA (length=8)
#   Cycle  22: Longest RNA = AUGCCCUA (length=8)
#   Cycle  23: Longest RNA = AUGCCCUA (length=8)
#   Cycle  24: Longest RNA = AUGCCCUA (length=8)
#   Cycle  25: Longest RNA = AUGCCCUA (length=8)
#   [Record] Cycle  25: Entropy=7.037 | Unique= 163 | Total copies=   613 | Avg len=4.9 | Max len=8 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = AUGCCCUA (length=8)
#   Cycle  27: Longest RNA = AUGCCCUA (length=8)
#   Cycle  28: Longest RNA = AUGCCCUA (length=8)
#   Cycle  29: Longest RNA = AUGCCCUA (length=8)
#   Cycle  30: Longest RNA = AUGCCCUA (length=8)
#   [Record] Cycle  30: Entropy=6.945 | Unique= 142 | Total copies=   510 | Avg len=5.1 | Max len=8 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = AUGCCCUA (length=8)
#   Cycle  32: Longest RNA = AUGCCCUA (length=8)
#   Cycle  33: Longest RNA = AUGCCCUA (length=8)
#   Cycle  34: Longest RNA = AUGCCCUA (length=8)
#   Cycle  35: Longest RNA = UGUAUGUGGU (length=10)
#   [Record] Cycle  35: Entropy=6.806 | Unique= 130 | Total copies=   441 | Avg len=5.1 | Max len=10 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = UGUAUGUGGU (length=10)
#   Cycle  37: Longest RNA = UGUAUGUGGU (length=10)
#   Cycle  38: Longest RNA = UGUAUGUGGU (length=10)
#   Cycle  39: Longest RNA = UGUAUGUGGU (length=10)
#   Cycle  40: Longest RNA = UUCGAGGACUAA (length=12)
#   [Record] Cycle  40: Entropy=6.760 | Unique= 121 | Total copies=   410 | Avg len=5.3 | Max len=12 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  42: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  43: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  44: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  45: Longest RNA = UUCGAGGACUAA (length=12)
#   [Record] Cycle  45: Entropy=6.637 | Unique= 113 | Total copies=   390 | Avg len=5.5 | Max len=12 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  47: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  48: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  49: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  50: Longest RNA = UUCGAGGACUAA (length=12)
#   [Record] Cycle  50: Entropy=6.580 | Unique= 111 | Total copies=   400 | Avg len=5.6 | Max len=12 | tRNA candidates=0
#
#   Cycle  51: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  52: Longest RNA = UUCGAGGACUAA (length=12)
#   Cycle  53: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  54: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  55: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  55: Entropy=6.527 | Unique= 103 | Total copies=   354 | Avg len=5.9 | Max len=12 | tRNA candidates=0
#
#   Cycle  56: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  57: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  58: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  59: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  60: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  60: Entropy=6.473 | Unique=  99 | Total copies=   332 | Avg len=5.9 | Max len=12 | tRNA candidates=0
#
#   Cycle  61: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  62: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  63: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  64: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  65: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  65: Entropy=6.367 | Unique=  95 | Total copies=   337 | Avg len=6.0 | Max len=12 | tRNA candidates=0
#
#   Cycle  66: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  67: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  68: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  69: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  70: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  70: Entropy=6.293 | Unique=  89 | Total copies=   325 | Avg len=6.1 | Max len=12 | tRNA candidates=0
#
#   Cycle  71: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  72: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  73: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  74: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  75: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  75: Entropy=6.309 | Unique=  87 | Total copies=   326 | Avg len=6.3 | Max len=12 | tRNA candidates=0
#
#   Cycle  76: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  77: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  78: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  79: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  80: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   [Record] Cycle  80: Entropy=6.266 | Unique=  86 | Total copies=   316 | Avg len=6.4 | Max len=14 | tRNA candidates=0
#
#   Cycle  81: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  82: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  83: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  84: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  85: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   [Record] Cycle  85: Entropy=6.200 | Unique=  80 | Total copies=   289 | Avg len=6.4 | Max len=14 | tRNA candidates=0
#
#   Cycle  86: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  87: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  88: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  89: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  90: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   [Record] Cycle  90: Entropy=6.152 | Unique=  79 | Total copies=   292 | Avg len=6.5 | Max len=14 | tRNA candidates=0
#
#   Cycle  91: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  92: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  93: Longest RNA = GAAAUGAUGCCCUA (length=14)
#   Cycle  94: Longest RNA = UUUAUGAGUGGA (length=12)
#   Cycle  95: Longest RNA = UUUAUGAGUGGA (length=12)
#   [Record] Cycle  95: Entropy=6.064 | Unique=  75 | Total copies=   279 | Avg len=6.3 | Max len=12 | tRNA candidates=0
#
#   Cycle  96: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle  97: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle  98: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle  99: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 100: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 100: Entropy=5.991 | Unique=  73 | Total copies=   259 | Avg len=6.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 101: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 102: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 103: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 104: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 105: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 105: Entropy=5.953 | Unique=  70 | Total copies=   258 | Avg len=6.6 | Max len=18 | tRNA candidates=0
#
#   Cycle 106: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 107: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 108: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 109: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 110: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 110: Entropy=5.931 | Unique=  68 | Total copies=   236 | Avg len=6.6 | Max len=18 | tRNA candidates=0
#
#   Cycle 111: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 112: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 113: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 114: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 115: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 115: Entropy=5.909 | Unique=  67 | Total copies=   230 | Avg len=6.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 116: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 117: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 118: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 119: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 120: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 120: Entropy=5.890 | Unique=  65 | Total copies=   228 | Avg len=7.0 | Max len=18 | tRNA candidates=0
#
#   Cycle 121: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 122: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 123: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 124: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 125: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 125: Entropy=5.781 | Unique=  63 | Total copies=   224 | Avg len=6.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 126: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 127: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 128: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 129: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 130: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 130: Entropy=5.883 | Unique=  64 | Total copies=   223 | Avg len=7.2 | Max len=18 | tRNA candidates=0
#
#   Cycle 131: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 132: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 133: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 134: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   Cycle 135: Longest RNA = CGUCAUAAGGUAAUUUGA (length=18)
#   [Record] Cycle 135: Entropy=5.773 | Unique=  63 | Total copies=   193 | Avg len=7.3 | Max len=18 | tRNA candidates=0
#
#   Cycle 136: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 137: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 138: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 139: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 140: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   [Record] Cycle 140: Entropy=5.714 | Unique=  60 | Total copies=   202 | Avg len=7.9 | Max len=24 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 142: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 143: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 144: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 145: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   [Record] Cycle 145: Entropy=5.617 | Unique=  57 | Total copies=   195 | Avg len=8.1 | Max len=24 | tRNA candidates=0
#
#   Cycle 146: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 147: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 148: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 149: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 150: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   [Record] Cycle 150: Entropy=5.540 | Unique=  53 | Total copies=   185 | Avg len=8.3 | Max len=24 | tRNA candidates=0
#
#   Cycle 151: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 152: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 153: Longest RNA = CUCGCCGGUCCAUAACUACCCCCC (length=24)
#   Cycle 154: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 155: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 155: Entropy=5.544 | Unique=  54 | Total copies=   173 | Avg len=9.1 | Max len=30 | tRNA candidates=0
#
#   Cycle 156: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 157: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 158: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 159: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 160: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 160: Entropy=5.516 | Unique=  53 | Total copies=   186 | Avg len=9.4 | Max len=30 | tRNA candidates=0
#
#   Cycle 161: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 162: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 163: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 164: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 165: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 165: Entropy=5.488 | Unique=  51 | Total copies=   182 | Avg len=9.5 | Max len=30 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 167: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 168: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 169: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 170: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 170: Entropy=5.340 | Unique=  48 | Total copies=   172 | Avg len=9.4 | Max len=30 | tRNA candidates=0
#
#   Cycle 171: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 172: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 173: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 174: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 175: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 175: Entropy=5.343 | Unique=  47 | Total copies=   162 | Avg len=9.6 | Max len=30 | tRNA candidates=0
#
#   Cycle 176: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 177: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 178: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 179: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 180: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 180: Entropy=5.386 | Unique=  46 | Total copies=   166 | Avg len=10.2 | Max len=30 | tRNA candidates=0
#
#   Cycle 181: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 182: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 183: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 184: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 185: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   [Record] Cycle 185: Entropy=5.356 | Unique=  46 | Total copies=   174 | Avg len=10.7 | Max len=30 | tRNA candidates=0
#
#   Cycle 186: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 187: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUG (length=30)
#   Cycle 188: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 189: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 190: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 190: Entropy=5.358 | Unique=  47 | Total copies=   169 | Avg len=11.6 | Max len=36 | tRNA candidates=0
#
#   Cycle 191: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 192: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 193: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 194: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 195: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 195: Entropy=5.353 | Unique=  46 | Total copies=   151 | Avg len=12.0 | Max len=36 | tRNA candidates=0
#
#   Cycle 196: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 197: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 198: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 199: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 200: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 200: Entropy=5.282 | Unique=  45 | Total copies=   143 | Avg len=11.9 | Max len=36 | tRNA candidates=0
#
#   Cycle 201: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 202: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 203: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 204: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 205: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 205: Entropy=5.306 | Unique=  47 | Total copies=   161 | Avg len=11.9 | Max len=36 | tRNA candidates=0
#
#   Cycle 206: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 207: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 208: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 209: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 210: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 210: Entropy=5.273 | Unique=  45 | Total copies=   149 | Avg len=11.8 | Max len=36 | tRNA candidates=0
#
#   Cycle 211: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 212: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 213: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 214: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 215: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   [Record] Cycle 215: Entropy=5.283 | Unique=  43 | Total copies=   159 | Avg len=11.7 | Max len=36 | tRNA candidates=0
#
#   Cycle 216: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 217: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG (length=36)
#   Cycle 218: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 219: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 220: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   [Record] Cycle 220: Entropy=5.309 | Unique=  44 | Total copies=   176 | Avg len=13.1 | Max len=59 | tRNA candidates=1
#
#   Cycle 221: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 222: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 223: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 224: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 225: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   [Record] Cycle 225: Entropy=5.343 | Unique=  45 | Total copies=   155 | Avg len=13.2 | Max len=59 | tRNA candidates=1
#
#   Cycle 226: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 227: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUCGCCGGU... (length=59)
#   Cycle 228: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 229: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 230: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   [Record] Cycle 230: Entropy=5.360 | Unique=  46 | Total copies=   162 | Avg len=14.7 | Max len=65 | tRNA candidates=1
#
#   Cycle 231: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 232: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 233: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 234: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 235: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   [Record] Cycle 235: Entropy=5.398 | Unique=  47 | Total copies=   172 | Avg len=15.8 | Max len=65 | tRNA candidates=2
#
#   Cycle 236: Longest RNA = AUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUACUUUCUC... (length=65)
#   Cycle 237: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 238: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 239: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 240: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 240: Entropy=5.389 | Unique=  47 | Total copies=   175 | Avg len=17.2 | Max len=71 | tRNA candidates=3
#
#   Cycle 241: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 242: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 243: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 244: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 245: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 245: Entropy=5.350 | Unique=  46 | Total copies=   163 | Avg len=17.9 | Max len=71 | tRNA candidates=3
#
#   Cycle 246: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 247: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 248: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 249: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 250: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 250: Entropy=5.374 | Unique=  47 | Total copies=   163 | Avg len=17.8 | Max len=71 | tRNA candidates=3
#
#   Cycle 251: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 252: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 253: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 254: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 255: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 255: Entropy=5.416 | Unique=  48 | Total copies=   153 | Avg len=17.7 | Max len=71 | tRNA candidates=3
#
#   Cycle 256: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 257: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 258: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 259: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 260: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 260: Entropy=5.402 | Unique=  49 | Total copies=   146 | Avg len=18.3 | Max len=71 | tRNA candidates=2
#
#   Cycle 261: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 262: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 263: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 264: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 265: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 265: Entropy=5.408 | Unique=  48 | Total copies=   134 | Avg len=17.8 | Max len=71 | tRNA candidates=1
#
#   Cycle 266: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 267: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 268: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 269: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 270: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 270: Entropy=5.249 | Unique=  43 | Total copies=   140 | Avg len=17.4 | Max len=71 | tRNA candidates=1
#
#   Cycle 271: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 272: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 273: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 274: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 275: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 275: Entropy=5.354 | Unique=  45 | Total copies=   155 | Avg len=17.8 | Max len=71 | tRNA candidates=1
#
#   Cycle 276: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 277: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 278: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 279: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 280: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 280: Entropy=5.454 | Unique=  49 | Total copies=   181 | Avg len=19.9 | Max len=71 | tRNA candidates=2
#
#   Cycle 281: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 282: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 283: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 284: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 285: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 285: Entropy=5.486 | Unique=  53 | Total copies=   176 | Avg len=21.4 | Max len=71 | tRNA candidates=4
#
#   Cycle 286: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 287: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 288: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 289: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 290: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 290: Entropy=5.547 | Unique=  54 | Total copies=   180 | Avg len=21.9 | Max len=71 | tRNA candidates=3
#
#   Cycle 291: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 292: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 293: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 294: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 295: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   [Record] Cycle 295: Entropy=5.525 | Unique=  52 | Total copies=   175 | Avg len=22.8 | Max len=71 | tRNA candidates=6
#
#   Cycle 296: Longest RNA = GAUAGCAUAAUACUCGCCGGUCCAUAACUACCCCCCGAAAUGACUCGUAC... (length=71)
#   Cycle 297: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 298: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 299: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 300: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   [Record] Cycle 300: Entropy=5.556 | Unique=  53 | Total copies=   174 | Avg len=24.0 | Max len=72 | tRNA candidates=6
#
#   Cycle 301: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 302: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 303: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 304: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 305: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   [Record] Cycle 305: Entropy=5.442 | Unique=  49 | Total copies=   168 | Avg len=24.9 | Max len=72 | tRNA candidates=7
#
#   Cycle 306: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 307: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 308: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 309: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 310: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   [Record] Cycle 310: Entropy=5.331 | Unique=  45 | Total copies=   173 | Avg len=24.3 | Max len=72 | tRNA candidates=5
#
#   Cycle 311: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 312: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 313: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 314: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 315: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   [Record] Cycle 315: Entropy=5.415 | Unique=  47 | Total copies=   172 | Avg len=24.9 | Max len=72 | tRNA candidates=7
#
#   Cycle 316: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 317: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 318: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 319: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   Cycle 320: Longest RNA = CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUA... (length=72)
#   [Record] Cycle 320: Entropy=5.238 | Unique=  44 | Total copies=   150 | Avg len=25.7 | Max len=72 | tRNA candidates=5
#
#   Cycle 321: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 322: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 323: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 324: Longest RNA = CCCCCCAUAAUAGUUACGAGAAAUGGGUCCACUCGCCGGUCCAUAACUAC... (length=97)
#   Cycle 325: Longest RNA = CCCCCCAUAAUAGUUACGAGAAAUGGGUCCACUCGCCGGUCCAUAACUAC... (length=97)
#   [Record] Cycle 325: Entropy=5.288 | Unique=  45 | Total copies=   145 | Avg len=28.4 | Max len=97 | tRNA candidates=6
#
#   Cycle 326: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=84)
#   Cycle 327: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 328: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 329: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 330: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   [Record] Cycle 330: Entropy=5.311 | Unique=  44 | Total copies=   149 | Avg len=25.9 | Max len=78 | tRNA candidates=6
#
#   Cycle 331: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 332: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 333: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 334: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 335: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   [Record] Cycle 335: Entropy=5.344 | Unique=  44 | Total copies=   139 | Avg len=26.3 | Max len=78 | tRNA candidates=6
#
#   Cycle 336: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 337: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 338: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 339: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 340: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   [Record] Cycle 340: Entropy=5.357 | Unique=  45 | Total copies=   146 | Avg len=28.1 | Max len=78 | tRNA candidates=6
#
#   Cycle 341: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 342: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 343: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 344: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=78)
#   Cycle 345: Longest RNA = AUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCUCGCCG... (length=79)
#   [Record] Cycle 345: Entropy=5.416 | Unique=  49 | Total copies=   172 | Avg len=28.9 | Max len=79 | tRNA candidates=7
#
#   Cycle 346: Longest RNA = AUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCUCGCCG... (length=79)
#   Cycle 347: Longest RNA = AUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCUCGCCG... (length=79)
#   Cycle 348: Longest RNA = AUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCUCGCCG... (length=79)
#   Cycle 349: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 350: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 350: Entropy=5.508 | Unique=  51 | Total copies=   199 | Avg len=31.8 | Max len=120 | tRNA candidates=8
#
#   Cycle 351: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 352: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 353: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 354: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 355: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 355: Entropy=5.595 | Unique=  53 | Total copies=   195 | Avg len=33.8 | Max len=120 | tRNA candidates=10
#
#   Cycle 356: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 357: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 358: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 359: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 360: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 360: Entropy=5.543 | Unique=  52 | Total copies=   198 | Avg len=34.9 | Max len=120 | tRNA candidates=10
#
#   Cycle 361: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 362: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 363: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 364: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 365: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 365: Entropy=5.551 | Unique=  51 | Total copies=   191 | Avg len=35.5 | Max len=120 | tRNA candidates=11
#
#   Cycle 366: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 367: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 368: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 369: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 370: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 370: Entropy=5.546 | Unique=  52 | Total copies=   192 | Avg len=36.1 | Max len=120 | tRNA candidates=11
#
#   Cycle 371: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 372: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 373: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 374: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 375: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 375: Entropy=5.473 | Unique=  51 | Total copies=   179 | Avg len=37.0 | Max len=120 | tRNA candidates=10
#
#   Cycle 376: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 377: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 378: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 379: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 380: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 380: Entropy=5.518 | Unique=  53 | Total copies=   189 | Avg len=36.7 | Max len=120 | tRNA candidates=11
#
#   Cycle 381: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 382: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 383: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 384: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 385: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 385: Entropy=5.593 | Unique=  54 | Total copies=   179 | Avg len=37.7 | Max len=120 | tRNA candidates=10
#
#   Cycle 386: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 387: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 388: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 389: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 390: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 390: Entropy=5.608 | Unique=  53 | Total copies=   166 | Avg len=38.3 | Max len=120 | tRNA candidates=14
#
#   Cycle 391: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 392: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 393: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 394: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 395: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 395: Entropy=5.556 | Unique=  51 | Total copies=   166 | Avg len=38.9 | Max len=120 | tRNA candidates=14
#
#   Cycle 396: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 397: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 398: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 399: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 400: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   [Record] Cycle 400: Entropy=5.509 | Unique=  50 | Total copies=   175 | Avg len=41.2 | Max len=134 | tRNA candidates=16
#
#   Cycle 401: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 402: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 403: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 404: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 405: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   [Record] Cycle 405: Entropy=5.529 | Unique=  52 | Total copies=   190 | Avg len=43.0 | Max len=134 | tRNA candidates=16
#
#   Cycle 406: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 407: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 408: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 409: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 410: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   [Record] Cycle 410: Entropy=5.507 | Unique=  50 | Total copies=   173 | Avg len=43.1 | Max len=134 | tRNA candidates=16
#
#   Cycle 411: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 412: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 413: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 414: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 415: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   [Record] Cycle 415: Entropy=5.439 | Unique=  49 | Total copies=   175 | Avg len=42.7 | Max len=134 | tRNA candidates=14
#
#   Cycle 416: Longest RNA = CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGCUAACUAACUCGCC... (length=134)
#   Cycle 417: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 418: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 419: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 420: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 420: Entropy=5.314 | Unique=  47 | Total copies=   171 | Avg len=41.0 | Max len=120 | tRNA candidates=13
#
#   Cycle 421: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 422: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 423: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 424: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 425: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 425: Entropy=5.331 | Unique=  46 | Total copies=   162 | Avg len=40.3 | Max len=120 | tRNA candidates=16
#
#   Cycle 426: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 427: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 428: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 429: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 430: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 430: Entropy=5.175 | Unique=  43 | Total copies=   150 | Avg len=41.8 | Max len=120 | tRNA candidates=14
#
#   Cycle 431: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 432: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 433: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 434: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 435: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 435: Entropy=5.212 | Unique=  45 | Total copies=   138 | Avg len=43.2 | Max len=120 | tRNA candidates=11
#
#   Cycle 436: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 437: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 438: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 439: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 440: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 440: Entropy=5.249 | Unique=  42 | Total copies=   148 | Avg len=43.5 | Max len=120 | tRNA candidates=17
#
#   Cycle 441: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 442: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 443: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 444: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 445: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 445: Entropy=5.383 | Unique=  47 | Total copies=   140 | Avg len=49.1 | Max len=120 | tRNA candidates=16
#
#   Cycle 446: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 447: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 448: Longest RNA = GCCCCCCCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCCGCGUC... (length=129)
#   Cycle 449: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 450: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 450: Entropy=5.318 | Unique=  45 | Total copies=   146 | Avg len=51.8 | Max len=120 | tRNA candidates=16
#
#   Cycle 451: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 452: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 453: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 454: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 455: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 455: Entropy=5.279 | Unique=  44 | Total copies=   154 | Avg len=53.5 | Max len=120 | tRNA candidates=17
#
#   Cycle 456: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 457: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 458: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 459: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   Cycle 460: Longest RNA = GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU... (length=120)
#   [Record] Cycle 460: Entropy=5.334 | Unique=  45 | Total copies=   157 | Avg len=55.4 | Max len=120 | tRNA candidates=19
#
# ...
#     Gen: CGACUCGAUAAUAAUACACGCUC-GUCCCCCCAUAAUAGUUACGAGAUAGCCCCCC-CAUAAU-AGUUACGACUCGCCGG
#     tRNA: GGCCUC--U--UA------GCUCAGU----------UGGUUA-GAG--CGCAUGACUCAUAAUCAGUU--G-GUCGCGGG
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     Human_Lys_tRNA                  92 nt    43.0%     41.0
#   2     E_coli_Val_tRNA                 92 nt    40.3%     38.0
#   3     Bsub_Met_tRNA                   91 nt    45.2%     50.0
#   4     Yeast_Ala_tRNA                  91 nt    42.7%     45.0
#   5     E_coli_Pro_tRNA                 91 nt    40.3%     38.0
#   6     E_coli_Ile_tRNA                 90 nt    43.4%     45.0
#   7     E_coli_Tyr_tRNA                 90 nt    40.0%     42.0
#   8     E_coli_Glu_tRNA                 88 nt    38.3%     37.0
#   9     E_coli_Leu_tRNA                 87 nt    37.2%     36.0
#   10    Yeast_Met_tRNA                  85 nt    39.0%     37.0
#
#   Best local match: Human_Lys_tRNA
#   Fragment length: 92 nt
#   Fragment identity: 43.0%
#   Fragment position in generated sequence: nt 19 - 113
#   Fragment sequence: GCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCCCCCCAUAAUAGUUACGACUCGCCGGUC
#   Alignment:
#     Gen: CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAA-UAGUUACGAG-AU-AGCCCCCCCAUAAUAGUUACGACUCGCCGG
#     tRNA: -------------------GCCCGGCUAGC--UCAGUCGGUA-GAGCAUGAG---ACUCUUAAU-CUCA-GGGUCGUGGG
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   ACCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGCUCGCCGGUCCAUAACU...
#   Length: 111 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     Bsub_Met_tRNA               50.0%     41.0
#   2     E_coli_Ile_tRNA             48.2%     33.0
#   3     Human_Val_tRNA              47.8%     31.0
#   4     E_coli_Asn_tRNA             47.4%     28.0
#   5     E_coli_Cys_tRNA             47.0%     27.0
#   ... and 25 more
#
#   Best global match: Bsub_Met_tRNA (identity: 50.0%)
#   Alignment preview (first 80 chars):
#     Gen: ACCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGCUCGCCGGUCCAUAACUACCCCCCGA-AAUGAAGUUG
#     tRNA: GGCCUC--U--UAGCU-C---AGUUG----------GUUAGAG--CG------CAUGACU------C-AUAAU-CAGUUG
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     Human_Val_tRNA                  96 nt    46.0%     46.0
#   2     E_coli_Pro_tRNA                 93 nt    43.1%     45.0
#   3     Human_Phe_tRNA                  92 nt    42.2%     42.0
#   4     E_coli_Ile_tRNA                 89 nt    45.2%     48.0
#   5     Yeast_Met_tRNA                  89 nt    42.6%     40.0
#   6     Yeast_Val_tRNA                  86 nt    40.0%     42.0
#   7     E_coli_Ala_tRNA                 82 nt    40.0%     45.0
#   8     Bsub_Ala_tRNA                   81 nt    38.7%     42.0
#   9     E_coli_Leu_tRNA                 81 nt    37.0%     41.0
#   10    E_coli_His_tRNA                 80 nt    40.2%     46.0
#
#   Best local match: Human_Val_tRNA
#   Fragment length: 96 nt
#   Fragment identity: 46.0%
#   Fragment position in generated sequence: nt 13 - 109
#   Fragment sequence: GUUACGAAACUUGUAACUAACUCGUUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUG
#   Alignment:
#     Gen: ACCCCCCAUAAUAGUUAC-GAAACUUGUAACUAACUCGUUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUG
#     tRNA: -------------GUUUCCGUA--GUGU-----AGUGGUU--AUCACGUCUG-CC-UCAC-ACGC------A-GAAG--G
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   GCCCCCCCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCCGCGUGGCUCUCGCCG...
#   Length: 135 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     Bsub_Met_tRNA               45.6%     28.0
#   2     E_coli_Arg_tRNA             45.2%     24.0
#   3     E_coli_Tyr_tRNA             44.9%     25.0
#   4     E_coli_Ile_tRNA             43.7%     23.0
#   5     E_coli_Met_tRNA             43.1%     20.0
#   ... and 25 more
#
#   Best global match: Bsub_Met_tRNA (identity: 45.6%)
#   Alignment preview (first 80 chars):
#     Gen: GCCCCCCCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCCGCGUGGCUCUCGCCGGUCCAUAACUACCCCCCGA-
#     tRNA: G---------GCC--U-CUUAGCU-C------------AGUUG----GU---UAGAG-CG---CAUGACU------C-AU
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Ser_tRNA                 99 nt    39.7%     51.0
#   2     E_coli_Leu_tRNA                 95 nt    34.0%     39.0
#   3     E_coli_Arg_tRNA                 93 nt    37.1%     47.0
#   4     Human_Lys_tRNA                  93 nt    35.7%     43.0
#   5     Yeast_Ala_tRNA                  91 nt    36.5%     45.0
#   6     E_coli_Pro_tRNA                 91 nt    36.4%     45.0
#   7     Yeast_Met_tRNA                  90 nt    31.9%     33.0
#   8     E_coli_Ile_tRNA                 89 nt    34.8%     42.0
#   9     E_coli_Glu_tRNA                 89 nt    33.6%     42.0
#   10    Bsub_Met_tRNA                   87 nt    36.5%     51.0
#
#   Best local match: E_coli_Ser_tRNA
#   Fragment length: 99 nt
#   Fragment identity: 39.7%
#   Fragment position in generated sequence: nt 36 - 136
#   Fragment sequence: GAAGUUGCCGCGUGGCUCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGGCUCGCC
#   Alignment:
#     Gen: GCCCCCCCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCCGCGUGGCUCUCGCCGGUCCAUA-ACUACCCCCCGA
#     tRNA: ---------------------------------GGAGAGGUGGCCGAGUGG-UUU--AAGG-CGAUGGACU------UGA
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   UUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUA...
#   Length: 141 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Cys_tRNA             43.0%     16.0
#   2     E_coli_Tyr_tRNA             43.0%     17.0
#   3     E_coli_Ser_tRNA             41.0%     14.0
#   4     E_coli_Phe_tRNA             40.8%     11.0
#   5     Yeast_Ala_tRNA              40.8%      9.0
#   ... and 25 more
#
#   Best global match: E_coli_Cys_tRNA (identity: 43.0%)
#   Alignment preview (first 80 chars):
#     Gen: UUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGU-UGCUCGCCGGUCCAUAACUACCCCCCGAAAUGCCCCCCA
#     tRNA: ---G-G--CGC--GU---UAGC-A-------AAGUG--GUAUG--CACCG--C---AACU-----GCG-AAUGC------
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     Yeast_Val_tRNA                 105 nt    36.8%     41.0
#   2     Human_Phe_tRNA                  86 nt    32.4%     44.0
#   3     Bsub_Ala_tRNA                   86 nt    30.5%     41.0
#   4     Human_Ala_tRNA                  86 nt    29.9%     38.0
#   5     E_coli_Ala_tRNA                 83 nt    30.1%     38.0
#   6     E_coli_Ser_tRNA                 82 nt    28.3%     41.0
#   7     E_coli_Asp_tRNA                 81 nt    30.5%     45.0
#   8     E_coli_Tyr_tRNA                 81 nt    29.9%     45.0
#   9     Human_Val_tRNA                  80 nt    30.3%     45.0
#   10    E_coli_Met_tRNA                 79 nt    32.2%     53.0
#
#   Best local match: Yeast_Val_tRNA
#   Fragment length: 105 nt
#   Fragment identity: 36.8%
#   Fragment position in generated sequence: nt 12 - 117
#   Fragment sequence: GGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCCCCGAAAUG
#   Alignment:
#     Gen: UUCGAGCUCGCCGGU-CCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUC--CAUAACUACCCCCCGAAAUGCCCCC
#     tRNA: ------------GGUUCCAU-AGU-------GUAGUG--GUU-AUCAC--GUCUGCUU---UACACGCAG-AAGGUCUC-
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCCCCCCAUAA...
#   Length: 112 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     Bsub_Met_tRNA               50.4%     39.0 ★
#   2     E_coli_Thr_tRNA             49.1%     36.0
#   3     E_coli_Met_tRNA             48.7%     35.0
#   4     Yeast_Phe_tRNA              47.8%     30.0
#   5     E_coli_Ile_tRNA             47.4%     30.0
#   ... and 25 more
#
#   Best global match: Bsub_Met_tRNA (identity: 50.4%)
#   Alignment preview (first 80 chars):
#     Gen: CGACUCGAUAAUAAUACACGCUC-GUCCCCCCAUAAUAGUUACGAGAUAGCCCCCC-CAUAAU-AGUUACGACUCGCCGG
#     tRNA: GGCCUC--U--UA------GCUCAGU----------UGGUUA-GAG--CGCAUGACUCAUAAUCAGUU--G-GUCGCGGG
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     Human_Lys_tRNA                  93 nt    42.6%     41.0
#   2     E_coli_Val_tRNA                 92 nt    40.0%     38.0
#   3     Bsub_Met_tRNA                   91 nt    44.8%     50.0
#   4     Yeast_Ala_tRNA                  91 nt    42.4%     45.0
#   5     E_coli_Pro_tRNA                 91 nt    40.0%     38.0
#   6     E_coli_Ile_tRNA                 90 nt    43.0%     45.0
#   7     E_coli_Tyr_tRNA                 90 nt    39.7%     42.0
#   8     E_coli_Glu_tRNA                 88 nt    38.0%     37.0
#   9     E_coli_Leu_tRNA                 87 nt    36.9%     36.0
#   10    Yeast_Met_tRNA                  86 nt    38.7%     37.0
#
#   Best local match: Human_Lys_tRNA
#   Fragment length: 93 nt
#   Fragment identity: 42.6%
#   Fragment position in generated sequence: nt 19 - 113
#   Fragment sequence: GCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCCCCCCAUAAUAGUUACGACUCGCCGGUC
#   Alignment:
#     Gen: CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAA-UAGUUACGAG-AU-AGCCCCCCCAUAAUAGUUACGACUCGCCGG
#     tRNA: -------------------GCCCGGCUAGC--UCAGUCGGUA-GAGCAUGAG---ACUCUUAAU-CUCA-GGGUCGUGGG
#
# ------------------------------------------------------------
# Generated sequence (copy count: 3):
#   GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCA...
#   Length: 121 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Tyr_tRNA             48.4%     35.0
#   2     Bsub_Met_tRNA               46.3%     26.0
#   3     E_coli_Ser_tRNA             46.0%     28.0
#   4     E_coli_Ile_tRNA             45.1%     23.0
#   5     E_coli_Phe_tRNA             44.4%     22.0
#   ... and 25 more
#
#   Best global match: E_coli_Tyr_tRNA (identity: 48.4%)
#   Alignment preview (first 80 chars):
#     Gen: GAAAUGGG--UCCACUCGCCGGUCCAUAACU-ACC--CCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCCCCGAA
#     tRNA: G--GUGGGGUUCC-CGAG-CGG-CCA-AAGGGAGCAGACUCUAAAU-------CU-GCC-GU-CAU--CGA--CUUCG-A
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Ser_tRNA                111 nt    43.8%     43.0
#   2     E_coli_Tyr_tRNA                106 nt    45.7%     49.0
#   3     Yeast_Met_tRNA                 102 nt    40.7%     33.0
#   4     E_coli_Ile_tRNA                101 nt    41.9%     39.0
#   5     E_coli_Glu_tRNA                 89 nt    36.4%     40.0
#   6     E_coli_Phe_tRNA                 88 nt    38.1%     38.0
#   7     Human_Lys_tRNA                  88 nt    37.3%     38.0
#   8     E_coli_Asp_tRNA                 87 nt    38.1%     44.0
#   9     Bsub_Ala_tRNA                   87 nt    36.2%     39.0
#   10    E_coli_His_tRNA                 85 nt    35.7%     37.0
#
#   Best local match: E_coli_Ser_tRNA
#   Fragment length: 111 nt
#   Fragment identity: 43.8%
#   Fragment position in generated sequence: nt 1 - 112
#   Fragment sequence: AAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAU
#   Alignment:
#     Gen: -GAAAUGG-GUCC-ACUCGCCGGUCCAUAA--CUACCCCCC-GAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCCCCGA
#     tRNA: GGAGA-GGUGGCCGAGU----GGU--UUAAGGCGAUGGACUUGAAAUCUA-UUG---G--GGUC--U---U---CCCCG-
#
# ================================================================================
# END OF TRNA COMPARISON
# ================================================================================
# ================================================================================
# Top 15 Most Frequent Sequences
# ================================================================================
#  1. [    6] CGGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGACCCCC...   (stability=0.474) ★ tRNA-like
#  2. [    6] ACCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGGAAAUGG...   (stability=0.492) ★ tRNA-like
#  3. [    5] CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGGAAAUGGG...   (stability=0.492) ★ tRNA-like
#  4. [    5] UCGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAG...   (stability=0.467) ★ tRNA-like
#  5. [    4] CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGC...   (stability=0.467) ★ tRNA-like
#  6. [    4] ACCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGCUCGCCG...   (stability=0.498) ★ tRNA-like
#  7. [    4] GCCCCCCCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCCGCGUG...   (stability=0.497) ★ tRNA-like
#  8. [    4] UUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGG...   (stability=0.498) ★ tRNA-like
#  9. [    4] CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGC...   (stability=0.469) ★ tRNA-like
# 10. [    3] GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCU...   (stability=0.487) ★ tRNA-like
# 11. [    3] CGGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGACCCCC...   (stability=0.480) ★ tRNA-like
# 12. [    3] CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGGAAAUGGG...   (stability=0.495) ★ tRNA-like
# 13. [    2] GUUUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCC...   (stability=0.490) ★ tRNA-like
# 14. [    2] GGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGACCCCCC...   (stability=0.473) ★ tRNA-like
# 15. [    2] CGGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGACCCCC...   (stability=0.476) ★ tRNA-like
#
# ================================================================================
# Discovered tRNA-like Structures (20 sequences)
# ================================================================================
#
#   Sequence: CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGGAAAUGGGUCCAGAUAGCCUCGCCGGUC
#   Length: 121 nt, Stability: 0.492
#
#   Sequence: CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCCCCCCAUAAUAGUUACGAC
#   Length: 111 nt, Stability: 0.467
#
#   Sequence: GUUUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCCCCGA
#   Length: 130 nt, Stability: 0.490
#
#   Sequence: GAAAUGGGUCCACUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCC
#   Length: 121 nt, Stability: 0.487
#
#   Sequence: CUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAG
#   Length: 98 nt, Stability: 0.482
#   Predicted structure: ...((((((...(((((..............)))))....))))))((((..((((.(..(((.......
#   Minimum free energy: -17.5 kcal/mol
#
#   ... and 15 more
#
#
# ================================================================================
# Simulation Summary
# ================================================================================
# Final unique sequences (length>1): 20
# Final total copies (all): 74
# Final entropy: 4.324 bits
# Sequence length range: 98 - 141 nt
# Average sequence length: 120.8 nt
#
# Entropy reduction: -1.00 bits (from 3.33 to 4.32)
#   ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.
#
# Longest sequence discovered: UUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAACUACCCCCCGAAAUGCCCCCCAU...
#   Length: 141 nt
#
# ★ tRNA-like sequences found: 20
#     - CCCCCCAUAAUAGUUACGAAACUUGUAACUAACUCGUUCGAGGAAAUGGGUCCAGAUAGC... (len=121)
#     - CGACUCGAUAAUAAUACACGCUCGUCCCCCCAUAAUAGUUACGAGAUAGCCCCCCCAUAA... (len=111)
#     - GUUUCGAGCUCGCCGGUCCAUAACUACCCCCCGAAAUGAAGUUGCUCGCCGGUCCAUAAC... (len=130)

# %% [markdown]
# In the origin of life, the appropriate intensity of environmental selection is crucial. If the environment is too harsh—such as excessively high temperature or extreme acidity—it may indiscriminately degrade almost any RNA sequence, including those with relatively stable structures, leaving little opportunity for complex molecules to accumulate. Conversely, an overly mild environment may fail to amplify the stability differences among sequences, resulting in a slow and inefficient distillation process.
#
# Moderate supplementation of ribonucleotides plays an important role in maintaining the total copy number of RNA molecules. Periodic addition of "food" (monomers) provides the raw materials necessary for polymerization and ligation during dry phases, preventing the system from going extinct due to resource depletion. However, excessive supplementation may reduce evolutionary pressure. When monomers are too abundant, even unstable and functionally irrelevant sequences can survive and replicate, reducing the selective advantage of stable, structure-forming RNAs. In such a "resource-rich" environment, the system may remain trapped at the stage of short, random sequences without ever progressing toward longer, functional molecules like tRNA-like structures.
#
# This phenomenon mirrors Darwinian natural selection: without sufficient selective pressure, evolution stalls; with too much pressure, diversity collapses. Only at the "Goldilocks" level of environmental stress and resource availability can the stability-distillation process effectively generate and accumulate informational macromolecules. This suggests that the origin of life is not merely a chemical inevitability but a finely balanced interplay between environmental conditions and molecular selection.
