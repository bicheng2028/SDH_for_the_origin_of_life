# %%
# Cell 1: Install ViennaRNA
# !pip install viennarna

# Verify installation
try:
    import RNA
    VIENNA_AVAILABLE = True
    print("✓ ViennaRNA loaded successfully")
except ImportError:
    VIENNA_AVAILABLE = False
    print("⚠ ViennaRNA not available, using heuristic stability function")
    print("  Install with: !pip install viennarna")
# Out:
# Collecting viennarna
#   Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Downloading viennarna-2.7.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: viennarna
# Successfully installed viennarna-2.7.2
# ✓ ViennaRNA loaded successfully

# %%
# Cell: Install Biopython for sequence alignment
# !pip install biopython

from Bio import pairwise2
from Bio.pairwise2 import format_alignment
# Out:
# Collecting biopython
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 41.9 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.87
# /usr/local/lib/python3.12/dist-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Stability-Distillation Hypothesis Simulation
Simulates wet-dry cycles driving RNA sequence frequency convergence and the emergence of tRNA-like structures.

Run in Google Colab:
    # !pip install viennarna
    then run this script.

Key mechanisms:
- Wet phase: Unstable sequences degrade based on thermal/acidic stress
- Dry phase: Frequent stable sequences ligate to form longer RNAs
- Nucleotide supplementation: Periodic monomer input from geothermal activity
- Stability difference amplification: Harsh conditions magnify stability disparities
"""

import numpy as np
import random
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
import warnings
warnings.filterwarnings('ignore')



# ============================================================================
# Part 1: Stability Calculation Functions
# ============================================================================

def calculate_stability_vienna(sequence, harshness=1.0):
    """
    Calculate RNA stability using ViennaRNA's minimum free energy (MFE).
    Directly uses MFE without length normalization - stable structures naturally have lower MFE.

    The harshness parameter amplifies stability differences:
    - harshness > 1.0: More extreme environment, stability differences magnified
    - harshness = 1.0: Normal environment
    - harshness < 1.0: Mild environment, stability differences reduced

    Args:
        sequence: RNA sequence string (A/U/G/C)
        harshness: Environmental harshness factor (amplifies stability differences)

    Returns:
        stability: normalized score 0-1 (higher = more stable)
        structure: dot-bracket secondary structure
        mfe: minimum free energy in kcal/mol
    """
    if len(sequence) < 4:
        return 0.2, "", 0

    try:
        fc = RNA.fold_compound(sequence)
        (ss, mfe) = fc.mfe()

        # Direct MFE usage - no length normalization!
        # MFE range: 0 to -50 kcal/mol (more negative = more stable)
        # Map to 0-1: -50 -> 1.0, 0 -> 0.0
        raw_stability = -mfe / 50.0
        stability = min(0.95, max(0.05, raw_stability))

        # Apply harshness: amplify the difference from baseline (0.5)
        # This makes stable sequences more stable, unstable ones more unstable
        if harshness != 1.0:
            # Center around 0.5, then stretch
            deviation = stability - 0.5
            stability = 0.5 + deviation * harshness
            stability = min(0.95, max(0.05, stability))

        return stability, ss, mfe

    except Exception as e:
        return calculate_stability_heuristic(sequence, harshness), "", 0


def calculate_stability_heuristic(sequence, harshness=1.0):
    """
    Heuristic stability calculation based on structural formation capability.
    Focuses on complementarity and stem-loop potential, not GC content bias.

    Args:
        sequence: RNA sequence string
        harshness: Environmental harshness factor

    Returns:
        stability: normalized score 0-1
    """
    if len(sequence) < 4:
        return 0.2

    comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}

    # 1. Self-complementarity detection (most important for stable folding)
    half_len = len(sequence) // 2
    complement_score = 0
    if half_len >= 1:
        first_half = sequence[:half_len]
        second_half_rev = sequence[half_len:][::-1]

        matches = 0
        for i in range(min(len(first_half), len(second_half_rev))):
            if comp_map.get(first_half[i], '') == second_half_rev[i]:
                matches += 1
        complement_score = matches / max(1, half_len)

    # 2. Local structure formation (ability to form hairpins and stems)
    structural_score = 0
    for i in range(len(sequence) - 3):
        for length in range(3, min(8, (len(sequence) - i) // 2)):
            left = sequence[i:i+length]
            right = sequence[i+length:i+2*length][::-1]

            if len(right) >= length:
                matches = 0
                for k in range(length):
                    if comp_map.get(left[k], '') == right[k]:
                        matches += 1
                pair_rate = matches / length
                if pair_rate > structural_score:
                    structural_score = pair_rate

    # 3. Base composition (reduced weight - structure matters more)
    gc_ratio = (sequence.count('G') + sequence.count('C')) / len(sequence)

    # 4. Stability = structural capability dominates
    # AU-rich sequences can be stable if they form good structures!
    stability = 0.1 + 0.5 * complement_score + 0.3 * structural_score + 0.1 * gc_ratio

    # 5. Long sequences with good structure get recognition
    if len(sequence) > 30 and structural_score > 0.5:
        stability = min(0.95, stability + 0.1)

    # Apply harshness: amplify stability differences
    if harshness != 1.0:
        deviation = stability - 0.5
        stability = 0.5 + deviation * harshness
        stability = min(0.95, max(0.05, stability))

    return stability


# Global variables for stability calculation
USE_VIENNA_GLOBAL = VIENNA_AVAILABLE
HARSHNESS_GLOBAL = 1.0

def get_stability(sequence):
    """
    Unified stability calculation interface.
    Uses global settings for ViennaRNA and harshness.

    Args:
        sequence: RNA sequence string

    Returns:
        stability: normalized score 0-1
    """
    if USE_VIENNA_GLOBAL and VIENNA_AVAILABLE and len(sequence) >= 4:
        stability, _, _ = calculate_stability_vienna(sequence, HARSHNESS_GLOBAL)
        return stability
    else:
        return calculate_stability_heuristic(sequence, HARSHNESS_GLOBAL)


# ============================================================================
# Part 2: tRNA Detection Function (Improved with end-pairing detection)
# ============================================================================

def is_trna_like(sequence, use_vienna=False, min_stem_loops=3, min_end_pairs=3):
    """
    Detect whether a sequence has tRNA-like structural potential.

    Improved detection includes:
    1. End-pairing detection (acceptor stem - critical for tRNA)
    2. Internal stem-loop detection (D-loop, anticodon loop, T-loop)
    3. Optional ViennaRNA validation for higher accuracy

    True tRNA characteristics:
    - Cloverleaf structure with 3-4 stem-loop regions
    - 5' and 3' ends pair to form the acceptor stem
    - Typically 70-90 nucleotides in length

    Args:
        sequence: RNA sequence string
        use_vienna: If True, use ViennaRNA for secondary structure validation
        min_stem_loops: Minimum number of stem-loop regions required
        min_end_pairs: Minimum number of end base pairs for acceptor stem

    Returns:
        True if the sequence exhibits tRNA-like characteristics
    """
    # Quick length filter - tRNA is typically 60-100 nt
    if len(sequence) < 30:
        return False

    comp_map = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}
    stem_regions = []

    # ========== 1. End-pairing detection (acceptor stem) ==========
    # This is a critical feature of tRNA - the 5' and 3' ends pair together
    end_pairs = 0
    max_end_check = min(10, len(sequence) // 2)

    for i in range(max_end_check):
        left_base = sequence[i]
        right_base = sequence[-(i+1)]
        if comp_map.get(left_base, '') == right_base:
            end_pairs += 1
        else:
            break

    if end_pairs >= min_end_pairs:
        # Record the acceptor stem as a structural feature
        stem_regions.append(('acceptor_stem', end_pairs))

    # ========== 2. Internal stem-loop detection (sliding window) ==========
    # Detects D-loop, anticodon loop, and T-loop stems
    for i in range(len(sequence) - 6):
        for length in range(3, min(10, (len(sequence) - i) // 2)):
            left = sequence[i:i+length]
            right = sequence[i+length:i+2*length][::-1]

            if len(right) >= length:
                matches = 0
                for k in range(length):
                    if comp_map.get(left[k], '') == right[k]:
                        matches += 1

                pairing_rate = matches / length if length > 0 else 0

                if pairing_rate >= 0.6:  # 60% or more base pairing
                    # Avoid duplicate detection of the same stem region
                    is_new_region = True
                    for existing in stem_regions:
                        if isinstance(existing, tuple) and len(existing) >= 3:
                            # Check if this region overlaps with an existing one
                            if abs(existing[1] - i) < length:
                                is_new_region = False
                                break

                    if is_new_region:
                        stem_regions.append(('internal', i, i+2*length, pairing_rate))

    # ========== 3. Count structural features ==========
    # Count internal stem-loops (each counts as one structural feature)
    internal_stem_count = len([r for r in stem_regions if r[0] == 'internal'])

    # Acceptor stem counts as one structural feature if present
    total_structure_count = internal_stem_count
    if end_pairs >= min_end_pairs:
        total_structure_count += 1

    # ========== 4. Optional ViennaRNA validation ==========
    if use_vienna and VIENNA_AVAILABLE and total_structure_count >= 2:
        try:
            fc = RNA.fold_compound(sequence)
            (ss, mfe) = fc.mfe()

            # Count stem regions from dot-bracket notation
            # Each '(' starts a stem, consecutive '(' form a longer stem
            stem_count = 0
            in_stem = False
            for char in ss:
                if char == '(' and not in_stem:
                    stem_count += 1
                    in_stem = True
                elif char != '(':
                    in_stem = False

            # True tRNA should have multiple stems and low free energy
            # Typical tRNA MFE ranges from -15 to -40 kcal/mol
            if stem_count >= min_stem_loops and mfe < -12:
                return True
            else:
                return False
        except:
            pass

    # ========== 5. Return judgment ==========
    # Need at least 3 structural features (acceptor stem + 2 internal stems)
    # or 3 internal stems for longer sequences
    if len(sequence) >= 60:
        return total_structure_count >= min_stem_loops
    else:
        # Shorter sequences need proportionally fewer features
        return total_structure_count >= max(2, min_stem_loops - 1)


# ============================================================================
# Part 3: Utility Functions
# ============================================================================

def calculate_entropy(frequencies):
    """
    Calculate Shannon entropy of the current sequence distribution.
    Lower entropy = more concentrated distribution = more information.

    Args:
        frequencies: Dictionary mapping sequence -> copy count

    Returns:
        entropy: Shannon entropy in bits
    """
    total = sum(frequencies.values())
    if total == 0:
        return 0
    entropy = 0
    for count in frequencies.values():
        p = count / total
        if p > 0:
            entropy -= p * np.log2(p)
    return entropy


def plot_results(sim):
    """
    Generate visualization plots showing key metrics over time.

    Args:
        sim: StabilityDistillationSimulation instance with history data
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))

    # Generate x-axis values
    cycles = np.arange(len(sim.history['entropy']))
    cycles_scaled = cycles * 5
    if len(cycles_scaled) < len(sim.history['entropy']):
        cycles_scaled = cycles

    # Plot 1: Shannon entropy
    ax1 = axes[0, 0]
    ax1.plot(cycles_scaled, sim.history['entropy'], 'b-o', linewidth=2, markersize=4)
    ax1.set_xlabel('Wet-dry cycles')
    ax1.set_ylabel('Shannon entropy (bits)')
    ax1.set_title('Entropy Decrease = Information Accumulation')
    ax1.grid(True, alpha=0.3)

    # Plot 2: Number of unique sequences
    ax2 = axes[0, 1]
    ax2.plot(cycles_scaled, sim.history['num_unique_sequences'], 'r-s', linewidth=2, markersize=4)
    ax2.set_xlabel('Wet-dry cycles')
    ax2.set_ylabel('Number of unique sequences')
    ax2.set_title('Sequence Diversity')
    ax2.grid(True, alpha=0.3)

    # Plot 3: Total copy number
    ax3 = axes[0, 2]
    ax3.plot(cycles_scaled, sim.history['total_copies'], 'g-^', linewidth=2, markersize=4)
    ax3.set_xlabel('Wet-dry cycles')
    ax3.set_ylabel('Total copy number')
    ax3.set_title(f'Total RNA Copies (Supp: {sim.supplementation_fraction*100:.1f}%/cycle)')
    ax3.grid(True, alpha=0.3)

    # Plot 4: Maximum sequence length
    ax4 = axes[1, 0]
    ax4.plot(cycles_scaled, sim.history['max_length'], 'c-d', linewidth=2, markersize=4)
    ax4.set_xlabel('Wet-dry cycles')
    ax4.set_ylabel('Maximum sequence length (nt)')
    ax4.set_title('Maximum Length Growth = Distillation Effect')
    ax4.grid(True, alpha=0.3)

    # Plot 5: Number of tRNA-like candidates
    ax5 = axes[1, 1]
    trna_counts = [len(t) for t in sim.history['trna_candidates']]
    ax5.bar(cycles_scaled, trna_counts, color='purple', alpha=0.7)
    ax5.set_xlabel('Wet-dry cycles')
    ax5.set_ylabel('Number of tRNA-like candidates')
    ax5.set_title('Emergence of tRNA-like Structures')
    ax5.grid(True, alpha=0.3)

    # Plot 6: Entropy vs Total copies (phase space)
    ax6 = axes[1, 2]
    ax6.scatter(sim.history['total_copies'], sim.history['entropy'],
               c=cycles_scaled, cmap='viridis', s=50, alpha=0.7)
    ax6.set_xlabel('Total copy number')
    ax6.set_ylabel('Shannon entropy')
    ax6.set_title('Phase Space: Entropy vs. Population Size')
    ax6.grid(True, alpha=0.3)
    cbar = plt.colorbar(ax6.collections[0], ax=ax6)
    cbar.set_label('Cycle number')

    plt.tight_layout()
    plt.savefig('stability_distillation_results.png', dpi=150)
    plt.show()


def print_summary(sim):
    """
    Print simulation summary statistics.

    Args:
        sim: StabilityDistillationSimulation instance
    """
    print("\n" + "=" * 80)
    print("Simulation Summary")
    print("=" * 80)

    # Filter out monomers for summary
    sequences_only = {seq: count for seq, count in sim.frequencies.items() if len(seq) > 1}

    print(f"Final unique sequences (length>1): {len(sequences_only)}")
    print(f"Final total copies (all): {sum(sim.frequencies.values())}")
    print(f"Final entropy: {calculate_entropy(sim.frequencies):.3f} bits")

    if sequences_only:
        seq_lengths = [len(s) for s in sequences_only.keys()]
        print(f"Sequence length range: {min(seq_lengths)} - {max(seq_lengths)} nt")
        print(f"Average sequence length: {np.mean(seq_lengths):.1f} nt")

    # Check if we achieved significant convergence
    if sim.history['entropy']:
        initial_entropy = sim.history['entropy'][0]
        final_entropy = sim.history['entropy'][-1]
        entropy_reduction = initial_entropy - final_entropy
        print(f"\nEntropy reduction: {entropy_reduction:.2f} bits (from {initial_entropy:.2f} to {final_entropy:.2f})")

        if entropy_reduction > 2:
            print("  ✓ Significant information accumulation observed!")
        elif entropy_reduction > 1:
            print("  ~ Moderate information accumulation observed.")
        else:
            print("  ⚠ Limited information accumulation. Try increasing cycles or adjusting parameters.")

    # Show longest sequence found
    longest_seq, max_len = sim.get_longest_sequence()
    if longest_seq:
        display_seq = longest_seq[:80] + '...' if len(longest_seq) > 80 else longest_seq
        print(f"\nLongest sequence discovered: {display_seq}")
        print(f"  Length: {max_len} nt")

    # Show tRNA-like sequences found
    trna_found = [seq for seq in sim.frequencies.keys() if is_trna_like(seq)]
    if trna_found:
        print(f"\n★ tRNA-like sequences found: {len(trna_found)}")
        for seq in trna_found[:3]:
            print(f"    - {seq[:60]}... (len={len(seq)})")


# ============================================================================
# Part 4: Main Simulation Class
# ============================================================================

class StabilityDistillationSimulation:
    """
    Simulates the stability-distillation process for RNA sequence evolution.

    Key mechanisms:
    - Wet phase: Unstable sequences degrade (probability = 1 - stability^harshness)
    - Dry phase: Stable sequences serve as building blocks for ligation
    - Nucleotide supplementation: Periodic addition of monomers
    - Harshness: Environmental stress amplifies stability differences
    """

    def __init__(self,
                 initial_seq_length=6,
                 num_initial_sequences=200,
                 max_seq_length=150,
                 dry_growth_factor=1.3,
                 wet_degradation_strength=1.0,
                 ligation_base_prob=0.05,
                 supplementation_fraction=0.02,
                 initial_nucleotide_pool=1000,
                 harshness=1.0,
                 trna_min_stem_loops=3,
                 trna_min_end_pairs=3,
                 trna_use_vienna=False):
        """
        Initialize the simulation.

        Args:
            initial_seq_length: Length of randomly generated starting sequences
            num_initial_sequences: Number of initial sequences to generate
            max_seq_length: Maximum allowed sequence length (prevents unbounded growth)
            dry_growth_factor: Multiplication factor for copy numbers during dry phase
            wet_degradation_strength: Exponent controlling degradation strength (higher = more degradation)
            ligation_base_prob: Base probability for sequence ligation events
            supplementation_fraction: Fraction of INITIAL nucleotide pool to add as monomers each cycle
            initial_nucleotide_pool: Total number of ribonucleotide monomers available at start
            harshness: Environmental harshness factor (amplifies stability differences)
                      Higher values = more extreme conditions (hot, acidic)
                      Typical range: 0.5 (mild) to 2.0 (extreme)
            trna_min_stem_loops: Minimum number of stem-loop regions required for tRNA detection
            trna_min_end_pairs: Minimum number of end base pairs for acceptor stem detection
            trna_use_vienna: Whether to use ViennaRNA for tRNA validation (more accurate but slower)
        """
        self.max_seq_length = max_seq_length
        self.dry_growth_factor = dry_growth_factor
        self.wet_degradation_strength = wet_degradation_strength
        self.ligation_base_prob = ligation_base_prob
        self.supplementation_fraction = supplementation_fraction
        self.initial_nucleotide_pool = initial_nucleotide_pool
        self.harshness = harshness

        # tRNA detection parameters
        self.trna_min_stem_loops = trna_min_stem_loops
        self.trna_min_end_pairs = trna_min_end_pairs
        self.trna_use_vienna = trna_use_vienna

        # Update global harshness for stability calculations
        global HARSHNESS_GLOBAL
        HARSHNESS_GLOBAL = harshness

        # Available nucleotides
        self.nucleotides = ['A', 'U', 'G', 'C']

        # Initialize sequence pool: generate random short sequences
        self.sequences = []
        for _ in range(num_initial_sequences):
            seq = ''.join(random.choice(self.nucleotides)
                         for _ in range(initial_seq_length))
            self.sequences.append(seq)

        # Frequency dictionary: sequence -> copy count
        self.frequencies = defaultdict(int)
        for seq in self.sequences:
            self.frequencies[seq] += 1

        # Add initial monomer pool
        for _ in range(initial_nucleotide_pool):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        # Track the current longest sequence for each cycle
        self.current_longest_sequence = ""

        # History tracking for visualization
        self.history = {
            'entropy': [],
            'num_unique_sequences': [],
            'avg_length': [],
            'total_copies': [],
            'max_length': [],
            'longest_sequence': [],
            'top_sequences': [],
            'trna_candidates': []
        }

        print(f"Simulation initialized")
        print(f"  Initial sequence count: {len(self.sequences)}")
        print(f"  Unique sequences: {len(self.frequencies)}")
        print(f"  Initial nucleotide pool: {self.initial_nucleotide_pool}")
        print(f"  ViennaRNA available: {VIENNA_AVAILABLE}")
        print(f"  Environmental harshness: {self.harshness}")
        print(f"  Supplementation fraction: {self.supplementation_fraction * 100:.1f}% of initial pool per cycle")
        print(f"  Ligation base probability: {self.ligation_base_prob}")
        print(f"  tRNA detection: min_stem_loops={self.trna_min_stem_loops}, "
              f"min_end_pairs={self.trna_min_end_pairs}, use_vienna={self.trna_use_vienna}")

    def calculate_entropy(self):
        """Calculate Shannon entropy of the current sequence distribution."""
        return calculate_entropy(self.frequencies)

    def get_longest_sequence(self):
        """
        Find the current longest RNA sequence in the pool.

        Returns:
            longest_seq: The longest sequence string
            max_len: Length of the longest sequence
        """
        if not self.frequencies:
            return "", 0

        # Filter out monomers (length 1) when looking for longest
        sequences_only = [seq for seq in self.frequencies.keys() if len(seq) > 1]
        if not sequences_only:
            return "", 0

        longest_seq = max(sequences_only, key=len)
        return longest_seq, len(longest_seq)

    def add_nucleotide_supplementation(self):
        """
        Add fresh ribonucleotide monomers to the pool.
        This simulates continuous input from the geothermal environment.

        The supplementation is added as monomers, which can be used
        during the dry phase to form new RNA sequences.

        Supplementation is anchored to the INITIAL nucleotide pool size,
        providing consistent input regardless of population fluctuations.
        """
        if self.supplementation_fraction <= 0:
            return 0

        # Calculate monomers to add based on INITIAL pool size
        num_monomers = max(1, int(self.initial_nucleotide_pool * self.supplementation_fraction))

        # Add monomers with balanced composition
        for _ in range(num_monomers):
            monomer = random.choice(self.nucleotides)
            self.frequencies[monomer] += 1

        return num_monomers

    def wet_phase(self):
        """
        Wet phase: Unstable sequences degrade.

        Degradation probability depends on:
        1. Sequence stability (higher stability = lower degradation)
        2. Environmental harshness (amplifies stability differences)
        3. Degradation strength parameter

        In harsh environments (high temperature, acidic), the difference
        between stable and unstable sequences is magnified.
        """
        new_frequencies = defaultdict(int)

        for seq, count in self.frequencies.items():
            stability = get_stability(seq)

            # Survival probability increases with stability
            # Harshness amplifies the difference:
            # - Stable sequences become MORE likely to survive
            # - Unstable sequences become LESS likely to survive
            survival_prob = stability ** (self.wet_degradation_strength * self.harshness)
            survived = np.random.binomial(count, survival_prob)

            if survived > 0:
                new_frequencies[seq] = survived

        self.frequencies = new_frequencies

        # If everything went extinct, reintroduce some random sequences
        if len(self.frequencies) == 0:
            for _ in range(50):
                seq = ''.join(random.choice(self.nucleotides)
                             for _ in range(6))
                self.frequencies[seq] += 1

    def dry_phase(self):
        """
        Dry phase: Sequence ligation and growth.

        Key mechanism from the stability-distillation hypothesis:
        - Frequent sequences are more likely to collide and ligate
        - Ligation probability ∝ frequency(a) × frequency(b)
        - This allows stable short sequences to serve as "stepping stones"
          for building longer, potentially more stable sequences.
        """
        total = sum(self.frequencies.values())
        if total == 0:
            return

        # Calculate frequency ratio for each sequence
        freq_ratio = {seq: count/total for seq, count in self.frequencies.items()}

        # Generate new sequences via ligation
        new_sequences = []
        seq_list = list(self.frequencies.keys())

        # Generate approximately 30% of current population as new ligation products
        num_ligations = int(total * 0.3)

        for _ in range(num_ligations):
            if len(seq_list) < 2:
                break

            # Weighted selection based on frequency
            weights = [freq_ratio.get(seq, 0) for seq in seq_list]
            if sum(weights) == 0:
                break

            # Select two sequences to ligate, weighted by their frequencies
            a = np.random.choice(seq_list, p=weights)
            b = np.random.choice(seq_list, p=weights)

            # Ligation probability is proportional to the product of their frequencies
            # This captures the "collision probability" concept
            p_ligate = self.ligation_base_prob * (freq_ratio[a] * freq_ratio[b] * 100)
            p_ligate = min(0.8, p_ligate)

            if random.random() < p_ligate:
                new_seq = a + b
                if len(new_seq) <= self.max_seq_length:
                    new_sequences.append(new_seq)

        # Add newly ligated sequences to the pool
        for seq in new_sequences:
            self.frequencies[seq] += 1

        # All sequences grow during dry phase (general polymerization)
        for seq in list(self.frequencies.keys()):
            growth = np.random.poisson(self.dry_growth_factor - 1)
            if growth > 0:
                self.frequencies[seq] += growth

    def step(self, cycle_number):
        """
        Execute one complete wet-dry cycle.

        Order:
        1. Wet phase: Degradation of unstable sequences
        2. Add fresh nucleotide supplementation (simulating geothermal input)
        3. Dry phase: Ligation and growth

        Args:
            cycle_number: Current cycle number (for logging)
        """
        # Step 1: Wet phase - degradation
        self.wet_phase()

        # Step 2: Add fresh nucleotide supplementation
        monomers_added = self.add_nucleotide_supplementation()

        # Step 3: Dry phase - ligation and growth
        self.dry_phase()

        # Track current longest sequence
        longest_seq, max_len = self.get_longest_sequence()
        self.current_longest_sequence = longest_seq

        # Print current longest sequence
        if longest_seq:
            display_seq = longest_seq[:50] + '...' if len(longest_seq) > 50 else longest_seq
            print(f"  Cycle {cycle_number:3d}: Longest RNA = {display_seq} (length={max_len})")

        return monomers_added

    def run(self, num_cycles=50, record_interval=5):
        """
        Run the simulation for a specified number of cycles.

        Args:
            num_cycles: Number of wet-dry cycles to simulate
            record_interval: How often to record statistics (cycles between records)
        """
        print(f"\nStarting simulation: {num_cycles} wet-dry cycles...")
        print("-" * 70)

        for cycle in range(num_cycles):
            monomers_added = self.step(cycle)

            # Record statistics at specified intervals
            if cycle % record_interval == 0 or cycle == num_cycles - 1:
                entropy = self.calculate_entropy()
                num_unique = len(self.frequencies)
                total = sum(self.frequencies.values())

                # Calculate average sequence length (excluding monomers)
                seq_lengths = [len(seq) for seq in self.frequencies.keys() if len(seq) > 1]
                avg_len = np.mean(seq_lengths) if seq_lengths else 0

                # Get current max length
                _, max_len = self.get_longest_sequence()

                # Get top 5 sequences by frequency
                top_seqs = Counter(self.frequencies).most_common(5)

                # Detect tRNA-like candidates using improved detection
                trna_candidates = []
                for seq in list(self.frequencies.keys())[:50]:  # Check first 50 only for performance
                    if is_trna_like(seq,
                                   use_vienna=self.trna_use_vienna,
                                   min_stem_loops=self.trna_min_stem_loops,
                                   min_end_pairs=self.trna_min_end_pairs):
                        if self.frequencies[seq] > 1:
                            trna_candidates.append(seq)

                # Store history
                self.history['entropy'].append(entropy)
                self.history['num_unique_sequences'].append(num_unique)
                self.history['avg_length'].append(avg_len)
                self.history['total_copies'].append(total)
                self.history['max_length'].append(max_len)
                self.history['longest_sequence'].append(self.current_longest_sequence)
                self.history['top_sequences'].append(top_seqs)
                self.history['trna_candidates'].append(trna_candidates)

                print(f"  [Record] Cycle {cycle:3d}: Entropy={entropy:.3f} | Unique={num_unique:4d} | "
                      f"Total copies={total:6d} | Avg len={avg_len:.1f} | Max len={max_len} | "
                      f"tRNA candidates={len(trna_candidates)}")
                print()

        print("-" * 70)
        print("Simulation complete!")

    def plot_results(self):
        """Generate visualization plots showing key metrics over time."""
        plot_results(self)

    def compare_with_known_trna(self):
        """
        Compare generated tRNA-like sequences with known tRNA sequences.
        Performs global alignment for overall similarity and local alignment
        to find conserved fragments.
        """
        # ====================================================================
        # Known tRNA sequences (at least 20 from various organisms)
        # ====================================================================
        KNOWN_TRNA = {
            # Escherichia coli tRNAs
            'E_coli_Ala_tRNA': 'GGGGAUGUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAGGAGGUCUGCGGUUCGAUCCCGCAUCUCCACCA',
            'E_coli_Arg_tRNA': 'GCCCCAGUGGCCUAGCUGGAUAGGCGCUGGCCUCCGGAGCCAGGGUCGUGGGUUCGAAUCCCAUCUGGGGCG',
            'E_coli_Asn_tRNA': 'UCCUCUGUAGUUCAGUCGGUAGAACGGCGGACUGUUAAUCCGUAUGUCACUGGUUCGAGUCCAGUCAGAGGAG',
            'E_coli_Asp_tRNA': 'GGAGCGUGGUCGUAGUCUGGUUAGGACACCGGCCCGUCACACGGUGGAGCGUGGGUUCGAAUCCCACCGUUCCG',
            'E_coli_Cys_tRNA': 'GGCGCGUUAGCAAAGUGGUAUGCACCGCAACUGCGAAUGCAGUAGGUCGUGAGUUCGAUCCUCACACGCGCCU',
            'E_coli_Gln_tRNA': 'UGGGGUAUCGCCAAGCGGUAAGGCAUCGGCUUUUGACCGCCAUCCAUUAGGUUCGAAUCCUGAUACCCCAG',
            'E_coli_Glu_tRNA': 'GUCCCCUUCGUCUAGAGGCCCAGGACACCGCCCUUUCACGGCGGUAACAGGGGUUCGAAUCCCCUAGGGGACG',
            'E_coli_Gly_tRNA': 'GCGGGUAUCGUCUAGUUGGUUAGGACACCACCUUCCCAAGCGGUUGUACGGGUUCGAUUCCCGUUACCCGCU',
            'E_coli_His_tRNA': 'GUGGCUGUAGCUCAGUUGGUUAGAGCUCCGAUUCUCAUUCAGAGGGUCGUGAGUUCGACCCUCACAGCCACC',
            'E_coli_Ile_tRNA': 'GGCCCUUUAGCUCAGUUGGUUAGAGCGUUGUGCUCAUAACACUUGGGUCGUGGGUUCGAACCCCACAAGGGCC',
            'E_coli_Leu_tRNA': 'GCCGAGUUGGCGAAAUUGGUUAGACGCAGAUGAUUUAGGUCGUGGUGUCGAUGGGCAUGUGGGUUCGAAUCCCAUUCUCGGC',
            'E_coli_Lys_tRNA': 'GGGUCGUUAGCUCAGUUGGUAGAGCAGUUGACUUUUAAUCAUUGGUCGCAGGUUCGAAUCCUGCACGACCCA',
            'E_coli_Met_tRNA': 'GGCUACGUAGCUCAGUUGGUUAGAGCACAUGACUCAUAAUCAGUUGGUCGCGGGUUCGAAUCCCGUCGUAGCC',
            'E_coli_Phe_tRNA': 'GCCCGGAUAGCUCAGUCGGUAGAGCAGGGGAUUGAAAAUCCCCGUGUCCUUGGUUCGAUUCCGAGUCCGGGCA',
            'E_coli_Pro_tRNA': 'CGGAAUGUAGCUCAGUUGGUUAGAGCAUCUGACUUUGGAUCAGUAGGUCGUGGGUUCGAAUCCCACAUUCCGA',
            'E_coli_Ser_tRNA': 'GGAGAGGUGGCCGAGUGGUUUAAGGCGAUGGACUUGAAAUCUAUUGGGGUCUUCCCCGCGCAGGUUCGAAUCCUGCCUCUCCG',
            'E_coli_Thr_tRNA': 'GCCGAUAUAGCUCAGUUGGUUAGAGCGCAUCCCUCAUAAGGGAGAGGUCGCUGGUUCGAUUCCAGUAUCGGCU',
            'E_coli_Trp_tRNA': 'AGGGGCGUAGCUCAGUUGGUUAGAGCACUGGUCUCCAAAACCAGGGGUCGCAGGUUCGAUUCCUGUCGCCCCU',
            'E_coli_Tyr_tRNA': 'GGUGGGGUUCCCGAGCGGCCAAAGGGAGCAGACUCUAAAUCUGCCGUCAUCGACUUCGAAGGUUCGAAUCCUUCCCCCACCA',
            'E_coli_Val_tRNA': 'GGGUGAUUAGCUCAGUUGGUUAGAGCGUACCUUGACAUGGUAGGGGUCGUGGGUUCGAGUCCCACUCACCCA',

            # Saccharomyces cerevisiae (yeast) tRNAs
            'Yeast_Ala_tRNA': 'GGGGGAUUAGCUCAAUUGGUAGAGCGCGUGCUUCGCAUGUACGAGAUCGUGAGUUCGAUCCUCAUUCCUCCA',
            'Yeast_Phe_tRNA': 'GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGGUCCUGUGUUCGAUCCACAGAAUUCGCA',
            'Yeast_Met_tRNA': 'GCCUCUUUAGCUCAGUUGGAAGAGCGCAAGACUCUUAAUCUUGAGGUCCUGGGUUCGAGUCCCAGAGAGGGCA',
            'Yeast_Val_tRNA': 'GGUUCCAUAGUGUAGUGGUUAUCACGUCUGCUUUACACGCAGAAGGUCUCUAGUUCGAUCCUGGUGGAAACA',

            # Homo sapiens (human) tRNAs
            'Human_Ala_tRNA': 'GGGGGAUUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAGGAGGUCUGCGGUUCGAUCCCGCAUCCUCCA',
            'Human_Lys_tRNA': 'GCCCGGCUAGCUCAGUCGGUAGAGCAUGAGACUCUUAAUCUCAGGGUCGUGGGUUCGAGCCCCACGUUGGGCG',
            'Human_Val_tRNA': 'GUUUCCGUAGUGUAGUGGUUAUCACGUCUGCCUCACACGCAGAAGGUCUCCGGUUCGAACCCGGGCGGAAACA',
            'Human_Phe_tRNA': 'GCCGAAAUAGCUCAGUUGGGAGAGCGUUAGACUGAAGAUCUAAAUGUCCUGGUGUUCGAUCCCACGUUUCGGCA',

            # Bacillus subtilis tRNAs
            'Bsub_Ala_tRNA': 'GGGGGAUUAGCUCAGCUGGGAGAGCGCCUGCUUUGCACGCAAGAGGUCUGCGGUUCGAUCCCGCAUCUCCGCA',
            'Bsub_Met_tRNA': 'GGCCUCUUAGCUCAGUUGGUUAGAGCGCAUGACUCAUAAUCAGUUGGUCGCGGGUUCGAAUCCCGAGAGGGCU',
        }

        # Get all generated sequences that are long enough for comparison
        sequences_only = {seq: count for seq, count in self.frequencies.items()
                         if len(seq) > 10}

        print("\n" + "=" * 80)
        print("COMPARISON WITH KNOWN tRNA SEQUENCES")
        print("=" * 80)

        for gen_seq, count in sorted(sequences_only.items(),
                                      key=lambda x: x[1], reverse=True)[:10]:
            print(f"\n{'-' * 60}")
            display_seq = gen_seq[:60] + '...' if len(gen_seq) > 60 else gen_seq
            print(f"Generated sequence (copy count: {count}):")
            print(f"  {display_seq}")
            print(f"  Length: {len(gen_seq)} nt")
            print(f"{'-' * 60}")

            # ============================================================
            # 1. Global alignment - overall similarity
            # ============================================================
            global_results = []
            for name, known_seq in KNOWN_TRNA.items():
                # Perform global alignment
                alignments = pairwise2.align.globalms(
                    gen_seq, known_seq, 2, -1, -2, -1,
                    one_alignment_only=True
                )
                if alignments:
                    aligned1, aligned2, score, begin, end = alignments[0]
                    # Calculate identity percentage
                    matches = sum(1 for a, b in zip(aligned1, aligned2) if a == b)
                    aligned_len = len(aligned1)
                    identity = (matches / aligned_len) * 100 if aligned_len > 0 else 0
                    global_results.append({
                        'name': name,
                        'score': score,
                        'identity': identity,
                        'aligned1': aligned1,
                        'aligned2': aligned2
                    })

            # Sort by identity
            global_results.sort(key=lambda x: x['identity'], reverse=True)

            print("\n  [Global Alignment - Overall Similarity]")
            print(f"  {'Rank':<5} {'tRNA':<25} {'Identity':<10} {'Score':<10}")
            print(f"  {'-' * 50}")
            for i, res in enumerate(global_results[:5], 1):
                star = " ★" if res['identity'] > 50 else ""
                print(f"  {i:<5} {res['name']:<25} {res['identity']:>6.1f}%   {res['score']:>6}{star}")
            if len(global_results) > 5:
                print(f"  ... and {len(global_results) - 5} more")

            # Show best alignment details
            best_global = global_results[0]
            print(f"\n  Best global match: {best_global['name']} "
                  f"(identity: {best_global['identity']:.1f}%)")
            print(f"  Alignment preview (first 80 chars):")
            print(f"    Gen: {best_global['aligned1'][:80]}")
            print(f"    tRNA: {best_global['aligned2'][:80]}")

            # ============================================================
            # 2. Local alignment - find conserved fragments
            # ============================================================
            local_results = []
            for name, known_seq in KNOWN_TRNA.items():
                # Perform local alignment to find best matching fragments
                alignments = pairwise2.align.localms(
                    gen_seq, known_seq, 2, -1, -2, -1,
                    one_alignment_only=True
                )
                if alignments:
                    aligned1, aligned2, score, start1, end1 = alignments[0]
                    # Calculate the matched fragment
                    fragment_gen = gen_seq[start1:end1]
                    # Calculate identity within the matched region
                    matches = sum(1 for a, b in zip(aligned1, aligned2) if a == b)
                    aligned_len = len(aligned1)
                    identity = (matches / aligned_len) * 100 if aligned_len > 0 else 0
                    local_results.append({
                        'name': name,
                        'score': score,
                        'identity': identity,
                        'fragment': fragment_gen,
                        'fragment_len': len(fragment_gen),
                        'aligned1': aligned1,
                        'aligned2': aligned2,
                        'start': start1,
                        'end': end1
                    })

            # Sort by fragment length (descending) then identity
            local_results.sort(key=lambda x: (x['fragment_len'], x['identity']),
                              reverse=True)

            print(f"\n  [Local Alignment - Conserved Fragments]")
            print(f"  {'Rank':<5} {'tRNA':<25} {'Frag Len':<10} {'Identity':<10} {'Score':<10}")
            print(f"  {'-' * 60}")

            shown = 0
            for res in local_results:
                if res['fragment_len'] >= 8:  # Only show fragments >= 8 nt
                    shown += 1
                    star = " ★" if res['identity'] > 70 else ""
                    print(f"  {shown:<5} {res['name']:<25} {res['fragment_len']:>8} nt  "
                          f"{res['identity']:>6.1f}%   {res['score']:>6}{star}")
                    if shown >= 10:
                        break

            if shown == 0:
                print(f"  No significant fragments found (length >= 8 nt)")

            # Show best local alignment detail
            if local_results:
                best_local = local_results[0]
                print(f"\n  Best local match: {best_local['name']}")
                print(f"  Fragment length: {best_local['fragment_len']} nt")
                print(f"  Fragment identity: {best_local['identity']:.1f}%")
                print(f"  Fragment position in generated sequence: "
                      f"nt {best_local['start']} - {best_local['end']}")
                print(f"  Fragment sequence: {best_local['fragment'][:60]}")
                print(f"  Alignment:")
                print(f"    Gen: {best_local['aligned1'][:80]}")
                print(f"    tRNA: {best_local['aligned2'][:80]}")

        print(f"\n{'=' * 80}")
        print("END OF TRNA COMPARISON")
        print(f"{'=' * 80}\n")

    def print_top_sequences(self, n=15):
        """
        Print the most frequent sequences with their stability scores.

        Args:
            n: Number of top sequences to display
        """
        print("\n" + "=" * 80)
        print(f"Top {n} Most Frequent Sequences")
        print("=" * 80)

        # Filter out monomers for top sequences display
        sequences_only = {seq: count for seq, count in self.frequencies.items() if len(seq) > 1}
        if not sequences_only:
            print("  No sequences longer than 1 nt found.")
            return

        top = Counter(sequences_only).most_common(n)
        for i, (seq, count) in enumerate(top, 1):
            stability = get_stability(seq)
            trna_flag = "★ tRNA-like" if is_trna_like(seq,
                                                       use_vienna=self.trna_use_vienna,
                                                       min_stem_loops=self.trna_min_stem_loops,
                                                       min_end_pairs=self.trna_min_end_pairs) else ""
            display_seq = seq[:50] + '...' if len(seq) > 50 else seq
            print(f"{i:2d}. [{count:5d}] {display_seq:55s} "
                  f"(stability={stability:.3f}) {trna_flag}")

        # Display all discovered tRNA-like sequences
        all_trna = [seq for seq in self.frequencies.keys()
                   if is_trna_like(seq,
                                  use_vienna=self.trna_use_vienna,
                                  min_stem_loops=self.trna_min_stem_loops,
                                  min_end_pairs=self.trna_min_end_pairs)]
        if all_trna:
            print("\n" + "=" * 80)
            print(f"Discovered tRNA-like Structures ({len(all_trna)} sequences)")
            print("=" * 80)
            for seq in all_trna[:5]:
                stability = get_stability(seq)
                print(f"\n  Sequence: {seq[:70]}")
                print(f"  Length: {len(seq)} nt, Stability: {stability:.3f}")

                # Show predicted secondary structure if ViennaRNA is available
                if VIENNA_AVAILABLE and len(seq) <= 100:
                    try:
                        fc = RNA.fold_compound(seq)
                        (ss, mfe) = fc.mfe()
                        print(f"  Predicted structure: {ss[:70]}")
                        print(f"  Minimum free energy: {mfe:.1f} kcal/mol")
                    except:
                        pass
            if len(all_trna) > 5:
                print(f"\n  ... and {len(all_trna) - 5} more")

        print()


# ============================================================================
# Part 5: Main Program with Configurable Parameters
# ============================================================================

def run_demo(stability_method='heuristic',
             initial_nucleotide_pool=1500,
             num_cycles=80,
             supplementation_fraction=0.02,
             ligation_prob=0.08,
             harshness=1.0,
             trna_min_stem_loops=3,
             trna_min_end_pairs=3,
             trna_use_vienna=False):
    """
    Run the stability-distillation simulation demo.

    Args:
        stability_method: Method for stability calculation
                         'vienna' - use ViennaRNA (requires installation)
                         'heuristic' - use built-in heuristic function
        initial_nucleotide_pool: Total number of ribonucleotide monomers at start
        num_cycles: Number of wet-dry cycles to simulate
        supplementation_fraction: Fraction of INITIAL pool to add as monomers each cycle
        ligation_prob: Base probability for sequence ligation during dry phase
                      Higher values = more frequent ligation events
        harshness: Environmental harshness factor (amplifies stability differences)
                  Higher values = more extreme conditions (hot, acidic)
                  Range: 0.5 (mild) to 2.0 (extreme), default: 1.0
        trna_min_stem_loops: Minimum number of stem-loop regions for tRNA detection (default: 3)
        trna_min_end_pairs: Minimum number of end base pairs for acceptor stem (default: 3)
        trna_use_vienna: Whether to use ViennaRNA for tRNA validation (default: False)
    """
    global USE_VIENNA_GLOBAL, HARSHNESS_GLOBAL

    print("=" * 80)
    print("     Stability-Distillation Hypothesis Simulation")
    print("     Simulating wet-dry cycles driving RNA sequence convergence")
    print("=" * 80)
    print(f"\nPaper: https://doi.org/10.48550/arXiv.2403.17072")

    # Display configuration
    print(f"\nConfiguration:")
    print(f"  Stability calculation method: {stability_method.upper()}")
    print(f"  Initial nucleotide pool: {initial_nucleotide_pool} monomers")
    print(f"  Number of cycles: {num_cycles}")
    print(f"  Supplementation fraction: {supplementation_fraction * 100:.1f}% of initial pool per cycle")
    print(f"  Ligation probability (base): {ligation_prob}")
    print(f"  Environmental harshness: {harshness}")
    print(f"    (Higher = more extreme conditions, stability differences amplified)")
    print(f"  tRNA detection:")
    print(f"    - Minimum stem-loops: {trna_min_stem_loops}")
    print(f"    - Minimum end pairs (acceptor stem): {trna_min_end_pairs}")
    print(f"    - Use ViennaRNA validation: {trna_use_vienna}")

    # Determine which stability method to use
    if stability_method.lower() == 'vienna':
        if VIENNA_AVAILABLE:
            USE_VIENNA_GLOBAL = True
            print(f"\n  ✓ Using ViennaRNA for stability calculations")
        else:
            USE_VIENNA_GLOBAL = False
            print(f"\n  ✗ ViennaRNA requested but not available!")
            print(f"    Falling back to heuristic method.")
            print(f"    Install with: !pip install viennarna")
    else:
        USE_VIENNA_GLOBAL = False
        print(f"\n  Using heuristic stability calculation")

    HARSHNESS_GLOBAL = harshness
    print()

    # Create simulator with parameters
    sim = StabilityDistillationSimulation(
        initial_seq_length=6,
        num_initial_sequences=200,
        max_seq_length=150,
        dry_growth_factor=1.3,
        wet_degradation_strength=1.0,
        ligation_base_prob=ligation_prob,
        supplementation_fraction=supplementation_fraction,
        initial_nucleotide_pool=initial_nucleotide_pool,
        harshness=harshness,
        trna_min_stem_loops=trna_min_stem_loops,
        trna_min_end_pairs=trna_min_end_pairs,
        trna_use_vienna=trna_use_vienna
    )

    # Run simulation
    sim.run(num_cycles=num_cycles, record_interval=5)

    # Visualize results
    sim.plot_results()

    # Print top sequences
    sim.print_top_sequences(n=15)

    # Print summary
    print_summary(sim)
    # Compare with known tRNA sequences
    sim.compare_with_known_trna()


# ============================================================================
# Run with different configurations
# ============================================================================

# %%
if __name__ == "__main__":
    # ================================================================
    # USER CONFIGURABLE PARAMETERS
    # ================================================================
    #
    # 1. STABILITY_METHOD: Method for calculating RNA stability
    #    - 'vienna'    : Use ViennaRNA (requires !pip install viennarna)
    #    - 'heuristic' : Use built-in GC content + complementarity heuristic
    #
    # 2. INITIAL_NUCLEOTIDE_POOL: Total ribonucleotide monomers at start
    #    - Default: 1500
    #    - This anchors the supplementation calculation
    #
    # 3. NUM_CYCLES: Number of wet-dry cycles to simulate
    #    - Default: 80
    #    - Increase for more evolution time
    #
    # 4. SUPPLEMENTATION_FRACTION: Fraction of INITIAL pool added each cycle
    #    - Default: 0.02 (2%)
    #    - 0.00 = no supplementation (closed system)
    #    - 0.01 = 1% of initial pool per cycle
    #    - 0.02 = 2% of initial pool per cycle (recommended)
    #    - 0.05 = 5% of initial pool per cycle
    #
    # 5. LIGATION_PROB: Base probability for sequence ligation
    #    - Default: 0.08
    #    - Higher values = more frequent ligation events
    #    - Increase if sequences aren't getting longer
    #
    # 6. HARSHNESS: Environmental harshness (amplifies stability differences)
    #    - Default: 1.0
    #    - 0.5 = Mild environment (small stability differences)
    #    - 1.0 = Normal environment
    #    - 1.5 = Harsh environment (hot, acidic)
    #    - 2.0 = Extreme environment (large stability differences)
    #
    # 7. TRNA_MIN_STEM_LOOPS: Minimum stem-loops for tRNA detection
    #    - Default: 3
    #    - Typical tRNA has 3-4 stem-loops
    #
    # 8. TRNA_MIN_END_PAIRS: Minimum end base pairs for acceptor stem
    #    - Default: 3
    #    - Acceptor stem typically has 4-7 base pairs
    #
    # 9. TRNA_USE_VIENNA: Use ViennaRNA for tRNA validation
    #    - Default: False
    #    - Set to True for more accurate detection (slower)
    #
    # ================================================================

    # --- EDIT THESE PARAMETERS ---
    STABILITY_METHOD = 'vienna'           # 'vienna' or 'heuristic'
    INITIAL_NUCLEOTIDE_POOL = 10000           # Total monomers at start
    NUM_CYCLES = 1000                          # Number of wet-dry cycles
    SUPPLEMENTATION_FRACTION = 0.001          # 2% of initial pool per cycle
    LIGATION_PROB = 0.15                     # Base ligation probability
    HARSHNESS = 0.15                         # Environmental harshness
    TRNA_MIN_STEM_LOOPS = 4                  # Minimum stem-loops for tRNA detection
    TRNA_MIN_END_PAIRS = 4                   # Minimum end pairs for acceptor stem
    TRNA_USE_VIENNA = True                  # Use ViennaRNA for tRNA validation
    # ----------------------------

    run_demo(
        stability_method=STABILITY_METHOD,
        initial_nucleotide_pool=INITIAL_NUCLEOTIDE_POOL,
        num_cycles=NUM_CYCLES,
        supplementation_fraction=SUPPLEMENTATION_FRACTION,
        ligation_prob=LIGATION_PROB,
        harshness=HARSHNESS,
        trna_min_stem_loops=TRNA_MIN_STEM_LOOPS,
        trna_min_end_pairs=TRNA_MIN_END_PAIRS,
        trna_use_vienna=TRNA_USE_VIENNA
    )
# Out:
# ================================================================================
#      Stability-Distillation Hypothesis Simulation
#      Simulating wet-dry cycles driving RNA sequence convergence
# ================================================================================
#
# Paper: https://doi.org/10.48550/arXiv.2403.17072
#
# Configuration:
#   Stability calculation method: VIENNA
#   Initial nucleotide pool: 10000 monomers
#   Number of cycles: 1000
#   Supplementation fraction: 0.1% of initial pool per cycle
#   Ligation probability (base): 0.15
#   Environmental harshness: 0.15
#     (Higher = more extreme conditions, stability differences amplified)
#   tRNA detection:
#     - Minimum stem-loops: 4
#     - Minimum end pairs (acceptor stem): 4
#     - Use ViennaRNA validation: True
#
#   ✓ Using ViennaRNA for stability calculations
#
# Simulation initialized
#   Initial sequence count: 200
#   Unique sequences: 200
#   Initial nucleotide pool: 10000
#   ViennaRNA available: True
#   Environmental harshness: 0.15
#   Supplementation fraction: 0.1% of initial pool per cycle
#   Ligation base probability: 0.15
#   tRNA detection: min_stem_loops=4, min_end_pairs=4, use_vienna=True
#
# Starting simulation: 1000 wet-dry cycles...
# ----------------------------------------------------------------------
#   Cycle   0: Longest RNA = GAUAUA (length=6)
#   [Record] Cycle   0: Entropy=3.342 | Unique= 189 | Total copies=  9888 | Avg len=5.7 | Max len=6 | tRNA candidates=0
#
#   Cycle   1: Longest RNA = GAUAUA (length=6)
#   Cycle   2: Longest RNA = GAUAUA (length=6)
#   Cycle   3: Longest RNA = GAUAUA (length=6)
#   Cycle   4: Longest RNA = GAUAUA (length=6)
#   Cycle   5: Longest RNA = GAUAUA (length=6)
#   [Record] Cycle   5: Entropy=4.561 | Unique= 206 | Total copies=  4536 | Avg len=4.9 | Max len=6 | tRNA candidates=0
#
#   Cycle   6: Longest RNA = GAUAUA (length=6)
#   Cycle   7: Longest RNA = GAUAUA (length=6)
#   Cycle   8: Longest RNA = GAUAUA (length=6)
#   Cycle   9: Longest RNA = AGGAAUGC (length=8)
#   Cycle  10: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  10: Entropy=5.517 | Unique= 193 | Total copies=  1828 | Avg len=4.8 | Max len=8 | tRNA candidates=0
#
#   Cycle  11: Longest RNA = AGGAAUGC (length=8)
#   Cycle  12: Longest RNA = AGGAAUGC (length=8)
#   Cycle  13: Longest RNA = AGGAAUGC (length=8)
#   Cycle  14: Longest RNA = AGGAAUGC (length=8)
#   Cycle  15: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  15: Entropy=6.293 | Unique= 169 | Total copies=   869 | Avg len=4.9 | Max len=8 | tRNA candidates=0
#
#   Cycle  16: Longest RNA = AGGAAUGC (length=8)
#   Cycle  17: Longest RNA = AGGAAUGC (length=8)
#   Cycle  18: Longest RNA = AGGAAUGC (length=8)
#   Cycle  19: Longest RNA = AGGAAUGC (length=8)
#   Cycle  20: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  20: Entropy=6.521 | Unique= 143 | Total copies=   547 | Avg len=5.0 | Max len=8 | tRNA candidates=0
#
#   Cycle  21: Longest RNA = AGGAAUGC (length=8)
#   Cycle  22: Longest RNA = AGGAAUGC (length=8)
#   Cycle  23: Longest RNA = AGGAAUGC (length=8)
#   Cycle  24: Longest RNA = AGGAAUGC (length=8)
#   Cycle  25: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  25: Entropy=6.527 | Unique= 121 | Total copies=   405 | Avg len=5.1 | Max len=8 | tRNA candidates=0
#
#   Cycle  26: Longest RNA = AGGAAUGC (length=8)
#   Cycle  27: Longest RNA = AGGAAUGC (length=8)
#   Cycle  28: Longest RNA = AGGAAUGC (length=8)
#   Cycle  29: Longest RNA = AGGAAUGC (length=8)
#   Cycle  30: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  30: Entropy=6.346 | Unique= 103 | Total copies=   311 | Avg len=5.3 | Max len=8 | tRNA candidates=0
#
#   Cycle  31: Longest RNA = AGGAAUGC (length=8)
#   Cycle  32: Longest RNA = AGGAAUGC (length=8)
#   Cycle  33: Longest RNA = AGGAAUGC (length=8)
#   Cycle  34: Longest RNA = AGGAAUGC (length=8)
#   Cycle  35: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  35: Entropy=6.100 | Unique=  88 | Total copies=   289 | Avg len=5.5 | Max len=8 | tRNA candidates=0
#
#   Cycle  36: Longest RNA = AGGAAUGC (length=8)
#   Cycle  37: Longest RNA = AGGAAUGC (length=8)
#   Cycle  38: Longest RNA = AGGAAUGC (length=8)
#   Cycle  39: Longest RNA = AGGAAUGC (length=8)
#   Cycle  40: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  40: Entropy=5.895 | Unique=  79 | Total copies=   274 | Avg len=5.6 | Max len=8 | tRNA candidates=0
#
#   Cycle  41: Longest RNA = AGGAAUGC (length=8)
#   Cycle  42: Longest RNA = AGGAAUGC (length=8)
#   Cycle  43: Longest RNA = AGGAAUGC (length=8)
#   Cycle  44: Longest RNA = AGGAAUGCG (length=9)
#   Cycle  45: Longest RNA = AGGAAUGCG (length=9)
#   [Record] Cycle  45: Entropy=5.893 | Unique=  75 | Total copies=   248 | Avg len=5.8 | Max len=9 | tRNA candidates=0
#
#   Cycle  46: Longest RNA = AGGAAUGCG (length=9)
#   Cycle  47: Longest RNA = AGGAAUGCG (length=9)
#   Cycle  48: Longest RNA = AGGAAUGCG (length=9)
#   Cycle  49: Longest RNA = AGGAAUGC (length=8)
#   Cycle  50: Longest RNA = AGGAAUGC (length=8)
#   [Record] Cycle  50: Entropy=5.712 | Unique=  69 | Total copies=   238 | Avg len=5.8 | Max len=8 | tRNA candidates=0
#
#   Cycle  51: Longest RNA = AGGAAUGC (length=8)
#   Cycle  52: Longest RNA = AGGAAUGC (length=8)
#   Cycle  53: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  54: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  55: Longest RNA = UCAACGGAUG (length=10)
#   [Record] Cycle  55: Entropy=5.623 | Unique=  64 | Total copies=   227 | Avg len=5.7 | Max len=10 | tRNA candidates=0
#
#   Cycle  56: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  57: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  58: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  59: Longest RNA = UCAACGGAUG (length=10)
#   Cycle  60: Longest RNA = CCUGUACUACUC (length=12)
#   [Record] Cycle  60: Entropy=5.597 | Unique=  62 | Total copies=   238 | Avg len=5.9 | Max len=12 | tRNA candidates=0
#
#   Cycle  61: Longest RNA = CCUGUACUACUC (length=12)
#   Cycle  62: Longest RNA = CCUGUACUACUC (length=12)
#   Cycle  63: Longest RNA = CCUGUACUACUC (length=12)
#   Cycle  64: Longest RNA = CCUGUACUACUC (length=12)
#   Cycle  65: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  65: Entropy=5.506 | Unique=  60 | Total copies=   248 | Avg len=5.8 | Max len=12 | tRNA candidates=0
#
#   Cycle  66: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  67: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  68: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  69: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  70: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  70: Entropy=5.450 | Unique=  57 | Total copies=   213 | Avg len=6.1 | Max len=12 | tRNA candidates=0
#
#   Cycle  71: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  72: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  73: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  74: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  75: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  75: Entropy=5.449 | Unique=  54 | Total copies=   206 | Avg len=6.2 | Max len=12 | tRNA candidates=0
#
#   Cycle  76: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  77: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  78: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  79: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  80: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  80: Entropy=5.314 | Unique=  51 | Total copies=   195 | Avg len=6.1 | Max len=12 | tRNA candidates=0
#
#   Cycle  81: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  82: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  83: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  84: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  85: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  85: Entropy=5.158 | Unique=  46 | Total copies=   178 | Avg len=6.3 | Max len=12 | tRNA candidates=0
#
#   Cycle  86: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  87: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  88: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  89: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  90: Longest RNA = UGCGGGCCUGUA (length=12)
#   [Record] Cycle  90: Entropy=5.050 | Unique=  47 | Total copies=   172 | Avg len=6.2 | Max len=12 | tRNA candidates=0
#
#   Cycle  91: Longest RNA = UGCGGGCCUGUA (length=12)
#   Cycle  92: Longest RNA = CUCAACGGAUG (length=11)
#   Cycle  93: Longest RNA = AACGUGAAAAGUA (length=13)
#   Cycle  94: Longest RNA = AACGUGAAAAGUA (length=13)
#   Cycle  95: Longest RNA = CUCAACGGAUG (length=11)
#   [Record] Cycle  95: Entropy=4.955 | Unique=  43 | Total copies=   147 | Avg len=5.8 | Max len=11 | tRNA candidates=0
#
#   Cycle  96: Longest RNA = CUCAACGGAUG (length=11)
#   Cycle  97: Longest RNA = CUCAACGGAUG (length=11)
#   Cycle  98: Longest RNA = CUCAACGGAUG (length=11)
#   Cycle  99: Longest RNA = CUCAACGGAUG (length=11)
#   Cycle 100: Longest RNA = UUAGUUUUAGUU (length=12)
#   [Record] Cycle 100: Entropy=4.889 | Unique=  41 | Total copies=   142 | Avg len=6.4 | Max len=12 | tRNA candidates=0
#
#   Cycle 101: Longest RNA = GAAUGCUGCACU (length=12)
#   Cycle 102: Longest RNA = GAAUGCGUGUGUG (length=13)
#   Cycle 103: Longest RNA = GAAUGCGUGUGUG (length=13)
#   Cycle 104: Longest RNA = UCAACGGAUGUCGAGC (length=16)
#   Cycle 105: Longest RNA = UCAACGGAUGUCGAGC (length=16)
#   [Record] Cycle 105: Entropy=4.817 | Unique=  36 | Total copies=   143 | Avg len=6.6 | Max len=16 | tRNA candidates=0
#
#   Cycle 106: Longest RNA = UCAACGGAUGUCGAGC (length=16)
#   Cycle 107: Longest RNA = UCAACGGAUGUCGAGC (length=16)
#   Cycle 108: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 109: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 110: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 110: Entropy=4.999 | Unique=  42 | Total copies=   156 | Avg len=6.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 111: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 112: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 113: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 114: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 115: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 115: Entropy=4.912 | Unique=  43 | Total copies=   155 | Avg len=6.2 | Max len=18 | tRNA candidates=0
#
#   Cycle 116: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 117: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 118: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 119: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 120: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 120: Entropy=4.835 | Unique=  40 | Total copies=   141 | Avg len=6.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 121: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 122: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 123: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 124: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 125: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 125: Entropy=4.696 | Unique=  39 | Total copies=   137 | Avg len=7.1 | Max len=18 | tRNA candidates=0
#
#   Cycle 126: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 127: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 128: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 129: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 130: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 130: Entropy=5.038 | Unique=  43 | Total copies=   175 | Avg len=6.8 | Max len=18 | tRNA candidates=0
#
#   Cycle 131: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 132: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 133: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 134: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 135: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 135: Entropy=4.987 | Unique=  44 | Total copies=   185 | Avg len=7.1 | Max len=18 | tRNA candidates=0
#
#   Cycle 136: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 137: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 138: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 139: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 140: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   [Record] Cycle 140: Entropy=5.014 | Unique=  45 | Total copies=   169 | Avg len=6.6 | Max len=18 | tRNA candidates=0
#
#   Cycle 141: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 142: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 143: Longest RNA = ACUCAGGAAUGCUGCACU (length=18)
#   Cycle 144: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   Cycle 145: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   [Record] Cycle 145: Entropy=5.022 | Unique=  43 | Total copies=   158 | Avg len=6.9 | Max len=16 | tRNA candidates=0
#
#   Cycle 146: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   Cycle 147: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   Cycle 148: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   Cycle 149: Longest RNA = GCGUUGACCGAACGAA (length=16)
#   Cycle 150: Longest RNA = GAAUGCUGCACUU (length=13)
#   [Record] Cycle 150: Entropy=4.809 | Unique=  39 | Total copies=   130 | Avg len=6.8 | Max len=13 | tRNA candidates=0
#
#   Cycle 151: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 152: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 153: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 154: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 155: Longest RNA = GAAUGCUGCACUU (length=13)
#   [Record] Cycle 155: Entropy=4.750 | Unique=  37 | Total copies=   138 | Avg len=7.2 | Max len=13 | tRNA candidates=0
#
#   Cycle 156: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 157: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 158: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 159: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 160: Longest RNA = GAAUGCUGCACUU (length=13)
#   [Record] Cycle 160: Entropy=4.960 | Unique=  42 | Total copies=   160 | Avg len=7.0 | Max len=13 | tRNA candidates=0
#
#   Cycle 161: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 162: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 163: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 164: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 165: Longest RNA = GAAUGCUGCACUU (length=13)
#   [Record] Cycle 165: Entropy=4.788 | Unique=  39 | Total copies=   148 | Avg len=6.9 | Max len=13 | tRNA candidates=0
#
#   Cycle 166: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 167: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 168: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 169: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 170: Longest RNA = GAAUGCUGCACUU (length=13)
#   [Record] Cycle 170: Entropy=5.027 | Unique=  44 | Total copies=   169 | Avg len=6.8 | Max len=13 | tRNA candidates=0
#
#   Cycle 171: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 172: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 173: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 174: Longest RNA = GAAUGCUGCACUU (length=13)
#   Cycle 175: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   [Record] Cycle 175: Entropy=4.773 | Unique=  39 | Total copies=   147 | Avg len=8.0 | Max len=19 | tRNA candidates=0
#
#   Cycle 176: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 177: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 178: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 179: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 180: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   [Record] Cycle 180: Entropy=4.837 | Unique=  38 | Total copies=   134 | Avg len=8.4 | Max len=19 | tRNA candidates=0
#
#   Cycle 181: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 182: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 183: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 184: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 185: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   [Record] Cycle 185: Entropy=4.853 | Unique=  40 | Total copies=   145 | Avg len=8.6 | Max len=19 | tRNA candidates=0
#
#   Cycle 186: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 187: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 188: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 189: Longest RNA = UGAACGAACGAAUUUAGUU (length=19)
#   Cycle 190: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   [Record] Cycle 190: Entropy=4.878 | Unique=  41 | Total copies=   170 | Avg len=9.1 | Max len=20 | tRNA candidates=0
#
#   Cycle 191: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 192: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 193: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 194: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 195: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   [Record] Cycle 195: Entropy=5.064 | Unique=  46 | Total copies=   176 | Avg len=9.2 | Max len=20 | tRNA candidates=0
#
#   Cycle 196: Longest RNA = GAAUGCUGCACUUAACGAACGAAU (length=24)
#   Cycle 197: Longest RNA = GAAUGCUGCACUUAACGAACGAAU (length=24)
#   Cycle 198: Longest RNA = GAAUGCUGCACUUAACGAACGAAU (length=24)
#   Cycle 199: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 200: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   [Record] Cycle 200: Entropy=5.048 | Unique=  43 | Total copies=   163 | Avg len=9.5 | Max len=20 | tRNA candidates=0
#
#   Cycle 201: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 202: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 203: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 204: Longest RNA = GAAUGCUGCACUUCUUAGUU (length=20)
#   Cycle 205: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   [Record] Cycle 205: Entropy=5.091 | Unique=  48 | Total copies=   175 | Avg len=9.4 | Max len=21 | tRNA candidates=0
#
#   Cycle 206: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   Cycle 207: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   Cycle 208: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   Cycle 209: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   Cycle 210: Longest RNA = UGAACGAACGAAUGGCGUUGU (length=21)
#   [Record] Cycle 210: Entropy=4.772 | Unique=  41 | Total copies=   155 | Avg len=9.9 | Max len=21 | tRNA candidates=0
#
#   Cycle 211: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 212: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 213: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 214: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 215: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   [Record] Cycle 215: Entropy=4.749 | Unique=  40 | Total copies=   149 | Avg len=10.0 | Max len=23 | tRNA candidates=0
#
#   Cycle 216: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 217: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 218: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 219: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 220: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   [Record] Cycle 220: Entropy=4.761 | Unique=  38 | Total copies=   137 | Avg len=9.6 | Max len=23 | tRNA candidates=0
#
#   Cycle 221: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 222: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 223: Longest RNA = GAACGAACGAACACGAAACUCAG (length=23)
#   Cycle 224: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 225: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 225: Entropy=4.628 | Unique=  36 | Total copies=   136 | Avg len=9.3 | Max len=22 | tRNA candidates=0
#
#   Cycle 226: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 227: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 228: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 229: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 230: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 230: Entropy=4.258 | Unique=  29 | Total copies=   120 | Avg len=10.7 | Max len=22 | tRNA candidates=0
#
#   Cycle 231: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 232: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 233: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 234: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 235: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 235: Entropy=4.383 | Unique=  30 | Total copies=   123 | Avg len=9.1 | Max len=22 | tRNA candidates=0
#
#   Cycle 236: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 237: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 238: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 239: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 240: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 240: Entropy=4.436 | Unique=  30 | Total copies=   129 | Avg len=9.9 | Max len=22 | tRNA candidates=0
#
#   Cycle 241: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 242: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 243: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 244: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 245: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 245: Entropy=4.444 | Unique=  30 | Total copies=   129 | Avg len=10.6 | Max len=22 | tRNA candidates=0
#
#   Cycle 246: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 247: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 248: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 249: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 250: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 250: Entropy=4.441 | Unique=  33 | Total copies=   119 | Avg len=9.3 | Max len=22 | tRNA candidates=0
#
#   Cycle 251: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 252: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 253: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 254: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 255: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 255: Entropy=4.512 | Unique=  34 | Total copies=   124 | Avg len=9.6 | Max len=22 | tRNA candidates=0
#
#   Cycle 256: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 257: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 258: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 259: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 260: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 260: Entropy=4.609 | Unique=  33 | Total copies=   121 | Avg len=9.1 | Max len=22 | tRNA candidates=0
#
#   Cycle 261: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 262: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 263: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 264: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 265: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 265: Entropy=4.451 | Unique=  30 | Total copies=   113 | Avg len=9.1 | Max len=22 | tRNA candidates=0
#
#   Cycle 266: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 267: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 268: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 269: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 270: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 270: Entropy=4.643 | Unique=  32 | Total copies=   124 | Avg len=8.3 | Max len=22 | tRNA candidates=0
#
#   Cycle 271: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 272: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 273: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 274: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 275: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   [Record] Cycle 275: Entropy=4.403 | Unique=  31 | Total copies=   130 | Avg len=7.7 | Max len=22 | tRNA candidates=0
#
#   Cycle 276: Longest RNA = UGAACGAACGAAUGGCGUUGUG (length=22)
#   Cycle 277: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 278: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 279: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 280: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   [Record] Cycle 280: Entropy=4.220 | Unique=  29 | Total copies=   121 | Avg len=6.8 | Max len=18 | tRNA candidates=0
#
#   Cycle 281: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 282: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 283: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 284: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 285: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 285: Entropy=4.523 | Unique=  33 | Total copies=   123 | Avg len=7.7 | Max len=19 | tRNA candidates=0
#
#   Cycle 286: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 287: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 288: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 289: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 290: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 290: Entropy=4.416 | Unique=  31 | Total copies=   104 | Avg len=8.6 | Max len=19 | tRNA candidates=0
#
#   Cycle 291: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 292: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 293: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 294: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 295: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 295: Entropy=4.439 | Unique=  32 | Total copies=   117 | Avg len=8.8 | Max len=19 | tRNA candidates=0
#
#   Cycle 296: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 297: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 298: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 299: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 300: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 300: Entropy=4.414 | Unique=  29 | Total copies=   123 | Avg len=9.9 | Max len=19 | tRNA candidates=0
#
#   Cycle 301: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 302: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 303: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 304: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 305: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 305: Entropy=4.566 | Unique=  32 | Total copies=   129 | Avg len=9.0 | Max len=19 | tRNA candidates=0
#
#   Cycle 306: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 307: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 308: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 309: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 310: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 310: Entropy=4.570 | Unique=  32 | Total copies=   130 | Avg len=10.0 | Max len=19 | tRNA candidates=0
#
#   Cycle 311: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 312: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 313: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 314: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 315: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   [Record] Cycle 315: Entropy=4.688 | Unique=  35 | Total copies=   125 | Avg len=9.7 | Max len=19 | tRNA candidates=0
#
#   Cycle 316: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 317: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 318: Longest RNA = ACGAAACUCAGGUGUGUGC (length=19)
#   Cycle 319: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 320: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   [Record] Cycle 320: Entropy=4.648 | Unique=  36 | Total copies=   126 | Avg len=10.0 | Max len=18 | tRNA candidates=0
#
#   Cycle 321: Longest RNA = ACGAAACUCAGGUGUGUG (length=18)
#   Cycle 322: Longest RNA = UGGCGUUGCACGGCGUUGU (length=19)
#   Cycle 323: Longest RNA = UGGCGUUGCACGGCGUUGU (length=19)
#   Cycle 324: Longest RNA = UGGCGUUGCACGGCGUUGU (length=19)
#   Cycle 325: Longest RNA = UGGCGUUGCACGGCGUUGU (length=19)
#   [Record] Cycle 325: Entropy=4.665 | Unique=  37 | Total copies=   138 | Avg len=9.8 | Max len=19 | tRNA candidates=0
#
#   Cycle 326: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 327: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 328: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 329: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 330: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   [Record] Cycle 330: Entropy=4.936 | Unique=  41 | Total copies=   159 | Avg len=9.4 | Max len=19 | tRNA candidates=0
#
#   Cycle 331: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 332: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 333: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 334: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 335: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   [Record] Cycle 335: Entropy=4.971 | Unique=  40 | Total copies=   162 | Avg len=10.6 | Max len=19 | tRNA candidates=0
#
#   Cycle 336: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 337: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 338: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 339: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 340: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   [Record] Cycle 340: Entropy=4.873 | Unique=  41 | Total copies=   153 | Avg len=10.6 | Max len=19 | tRNA candidates=0
#
#   Cycle 341: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 342: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 343: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 344: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 345: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   [Record] Cycle 345: Entropy=4.947 | Unique=  44 | Total copies=   157 | Avg len=9.7 | Max len=19 | tRNA candidates=0
#
#   Cycle 346: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 347: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 348: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 349: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   Cycle 350: Longest RNA = GACGAAACUCAGGUGUGUG (length=19)
#   [Record] Cycle 350: Entropy=5.022 | Unique=  45 | Total copies=   164 | Avg len=9.9 | Max len=19 | tRNA candidates=0
#
#   Cycle 351: Longest RNA = GGAGGCGUUGCAGCGUUGCA (length=20)
#   Cycle 352: Longest RNA = GGAGGCGUUGCAGCGUUGCA (length=20)
#   Cycle 353: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 354: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 355: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   [Record] Cycle 355: Entropy=5.114 | Unique=  46 | Total copies=   174 | Avg len=10.7 | Max len=26 | tRNA candidates=0
#
#   Cycle 356: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 357: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 358: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 359: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 360: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   [Record] Cycle 360: Entropy=5.046 | Unique=  44 | Total copies=   170 | Avg len=11.0 | Max len=26 | tRNA candidates=0
#
#   Cycle 361: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 362: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 363: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 364: Longest RNA = GCGUUGCAUCCACGAAACUCAGCGCUGGUGUGUGG (length=35)
#   Cycle 365: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   [Record] Cycle 365: Entropy=4.977 | Unique=  41 | Total copies=   158 | Avg len=11.1 | Max len=27 | tRNA candidates=0
#
#   Cycle 366: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 367: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 368: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 369: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 370: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   [Record] Cycle 370: Entropy=4.896 | Unique=  39 | Total copies=   151 | Avg len=11.0 | Max len=27 | tRNA candidates=0
#
#   Cycle 371: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 372: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 373: Longest RNA = ACGAAACUCAGGUGUGUGGGUGUGUGC (length=27)
#   Cycle 374: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   Cycle 375: Longest RNA = CCACGAAACUCAGCGCUGGUGUGUGG (length=26)
#   [Record] Cycle 375: Entropy=4.565 | Unique=  36 | Total copies=   142 | Avg len=11.6 | Max len=26 | tRNA candidates=0
#
#   Cycle 376: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 377: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 378: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 379: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 380: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 380: Entropy=4.713 | Unique=  37 | Total copies=   153 | Avg len=10.4 | Max len=28 | tRNA candidates=0
#
#   Cycle 381: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 382: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 383: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 384: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 385: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 385: Entropy=4.684 | Unique=  35 | Total copies=   141 | Avg len=10.5 | Max len=28 | tRNA candidates=0
#
#   Cycle 386: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 387: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 388: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 389: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 390: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 390: Entropy=4.581 | Unique=  35 | Total copies=   155 | Avg len=10.8 | Max len=28 | tRNA candidates=0
#
#   Cycle 391: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 392: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 393: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 394: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 395: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 395: Entropy=4.797 | Unique=  39 | Total copies=   156 | Avg len=10.1 | Max len=28 | tRNA candidates=0
#
#   Cycle 396: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 397: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 398: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 399: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 400: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 400: Entropy=4.724 | Unique=  38 | Total copies=   142 | Avg len=10.3 | Max len=28 | tRNA candidates=0
#
#   Cycle 401: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 402: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 403: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 404: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   Cycle 405: Longest RNA = CCCCACGAAACUCAGCGCUGGUGUGUGG (length=28)
#   [Record] Cycle 405: Entropy=4.722 | Unique=  37 | Total copies=   134 | Avg len=10.7 | Max len=28 | tRNA candidates=0
#
#   Cycle 406: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 407: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 408: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 409: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 410: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   [Record] Cycle 410: Entropy=4.545 | Unique=  36 | Total copies=   128 | Avg len=10.4 | Max len=25 | tRNA candidates=0
#
#   Cycle 411: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 412: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 413: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 414: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 415: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   [Record] Cycle 415: Entropy=4.343 | Unique=  29 | Total copies=   111 | Avg len=10.8 | Max len=25 | tRNA candidates=0
#
#   Cycle 416: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 417: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 418: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 419: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 420: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   [Record] Cycle 420: Entropy=4.349 | Unique=  29 | Total copies=   116 | Avg len=10.8 | Max len=25 | tRNA candidates=0
#
#   Cycle 421: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 422: Longest RNA = GUCGCGUUGCACUCGCGUUGCACGC (length=25)
#   Cycle 423: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 424: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 425: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   [Record] Cycle 425: Entropy=4.405 | Unique=  30 | Total copies=   126 | Avg len=10.8 | Max len=21 | tRNA candidates=0
#
#   Cycle 426: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 427: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 428: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 429: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 430: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   [Record] Cycle 430: Entropy=4.434 | Unique=  31 | Total copies=   125 | Avg len=10.0 | Max len=21 | tRNA candidates=0
#
#   Cycle 431: Longest RNA = UCGGCGUUGCAAAUUUCCAGC (length=21)
#   Cycle 432: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 433: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 434: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 435: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   [Record] Cycle 435: Entropy=4.496 | Unique=  30 | Total copies=   114 | Avg len=10.4 | Max len=23 | tRNA candidates=0
#
#   Cycle 436: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 437: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 438: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 439: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 440: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   [Record] Cycle 440: Entropy=4.343 | Unique=  31 | Total copies=   119 | Avg len=10.4 | Max len=23 | tRNA candidates=0
#
#   Cycle 441: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 442: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 443: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 444: Longest RNA = AUUUCCAGCUUCGCGUUGCACGC (length=23)
#   Cycle 445: Longest RNA = CUUCGCGUUGCACGCA (length=16)
#   [Record] Cycle 445: Entropy=4.290 | Unique=  29 | Total copies=   116 | Avg len=9.7 | Max len=16 | tRNA candidates=0
#
#   Cycle 446: Longest RNA = CUUCGCGUUGCACGCA (length=16)
#   Cycle 447: Longest RNA = CUUCGCGUUGCACGCA (length=16)
#   Cycle 448: Longest RNA = CUUCGCGUUGCACGCA (length=16)
#   Cycle 449: Longest RNA = CUUCGCGUUGCACGCA (length=16)
#   Cycle 450: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   [Record] Cycle 450: Entropy=4.577 | Unique=  33 | Total copies=   129 | Avg len=9.3 | Max len=17 | tRNA candidates=0
#
#   Cycle 451: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 452: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 453: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 454: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 455: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   [Record] Cycle 455: Entropy=4.523 | Unique=  33 | Total copies=   128 | Avg len=9.8 | Max len=17 | tRNA candidates=0
#
#   Cycle 456: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 457: Longest RNA = GCGUUGCAUUGGUGUGUGG (length=19)
#   Cycle 458: Longest RNA = GCGUUGCAUUGGUGUGUGG (length=19)
#   Cycle 459: Longest RNA = GCGUUGCAUUGGUGUGUGG (length=19)
#   Cycle 460: Longest RNA = GCGUUGCAUUGGUGUGUGG (length=19)
#   [Record] Cycle 460: Entropy=4.649 | Unique=  34 | Total copies=   136 | Avg len=10.2 | Max len=19 | tRNA candidates=0
#
#   Cycle 461: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 462: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 463: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 464: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 465: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   [Record] Cycle 465: Entropy=4.602 | Unique=  33 | Total copies=   124 | Avg len=9.2 | Max len=17 | tRNA candidates=0
#
#   Cycle 466: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 467: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 468: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 469: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 470: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   [Record] Cycle 470: Entropy=4.626 | Unique=  34 | Total copies=   135 | Avg len=10.4 | Max len=17 | tRNA candidates=0
#
#   Cycle 471: Longest RNA = CUUCGCGUUGCACGCAG (length=17)
#   Cycle 472: Longest RNA = GUCGAUCGGCGUUGCAA (length=17)
#   Cycle 473: Longest RNA = GUCGAUCGGCGUUGCAA (length=17)
#   Cycle 474: Longest RNA = GUCGAUCGGCGUUGCAA (length=17)
#   Cycle 475: Longest RNA = UUUCCAGGUUUCCAGC (length=16)
#   [Record] Cycle 475: Entropy=4.515 | Unique=  32 | Total copies=   122 | Avg len=9.8 | Max len=16 | tRNA candidates=0
#
#   Cycle 476: Longest RNA = UUUCCAGGUUUCCAGC (length=16)
#   Cycle 477: Longest RNA = UUUCCAGGUUUCCAGC (length=16)
#   Cycle 478: Longest RNA = UUUCCAGGUUUCCAGC (length=16)
#   Cycle 479: Longest RNA = UUUCCAGGUUUCCAGC (length=16)
#   Cycle 480: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   [Record] Cycle 480: Entropy=4.427 | Unique=  35 | Total copies=   127 | Avg len=9.4 | Max len=17 | tRNA candidates=0
#
#   Cycle 481: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 482: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 483: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 484: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 485: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   [Record] Cycle 485: Entropy=4.537 | Unique=  33 | Total copies=   131 | Avg len=9.6 | Max len=17 | tRNA candidates=0
#
#   Cycle 486: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 487: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 488: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 489: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 490: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   [Record] Cycle 490: Entropy=4.731 | Unique=  35 | Total copies=   136 | Avg len=8.7 | Max len=17 | tRNA candidates=0
#
#   Cycle 491: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 492: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 493: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 494: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 495: Longest RNA = CCUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 495: Entropy=4.462 | Unique=  33 | Total copies=   123 | Avg len=8.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 496: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 497: Longest RNA = CUUCGCGUUGCACGCUA (length=17)
#   Cycle 498: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 499: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 500: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 500: Entropy=4.665 | Unique=  35 | Total copies=   137 | Avg len=7.7 | Max len=18 | tRNA candidates=0
#
#   Cycle 501: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 502: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 503: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 504: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 505: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 505: Entropy=4.523 | Unique=  30 | Total copies=   133 | Avg len=9.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 506: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 507: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 508: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 509: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 510: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 510: Entropy=4.680 | Unique=  33 | Total copies=   140 | Avg len=9.3 | Max len=18 | tRNA candidates=0
#
#   Cycle 511: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 512: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 513: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 514: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 515: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 515: Entropy=4.675 | Unique=  35 | Total copies=   162 | Avg len=9.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 516: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 517: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 518: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 519: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 520: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 520: Entropy=4.601 | Unique=  36 | Total copies=   140 | Avg len=9.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 521: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 522: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 523: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 524: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 525: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 525: Entropy=4.557 | Unique=  32 | Total copies=   130 | Avg len=9.4 | Max len=18 | tRNA candidates=0
#
#   Cycle 526: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 527: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 528: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 529: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 530: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 530: Entropy=4.661 | Unique=  34 | Total copies=   136 | Avg len=9.5 | Max len=18 | tRNA candidates=0
#
#   Cycle 531: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 532: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 533: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 534: Longest RNA = ACUUCGCGUUGCACGCUAG (length=19)
#   Cycle 535: Longest RNA = ACUUCGCGUUGCACGCUAG (length=19)
#   [Record] Cycle 535: Entropy=4.528 | Unique=  34 | Total copies=   133 | Avg len=10.4 | Max len=19 | tRNA candidates=0
#
#   Cycle 536: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 537: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 538: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 539: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 540: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   [Record] Cycle 540: Entropy=4.536 | Unique=  29 | Total copies=   117 | Avg len=9.9 | Max len=18 | tRNA candidates=0
#
#   Cycle 541: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 542: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 543: Longest RNA = ACUUCGCGUUGCACGCUA (length=18)
#   Cycle 544: Longest RNA = CUGGUGUGUGGUCAUUUCCAGCCCCC (length=26)
#   Cycle 545: Longest RNA = CUGGUGUGUGGUCAUUUCCAGCCCCC (length=26)
#   [Record] Cycle 545: Entropy=4.391 | Unique=  30 | Total copies=   129 | Avg len=10.3 | Max len=26 | tRNA candidates=0
#
#   Cycle 546: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUA (length=30)
#   Cycle 547: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUA (length=30)
#   Cycle 548: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUA (length=30)
#   Cycle 549: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUA (length=30)
#   Cycle 550: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   [Record] Cycle 550: Entropy=4.441 | Unique=  32 | Total copies=   134 | Avg len=10.1 | Max len=31 | tRNA candidates=0
#
#   Cycle 551: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 552: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 553: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 554: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 555: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   [Record] Cycle 555: Entropy=4.487 | Unique=  32 | Total copies=   121 | Avg len=12.0 | Max len=31 | tRNA candidates=0
#
#   Cycle 556: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 557: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 558: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 559: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 560: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   [Record] Cycle 560: Entropy=4.374 | Unique=  28 | Total copies=   119 | Avg len=11.6 | Max len=31 | tRNA candidates=0
#
#   Cycle 561: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 562: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 563: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 564: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
#   Cycle 565: Longest RNA = AUUUCCAGCCCCCCUUCGCGUUGCACGCUAC (length=31)
# ...
#   5     Yeast_Met_tRNA                  43 nt    40.3%     30.0
#   6     E_coli_Trp_tRNA                 43 nt    39.5%     28.0
#   7     Yeast_Phe_tRNA                  43 nt    39.0%     27.0
#   8     E_coli_Cys_tRNA                 43 nt    36.1%     35.0
#   9     Human_Phe_tRNA                  42 nt    45.5%     26.0
#   10    E_coli_Thr_tRNA                 42 nt    43.4%     30.0
#
#   Best local match: Yeast_Val_tRNA
#   Fragment length: 46 nt
#   Fragment identity: 44.7%
#   Fragment position in generated sequence: nt 2 - 59
#   Fragment sequence: CAUGCGCGUUGCAUUAUGCGCGUUGCAUUUAUGCGCGUUGCAUUUU
#   Alignment:
#     Gen: --UUC-AUGCGCGU--UGCAUUAUGCGCGU-UGCAUUUAUGCGC-----GUUGC-AUUUU----------------
#     tRNA: GGUUCCAU-AGUGUAGUG-GUUAU-CACGUCUGC-UUUACACGCAGAAGGUCUCUAGUUCGAUCCUGGUGGAAACA
#
# ------------------------------------------------------------
# Generated sequence (copy count: 6):
#   ACCCUGGUGUGUGGUCGAAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCUUAUGUU...
#   Length: 126 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Leu_tRNA             48.8%     41.0
#   2     Human_Lys_tRNA              46.9%     26.0
#   3     E_coli_Asn_tRNA             46.5%     27.0
#   4     E_coli_Ser_tRNA             46.5%     31.0
#   5     E_coli_Tyr_tRNA             46.2%     31.0
#   ... and 25 more
#
#   Best global match: E_coli_Leu_tRNA (identity: 48.8%)
#   Alignment preview (first 80 chars):
#     Gen: ACCCUGGUGUGUGGUCGAAUUCCCUGGUGUGUGGUCGAAU-UGCAUUUCCAGCCUUAUGUUUCCAGGUUUCCAGAUGUUU
#     tRNA: GCC---GAGU-UGG-CGAAAU---UGGU---UAGACGCAGAUG-AUUU--AG------G--UCGUGGUGUC--GAUG---
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Leu_tRNA                112 nt    46.5%     51.0
#   2     E_coli_Ser_tRNA                105 nt    44.2%     52.0
#   3     E_coli_Tyr_tRNA                104 nt    43.1%     50.0
#   4     E_coli_Asp_tRNA                104 nt    43.0%     47.0
#   5     E_coli_Thr_tRNA                103 nt    42.6%     45.0
#   6     E_coli_Phe_tRNA                 94 nt    40.0%     46.0
#   7     E_coli_His_tRNA                 92 nt    39.2%     45.0
#   8     E_coli_Met_tRNA                 92 nt    38.2%     42.0
#   9     E_coli_Trp_tRNA                 91 nt    40.3%     52.0
#   10    E_coli_Gly_tRNA                 90 nt    39.1%     50.0
#
#   Best local match: E_coli_Leu_tRNA
#   Fragment length: 112 nt
#   Fragment identity: 46.5%
#   Fragment position in generated sequence: nt 2 - 114
#   Fragment sequence: CCUGGUGUGUGGUCGAAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCUUAUGUUUC
#   Alignment:
#     Gen: ACCCUGGUGUGUGGUCGAAUUCCCUGGUGUGUGGUCGAAU-UGCAUUUCCAGCCUUAUGUU-UCCA-GGUUUCCAGAUGU
#     tRNA: -GCC--GAGU-UGG-CGAAAU---UGGU---UAGACGCAGAUG-AUUU--AG-GUCGUGGUGUCGAUGG--GC---AUGU
#
# ------------------------------------------------------------
# Generated sequence (copy count: 6):
#   UCCCUGGUGUGUGGUCCUGUUUCCAGGUUUCCAGAGC
#   Length: 37 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Asn_tRNA             47.9%     19.0
#   2     Yeast_Val_tRNA              45.8%     16.0
#   3     E_coli_His_tRNA             45.2%     10.0
#   4     Bsub_Met_tRNA               45.2%     12.0
#   5     Human_Lys_tRNA              44.6%     10.0
#   ... and 25 more
#
#   Best global match: E_coli_Asn_tRNA (identity: 47.9%)
#   Alignment preview (first 80 chars):
#     Gen: UCC-CUG--GU---GU--GU-G---GUC---CUGUU--UCC--A-------GGUU----UCCAG--AG----C
#     tRNA: UCCUCUGUAGUUCAGUCGGUAGAACGGCGGACUGUUAAUCCGUAUGUCACUGGUUCGAGUCCAGUCAGAGGAG
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Arg_tRNA                 36 nt    32.0%     25.0
#   2     E_coli_Glu_tRNA                 36 nt    32.0%     23.0
#   3     Yeast_Val_tRNA                  34 nt    43.1%     33.0
#   4     Human_Val_tRNA                  34 nt    33.3%     30.0
#   5     E_coli_Asp_tRNA                 33 nt    27.5%     26.0
#   6     E_coli_Trp_tRNA                 32 nt    29.9%     25.0
#   7     E_coli_Gln_tRNA                 30 nt    35.1%     23.0
#   8     Human_Lys_tRNA                  26 nt    37.8%     25.0
#   9     E_coli_His_tRNA                 26 nt    32.1%     29.0
#   10    Yeast_Ala_tRNA                  26 nt    32.0%     27.0
#
#   Best local match: E_coli_Arg_tRNA
#   Fragment length: 36 nt
#   Fragment identity: 32.0%
#   Fragment position in generated sequence: nt 1 - 43
#   Fragment sequence: CCCUGGUGUGUGGUCCUGUUUCCAGGUUUCCAGAGC
#   Alignment:
#     Gen: UCCCUGGUGUG--UGGUCCUGUUU---C-CAGGUUUCCAGAGC--------------------------------
#     tRNA: GCCCCAGUG-GCCUAG--CUGGAUAGGCGCUGGCCUCCGGAGCCAGGGUCGUGGGUUCGAAUCCCAUCUGGGGCG
#
# ------------------------------------------------------------
# Generated sequence (copy count: 5):
#   UUCAUGCGCGUUGCAUUAUGCGCGUUGCAUUU
#   Length: 32 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     Yeast_Ala_tRNA              41.7%      5.0
#   2     Human_Phe_tRNA              40.5%      1.0
#   3     E_coli_Thr_tRNA             39.7%      0.0
#   4     E_coli_Gln_tRNA             38.9%      0.0
#   5     E_coli_Lys_tRNA             38.9%     -1.0
#   ... and 25 more
#
#   Best global match: Yeast_Ala_tRNA (identity: 41.7%)
#   Alignment preview (first 80 chars):
#     Gen: ------U----UCA-U-------GCGCG---UU-GCAU-U-----AU-GCGCGUU-G-----CAUU--U---
#     tRNA: GGGGGAUUAGCUCAAUUGGUAGAGCGCGUGCUUCGCAUGUACGAGAUCGUGAGUUCGAUCCUCAUUCCUCCA
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     Yeast_Val_tRNA                  30 nt    31.6%     29.0
#   2     Human_Val_tRNA                  30 nt    27.6%     23.0
#   3     Bsub_Met_tRNA                   28 nt    29.3%     25.0
#   4     E_coli_Arg_tRNA                 28 nt    26.7%     23.0
#   5     Yeast_Met_tRNA                  27 nt    30.7%     23.0
#   6     E_coli_Ile_tRNA                 27 nt    30.3%     29.0
#   7     Yeast_Phe_tRNA                  27 nt    28.0%     19.0
#   8     E_coli_Trp_tRNA                 27 nt    27.0%     21.0
#   9     E_coli_Val_tRNA                 26 nt    30.7%     27.0
#   10    E_coli_Lys_tRNA                 26 nt    29.9%     27.0
#
#   Best local match: Yeast_Val_tRNA
#   Fragment length: 30 nt
#   Fragment identity: 31.6%
#   Fragment position in generated sequence: nt 2 - 38
#   Fragment sequence: CAUGCGCGUUGCAUUAUGCGCGUUGCAUUU
#   Alignment:
#     Gen: --UUC-AUGCGCGU--UGCAUUAUGCGCGU-UGCAUUU--------------------------------------
#     tRNA: GGUUCCAU-AGUGUAGUG-GUUAU-CACGUCUGC-UUUACACGCAGAAGGUCUCUAGUUCGAUCCUGGUGGAAACA
#
# ------------------------------------------------------------
# Generated sequence (copy count: 5):
#   UAGCAUUUCCAGCCUUAUGUUUCCAGGUUUCCAGAUGUUUCCAGGUUUCCAGAUGUUUCC...
#   Length: 129 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Leu_tRNA             50.4%     44.0 ★
#   2     E_coli_His_tRNA             48.1%     32.0
#   3     E_coli_Ile_tRNA             47.7%     30.0
#   4     Bsub_Met_tRNA               47.3%     29.0
#   5     E_coli_Thr_tRNA             47.0%     29.0
#   ... and 25 more
#
#   Best global match: E_coli_Leu_tRNA (identity: 50.4%)
#   Alignment preview (first 80 chars):
#     Gen: UAGCAUUUCCAGCCUUAUGUUUCCAGGUUUCCAGAU-GUUUCCAGGUUUC-CAGAUG-UUUCCAGGUUUCCAGACCUGGU
#     tRNA: --G-----CC-G----A-GUU----GG---CGAAAUUGGUU--AG---ACGCAGAUGAUUU--AGGU---C-G---UGGU
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Leu_tRNA                103 nt    44.1%     61.0
#   2     E_coli_Trp_tRNA                 95 nt    40.3%     50.0
#   3     E_coli_His_tRNA                 89 nt    38.2%     48.0
#   4     Human_Lys_tRNA                  89 nt    37.8%     42.0
#   5     E_coli_Met_tRNA                 89 nt    36.0%     44.0
#   6     E_coli_Thr_tRNA                 88 nt    36.8%     49.0
#   7     E_coli_Ser_tRNA                 87 nt    36.3%     51.0
#   8     E_coli_Asp_tRNA                 87 nt    35.5%     42.0
#   9     E_coli_Ala_tRNA                 86 nt    37.1%     49.0
#   10    Yeast_Phe_tRNA                  86 nt    37.0%     50.0
#
#   Best local match: E_coli_Leu_tRNA
#   Fragment length: 103 nt
#   Fragment identity: 44.1%
#   Fragment position in generated sequence: nt 22 - 125
#   Fragment sequence: CCAGGUUUCCAGAUGUUUCCAGGUUUCCAGAUGUUUCCAGGUUUCCAGACCUGGUGUGUG
#   Alignment:
#     Gen: UAGCAUUUCCAGCCUUAUGUUUCCAG-GUUUCCAGAUGUUUCCAGGUU--UC-CAGAUG-UUUCCAGGUUUCCAGACCUG
#     tRNA: ---------------------GCC-GAGUUGGC-GAAAUU----GGUUAGACGCAGAUGAUUU--AGGU---C-G---UG
#
# ------------------------------------------------------------
# Generated sequence (copy count: 5):
#   CCCCUGGUGUGUGGUCGAAUCGUUUCCAGGUUUCCAGAUUCCUUUCCAGGUUUCCAGUGG...
#   Length: 63 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Asn_tRNA             58.0%     42.0 ★
#   2     E_coli_Phe_tRNA             56.2%     40.0 ★
#   3     Yeast_Val_tRNA              54.4%     38.0 ★
#   4     E_coli_Arg_tRNA             52.6%     32.0 ★
#   5     Human_Lys_tRNA              52.5%     32.0 ★
#   ... and 25 more
#
#   Best global match: E_coli_Asn_tRNA (identity: 58.0%)
#   Alignment preview (first 80 chars):
#     Gen: CCC-CUGGU-GU---GU-GGUCGAAUCGUUUCC-AG-GUU--UCCAG-AU-UC-CU--UUCCAGGUUUCCAGU--G-GCA
#     tRNA: UCCUCU-GUAGUUCAGUCGGUAGAA-CG--GCGGACUGUUAAUCC-GUAUGUCACUGGUUCGAG---UCCAGUCAGAGGA
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Phe_tRNA                 62 nt    56.2%     43.0
#   2     E_coli_Asn_tRNA                 62 nt    55.4%     46.0
#   3     E_coli_Arg_tRNA                 62 nt    52.6%     37.0
#   4     Human_Lys_tRNA                  62 nt    52.5%     37.0
#   5     Yeast_Met_tRNA                  62 nt    51.9%     36.0
#   6     Bsub_Met_tRNA                   61 nt    51.9%     36.0
#   7     E_coli_Ile_tRNA                 61 nt    47.4%     34.0
#   8     E_coli_Glu_tRNA                 61 nt    45.2%     36.0
#   9     E_coli_Leu_tRNA                 61 nt    41.9%     41.0
#   10    Yeast_Val_tRNA                  59 nt    54.4%     46.0
#
#   Best local match: E_coli_Phe_tRNA
#   Fragment length: 62 nt
#   Fragment identity: 56.2%
#   Fragment position in generated sequence: nt 1 - 79
#   Fragment sequence: CCCUGGUGUGUGGUCGAAUCGUUUCCAGGUUUCCAGAUUCCUUUCCAGGUUUCCAGUGGC
#   Alignment:
#     Gen: CCCCUGG-U-G-U--GU-GGUCGA--AUCG--UU-----UCCAGGUUUCCA-GAUUCCUUUCC-AGGUUUCCAGUGGCAA
#     tRNA: GCCC-GGAUAGCUCAGUCGGUAGAGCAGGGGAUUGAAAAUCCCCGUGUCCUUGGUUCGAUUCCGAG---UCC-G-GGCA-
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   GGACCUGGUGUGUGGUCCCAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCUUAUGU...
#   Length: 127 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Ser_tRNA             48.1%     36.0
#   2     E_coli_Leu_tRNA             47.7%     36.0
#   3     Human_Lys_tRNA              46.5%     26.0
#   4     Yeast_Met_tRNA              46.5%     26.0
#   5     E_coli_Ala_tRNA             46.1%     29.0
#   ... and 25 more
#
#   Best global match: E_coli_Ser_tRNA (identity: 48.1%)
#   Alignment preview (first 80 chars):
#     Gen: GGACCUGGUGUGUGGUCCCAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCUUAUGUUUCCAGGUUUCCAGAUGU-U
#     tRNA: GGA----GAG-GUGG-CCGA----GUGGUUUAAGG-CGA--UGGACUUGAAAUC-UAU-U-----GG------G--GUCU
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Tyr_tRNA                111 nt    45.0%     49.0
#   2     E_coli_Ser_tRNA                105 nt    43.8%     51.0
#   3     E_coli_Asp_tRNA                104 nt    41.9%     44.0
#   4     E_coli_Leu_tRNA                101 nt    42.2%     50.0
#   5     E_coli_Thr_tRNA                101 nt    41.5%     44.0
#   6     E_coli_Phe_tRNA                 93 nt    38.9%     46.0
#   7     E_coli_His_tRNA                 92 nt    38.9%     45.0
#   8     E_coli_Met_tRNA                 92 nt    37.9%     42.0
#   9     E_coli_Trp_tRNA                 91 nt    40.0%     52.0
#   10    E_coli_Gly_tRNA                 90 nt    38.8%     50.0
#
#   Best local match: E_coli_Tyr_tRNA
#   Fragment length: 111 nt
#   Fragment identity: 45.0%
#   Fragment position in generated sequence: nt 6 - 117
#   Fragment sequence: GGUGUGUGGUCCCAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCUUAUGUUUCCAG
#   Alignment:
#     Gen: GGACCUGGUGUGUGGUCCCAUUCCCUGGUGUGUGGUCGAAUUGCAUUUCCAGCCU-UAUGUUU-CCAGGUU-UCCAGAUG
#     tRNA: ------GGUG-G-GG-----UUCCC----GAGCGG-CCAAAGGGA---GCAGACUCUAAAUCUGCC--GUCAUC--GA--
#
# ------------------------------------------------------------
# Generated sequence (copy count: 4):
#   UCCCUGGUGUGUGGUCCUGUUUCCAGGUUUCCAGAGU
#   Length: 37 nt
# ------------------------------------------------------------
#
#   [Global Alignment - Overall Similarity]
#   Rank  tRNA                      Identity   Score
#   --------------------------------------------------
#   1     E_coli_Asn_tRNA             47.9%     19.0
#   2     Yeast_Val_tRNA              45.8%     16.0
#   3     Bsub_Met_tRNA               45.2%     13.0
#   4     Human_Lys_tRNA              44.6%     10.0
#   5     E_coli_His_tRNA             43.8%      7.0
#   ... and 25 more
#
#   Best global match: E_coli_Asn_tRNA (identity: 47.9%)
#   Alignment preview (first 80 chars):
#     Gen: UCC-CUG--GU---GU--GU-G---GUC---CUGUU--UCC--A-------GGUU----UCCAG--AG----U
#     tRNA: UCCUCUGUAGUUCAGUCGGUAGAACGGCGGACUGUUAAUCCGUAUGUCACUGGUUCGAGUCCAGUCAGAGGAG
#
#   [Local Alignment - Conserved Fragments]
#   Rank  tRNA                      Frag Len   Identity   Score
#   ------------------------------------------------------------
#   1     E_coli_Glu_tRNA                 36 nt    33.8%     23.0
#   2     Human_Val_tRNA                  34 nt    40.0%     30.0
#   3     Yeast_Val_tRNA                  34 nt    38.2%     33.0
#   4     E_coli_Asp_tRNA                 32 nt    25.6%     25.0
#   5     E_coli_Gln_tRNA                 30 nt    36.5%     23.0
#   6     E_coli_Trp_tRNA                 26 nt    35.1%     27.0
#   7     E_coli_Lys_tRNA                 26 nt    34.2%     23.0
#   8     Human_Lys_tRNA                  26 nt    33.8%     25.0
#   9     Yeast_Ala_tRNA                  26 nt    33.3%     27.0
#   10    Human_Ala_tRNA                  26 nt    32.5%     28.0
#
#   Best local match: E_coli_Glu_tRNA
#   Fragment length: 36 nt
#   Fragment identity: 33.8%
#   Fragment position in generated sequence: nt 1 - 46
#   Fragment sequence: CCCUGGUGUGUGGUCCUGUUUCCAGGUUUCCAGAGU
#   Alignment:
#     Gen: -UCCC--UGGUGU-GUGGUCCUGUUUC-CAG--GUUUC-CAGA-GU----------------------------
#     tRNA: GUCCCCUUCGUCUAGAGGCCCAG-GACACCGCCCUUUCACGGCGGUAACAGGGGUUCGAAUCCCCUAGGGGACG
#
# ================================================================================
# END OF TRNA COMPARISON
# ================================================================================

# %% [markdown]
# In the origin of life, the appropriate intensity of environmental selection is crucial. If the environment is too harsh—such as excessively high temperature or extreme acidity—it may indiscriminately degrade almost any RNA sequence, including those with relatively stable structures, leaving little opportunity for complex molecules to accumulate. Conversely, an overly mild environment may fail to amplify the stability differences among sequences, resulting in a slow and inefficient distillation process.
#
# Moderate supplementation of ribonucleotides plays an important role in maintaining the total copy number of RNA molecules. Periodic addition of "food" (monomers) provides the raw materials necessary for polymerization and ligation during dry phases, preventing the system from going extinct due to resource depletion. However, excessive supplementation may reduce evolutionary pressure. When monomers are too abundant, even unstable and functionally irrelevant sequences can survive and replicate, reducing the selective advantage of stable, structure-forming RNAs. In such a "resource-rich" environment, the system may remain trapped at the stage of short, random sequences without ever progressing toward longer, functional molecules like tRNA-like structures.
#
# This phenomenon mirrors Darwinian natural selection: without sufficient selective pressure, evolution stalls; with too much pressure, diversity collapses. Only at the "Goldilocks" level of environmental stress and resource availability can the stability-distillation process effectively generate and accumulate informational macromolecules. This suggests that the origin of life is not merely a chemical inevitability but a finely balanced interplay between environmental conditions and molecular selection.
